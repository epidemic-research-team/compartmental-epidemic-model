# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Dataset" data-toc-modified-id="Dataset-1">Dataset</a></span><ul class="toc-item"><li><span><a href="#Mobility" data-toc-modified-id="Mobility-1.1">Mobility</a></span></li><li><span><a href="#Cases" data-toc-modified-id="Cases-1.2">Cases</a></span></li><li><span><a href="#Merge" data-toc-modified-id="Merge-1.3">Merge</a></span></li></ul></li><li><span><a href="#Model" data-toc-modified-id="Model-2">Model</a></span></li><li><span><a href="#Experiments" data-toc-modified-id="Experiments-3">Experiments</a></span><ul class="toc-item"><li><span><a href="#$\lambda-(t)-=-f(t)$---Gaussian---Matern32" data-toc-modified-id="$\lambda-(t)-=-f(t)$---Gaussian---Matern32-3.1"><strong>$\lambda (t) = f(t)$</strong> - Gaussian - Matern32</a></span></li><li><span><a href="#$\lambda-(t)-=-f(S(t),-I(t))$---Gaussian---Matern32" data-toc-modified-id="$\lambda-(t)-=-f(S(t),-I(t))$---Gaussian---Matern32-3.2"><strong>$\lambda (t) = f(S(t), I(t))$</strong> - Gaussian - Matern32</a></span></li><li><span><a href="#$\lambda-(t)-=-f(S(t)*I(t))$---Gaussian---Matern32" data-toc-modified-id="$\lambda-(t)-=-f(S(t)*I(t))$---Gaussian---Matern32-3.3"><strong>$\lambda (t) = f(S(t)*I(t))$</strong> - Gaussian - Matern32</a></span></li><li><span><a href="#$\lambda-(t)-=-f(S(t)+I(t))$---Gaussian---Matern32" data-toc-modified-id="$\lambda-(t)-=-f(S(t)+I(t))$---Gaussian---Matern32-3.4"><strong>$\lambda (t) = f(S(t)+I(t))$</strong> - Gaussian - Matern32</a></span></li><li><span><a href="#$\lambda-(t)-=-f(t,-S(t)*I(t))$---Gaussian---Matern32" data-toc-modified-id="$\lambda-(t)-=-f(t,-S(t)*I(t))$---Gaussian---Matern32-3.5"><strong>$\lambda (t) = f(t, S(t)*I(t))$</strong> - Gaussian - Matern32</a></span></li><li><span><a href="#$\lambda-(t)-=-f(t,-S(t)+I(t))$---Gaussian---Matern32" data-toc-modified-id="$\lambda-(t)-=-f(t,-S(t)+I(t))$---Gaussian---Matern32-3.6"><strong>$\lambda (t) = f(t, S(t)+I(t))$</strong> - Gaussian - Matern32</a></span></li><li><span><a href="#$\lambda-(t)-=-f(t,-S(t),-I(t))$---Gaussian---Matern32" data-toc-modified-id="$\lambda-(t)-=-f(t,-S(t),-I(t))$---Gaussian---Matern32-3.7"><strong>$\lambda (t) = f(t, S(t), I(t))$</strong> - Gaussian - Matern32</a></span></li><li><span><a href="#$\lambda-(t)-=-f(t,-S(t)^p,-I(t)^p)$---Gaussian---Matern32" data-toc-modified-id="$\lambda-(t)-=-f(t,-S(t)^p,-I(t)^p)$---Gaussian---Matern32-3.8"><strong>$\lambda (t) = f(t, S(t)^p, I(t)^p)$</strong> - Gaussian - Matern32</a></span></li><li><span><a href="#$\lambda-(t)-=-f(t,-I(t),-Home(t))$---Gaussian---Matern32" data-toc-modified-id="$\lambda-(t)-=-f(t,-I(t),-Home(t))$---Gaussian---Matern32-3.9"><strong>$\lambda (t) = f(t, I(t), Home(t))$</strong> - Gaussian - Matern32</a></span></li><li><span><a href="#$\lambda-(t)-=-f(t,-S(t)*I(t),-Home(t))$---Gaussian---Matern32" data-toc-modified-id="$\lambda-(t)-=-f(t,-S(t)*I(t),-Home(t))$---Gaussian---Matern32-3.10"><strong>$\lambda (t) = f(t, S(t)*I(t), Home(t))$</strong> - Gaussian - Matern32</a></span></li><li><span><a href="#$\lambda-(t)-=-f(t,-S(t)*I(t),-Home(t)*Work(t)*Recreational(t))$---Gaussian---Matern32" data-toc-modified-id="$\lambda-(t)-=-f(t,-S(t)*I(t),-Home(t)*Work(t)*Recreational(t))$---Gaussian---Matern32-3.11"><strong>$\lambda (t) = f(t, S(t)*I(t), Home(t)*Work(t)*Recreational(t))$</strong> - Gaussian - Matern32</a></span></li><li><span><a href="#$\lambda-(t)-=-f(t,-S(t),-I(t),-Home(t),-Work(t),-Recreational(t))$---Gaussian---Matern32" data-toc-modified-id="$\lambda-(t)-=-f(t,-S(t),-I(t),-Home(t),-Work(t),-Recreational(t))$---Gaussian---Matern32-3.12"><strong>$\lambda (t) = f(t, S(t), I(t), Home(t), Work(t), Recreational(t))$</strong> - Gaussian - Matern32</a></span></li><li><span><a href="#$\lambda-(t)-=-f(t,-S(t)^p,-I(t)^p,-Home(t)^p,-Work(t)^p,-Recreational(t)^p)$---Gaussian---Matern32" data-toc-modified-id="$\lambda-(t)-=-f(t,-S(t)^p,-I(t)^p,-Home(t)^p,-Work(t)^p,-Recreational(t)^p)$---Gaussian---Matern32-3.13"><strong>$\lambda (t) = f(t, S(t)^p, I(t)^p, Home(t)^p, Work(t)^p, Recreational(t)^p)$</strong> - Gaussian - Matern32</a></span></li><li><span><a href="#$\lambda-(t)-=-f(t)$---Gaussian---SE*L*RQ" data-toc-modified-id="$\lambda-(t)-=-f(t)$---Gaussian---SE*L*RQ-3.14"><strong>$\lambda (t) = f(t)$</strong> - Gaussian - SE*L*RQ</a></span></li><li><span><a href="#$\lambda-(t)-=-f(S(t),-I(t))$---Gaussian---SE*L*RQ" data-toc-modified-id="$\lambda-(t)-=-f(S(t),-I(t))$---Gaussian---SE*L*RQ-3.15"><strong>$\lambda (t) = f(S(t), I(t))$</strong> - Gaussian - SE*L*RQ</a></span></li><li><span><a href="#$\lambda-(t)-=-f(S(t)*I(t))$---Gaussian---SE*L*RQ" data-toc-modified-id="$\lambda-(t)-=-f(S(t)*I(t))$---Gaussian---SE*L*RQ-3.16"><strong>$\lambda (t) = f(S(t)*I(t))$</strong> - Gaussian - SE*L*RQ</a></span></li><li><span><a href="#$\lambda-(t)-=-f(S(t)+I(t))$---Gaussian---SE*L*RQ" data-toc-modified-id="$\lambda-(t)-=-f(S(t)+I(t))$---Gaussian---SE*L*RQ-3.17"><strong>$\lambda (t) = f(S(t)+I(t))$</strong> - Gaussian - SE*L*RQ</a></span></li><li><span><a href="#$\lambda-(t)-=-f(t,-S(t)*I(t))$---Gaussian---SE*L*RQ" data-toc-modified-id="$\lambda-(t)-=-f(t,-S(t)*I(t))$---Gaussian---SE*L*RQ-3.18"><strong>$\lambda (t) = f(t, S(t)*I(t))$</strong> - Gaussian - SE*L*RQ</a></span></li><li><span><a href="#$\lambda-(t)-=-f(t,-S(t)+I(t))$---Gaussian---SE*L*RQ" data-toc-modified-id="$\lambda-(t)-=-f(t,-S(t)+I(t))$---Gaussian---SE*L*RQ-3.19"><strong>$\lambda (t) = f(t, S(t)+I(t))$</strong> - Gaussian - SE*L*RQ</a></span></li><li><span><a href="#$\lambda-(t)-=-f(t,-S(t),-I(t))$---Gaussian---SE*L*RQ" data-toc-modified-id="$\lambda-(t)-=-f(t,-S(t),-I(t))$---Gaussian---SE*L*RQ-3.20"><strong>$\lambda (t) = f(t, S(t), I(t))$</strong> - Gaussian - SE*L*RQ</a></span></li><li><span><a href="#$\lambda-(t)-=-f(t,-S(t)^p,-I(t)^p)$---Gaussian---SE*L*RQ" data-toc-modified-id="$\lambda-(t)-=-f(t,-S(t)^p,-I(t)^p)$---Gaussian---SE*L*RQ-3.21"><strong>$\lambda (t) = f(t, S(t)^p, I(t)^p)$</strong> - Gaussian - SE*L*RQ</a></span></li><li><span><a href="#$\lambda-(t)-=-f(t,-I(t),-Home(t))$---Gaussian---SE*L*RQ" data-toc-modified-id="$\lambda-(t)-=-f(t,-I(t),-Home(t))$---Gaussian---SE*L*RQ-3.22"><strong>$\lambda (t) = f(t, I(t), Home(t))$</strong> - Gaussian - SE*L*RQ</a></span></li><li><span><a href="#$\lambda-(t)-=-f(t,-S(t)*I(t),-Home(t))$---Gaussian---SE*L*RQ" data-toc-modified-id="$\lambda-(t)-=-f(t,-S(t)*I(t),-Home(t))$---Gaussian---SE*L*RQ-3.23"><strong>$\lambda (t) = f(t, S(t)*I(t), Home(t))$</strong> - Gaussian - SE*L*RQ</a></span></li><li><span><a href="#$\lambda-(t)-=-f(t,-S(t)*I(t),-Home(t)*Work(t)*Recreational(t))$---Gaussian---SE*L*RQ" data-toc-modified-id="$\lambda-(t)-=-f(t,-S(t)*I(t),-Home(t)*Work(t)*Recreational(t))$---Gaussian---SE*L*RQ-3.24"><strong>$\lambda (t) = f(t, S(t)*I(t), Home(t)*Work(t)*Recreational(t))$</strong> - Gaussian - SE*L*RQ</a></span></li><li><span><a href="#$\lambda-(t)-=-f(t,-S(t),-I(t),-Home(t),-Work(t),-Recreational(t))$---Gaussian---SE*L*RQ" data-toc-modified-id="$\lambda-(t)-=-f(t,-S(t),-I(t),-Home(t),-Work(t),-Recreational(t))$---Gaussian---SE*L*RQ-3.25"><strong>$\lambda (t) = f(t, S(t), I(t), Home(t), Work(t), Recreational(t))$</strong> - Gaussian - SE*L*RQ</a></span></li><li><span><a href="#$\lambda-(t)-=-f(t,-S(t)^p,-I(t)^p,-Home(t)^p,-Work(t)^p,-Recreational(t)^p)$---Gaussian---SE*L*RQ" data-toc-modified-id="$\lambda-(t)-=-f(t,-S(t)^p,-I(t)^p,-Home(t)^p,-Work(t)^p,-Recreational(t)^p)$---Gaussian---SE*L*RQ-3.26"><strong>$\lambda (t) = f(t, S(t)^p, I(t)^p, Home(t)^p, Work(t)^p, Recreational(t)^p)$</strong> - Gaussian - SE*L*RQ</a></span></li><li><span><a href="#$\lambda-(t)-=-f(t)$---Gaussian---SE+L+RQ" data-toc-modified-id="$\lambda-(t)-=-f(t)$---Gaussian---SE+L+RQ-3.27"><strong>$\lambda (t) = f(t)$</strong> - Gaussian - SE+L+RQ</a></span></li><li><span><a href="#$\lambda-(t)-=-f(S(t),-I(t))$---Gaussian---SE+L+RQ" data-toc-modified-id="$\lambda-(t)-=-f(S(t),-I(t))$---Gaussian---SE+L+RQ-3.28"><strong>$\lambda (t) = f(S(t), I(t))$</strong> - Gaussian - SE+L+RQ</a></span></li><li><span><a href="#$\lambda-(t)-=-f(S(t)*I(t))$---Gaussian---SE+L+RQ" data-toc-modified-id="$\lambda-(t)-=-f(S(t)*I(t))$---Gaussian---SE+L+RQ-3.29"><strong>$\lambda (t) = f(S(t)*I(t))$</strong> - Gaussian - SE+L+RQ</a></span></li><li><span><a href="#$\lambda-(t)-=-f(S(t)+I(t))$---Gaussian---SE+L+RQ" data-toc-modified-id="$\lambda-(t)-=-f(S(t)+I(t))$---Gaussian---SE+L+RQ-3.30"><strong>$\lambda (t) = f(S(t)+I(t))$</strong> - Gaussian - SE+L+RQ</a></span></li><li><span><a href="#$\lambda-(t)-=-f(t,-S(t)*I(t))$---Gaussian---SE+L+RQ" data-toc-modified-id="$\lambda-(t)-=-f(t,-S(t)*I(t))$---Gaussian---SE+L+RQ-3.31"><strong>$\lambda (t) = f(t, S(t)*I(t))$</strong> - Gaussian - SE+L+RQ</a></span></li><li><span><a href="#$\lambda-(t)-=-f(t,-S(t)+I(t))$---Gaussian---SE+L+RQ" data-toc-modified-id="$\lambda-(t)-=-f(t,-S(t)+I(t))$---Gaussian---SE+L+RQ-3.32"><strong>$\lambda (t) = f(t, S(t)+I(t))$</strong> - Gaussian - SE+L+RQ</a></span></li><li><span><a href="#$\lambda-(t)-=-f(t,-S(t),-I(t))$---Gaussian---SE+L+RQ" data-toc-modified-id="$\lambda-(t)-=-f(t,-S(t),-I(t))$---Gaussian---SE+L+RQ-3.33"><strong>$\lambda (t) = f(t, S(t), I(t))$</strong> - Gaussian - SE+L+RQ</a></span></li><li><span><a href="#$\lambda-(t)-=-f(t,-S(t)^p,-I(t)^p)$---Gaussian---SE+L+RQ" data-toc-modified-id="$\lambda-(t)-=-f(t,-S(t)^p,-I(t)^p)$---Gaussian---SE+L+RQ-3.34"><strong>$\lambda (t) = f(t, S(t)^p, I(t)^p)$</strong> - Gaussian - SE+L+RQ</a></span></li><li><span><a href="#$\lambda-(t)-=-f(t,-I(t),-Home(t))$---Gaussian---SE+L+RQ" data-toc-modified-id="$\lambda-(t)-=-f(t,-I(t),-Home(t))$---Gaussian---SE+L+RQ-3.35"><strong>$\lambda (t) = f(t, I(t), Home(t))$</strong> - Gaussian - SE+L+RQ</a></span></li><li><span><a href="#$\lambda-(t)-=-f(t,-S(t)*I(t),-Home(t))$---Gaussian---SE+L+RQ" data-toc-modified-id="$\lambda-(t)-=-f(t,-S(t)*I(t),-Home(t))$---Gaussian---SE+L+RQ-3.36"><strong>$\lambda (t) = f(t, S(t)*I(t), Home(t))$</strong> - Gaussian - SE+L+RQ</a></span></li><li><span><a href="#$\lambda-(t)-=-f(t,-S(t)*I(t),-Home(t)*Work(t)*Recreational(t))$---Gaussian---SE+L+RQ" data-toc-modified-id="$\lambda-(t)-=-f(t,-S(t)*I(t),-Home(t)*Work(t)*Recreational(t))$---Gaussian---SE+L+RQ-3.37"><strong>$\lambda (t) = f(t, S(t)*I(t), Home(t)*Work(t)*Recreational(t))$</strong> - Gaussian - SE+L+RQ</a></span></li><li><span><a href="#$\lambda-(t)-=-f(t,-S(t),-I(t),-Home(t),-Work(t),-Recreational(t))$---Gaussian---SE+L+RQ" data-toc-modified-id="$\lambda-(t)-=-f(t,-S(t),-I(t),-Home(t),-Work(t),-Recreational(t))$---Gaussian---SE+L+RQ-3.38"><strong>$\lambda (t) = f(t, S(t), I(t), Home(t), Work(t), Recreational(t))$</strong> - Gaussian - SE+L+RQ</a></span></li><li><span><a href="#$\lambda-(t)-=-f(t,-S(t)^p,-I(t)^p,-Home(t)^p,-Work(t)^p,-Recreational(t)^p)$---Gaussian---SE+L+RQ" data-toc-modified-id="$\lambda-(t)-=-f(t,-S(t)^p,-I(t)^p,-Home(t)^p,-Work(t)^p,-Recreational(t)^p)$---Gaussian---SE+L+RQ-3.39"><strong>$\lambda (t) = f(t, S(t)^p, I(t)^p, Home(t)^p, Work(t)^p, Recreational(t)^p)$</strong> - Gaussian - SE+L+RQ</a></span></li></ul></li><li><span><a href="#Report" data-toc-modified-id="Report-4">Report</a></span></li></ul></div>

# %%
import pandas as pd
from itertools import cycle
import gpflow
import numpy as np
from gpflow.utilities import print_summary, positive
from gpflow.ci_utils import ci_niter
from gpflow.optimizers import NaturalGradient
from gpflow import set_trainable
import tensorflow as tf
import tensorflow_probability as tfp
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from collections import namedtuple
import statsmodels.api as sm

sns.set(style="white")
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', -1)

gpflow.config.set_default_float(np.float64)
gpflow.config.set_default_summary_fmt("notebook")

# %% [markdown]
# ## Dataset

# %% [markdown]
# ### Mobility

# %%
mobility_data = pd.read_csv(
    "../Data/Google/Global_Mobility_Report.csv", 
    encoding="ISO-8859-1", 
    parse_dates=["date"],
    dayfirst=True
)
# Out:
# /Users/N547113/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3071: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
mobility_data_us = mobility_data[
    (mobility_data["country_region"]=="United States") & 
    (~mobility_data["sub_region_1"].isnull()) &
    (mobility_data["sub_region_2"].isnull())
]
mobility_data_us_temp = mobility_data_us.iloc[:,7:] # keep only relevant columns
mobility_data_us_temp["state"] = mobility_data_us["sub_region_1"]
mobility_data_us_temp.iloc[:,1:-1] = mobility_data_us_temp.iloc[:,1:-1].apply(lambda x: x/100 + 1)
mobility_data_us =  mobility_data_us_temp.reset_index(drop=True)

# %%
mobility_data_us = pd.DataFrame({
    "state": mobility_data_us["state"],
    "date": mobility_data_us["date"],
    "HOME": mobility_data_us['residential_percent_change_from_baseline'],
    "WORK": mobility_data_us['workplaces_percent_change_from_baseline'],
    "RECREATIONAL": mobility_data_us['retail_and_recreation_percent_change_from_baseline'],
    "OTHER": mobility_data_us.iloc[:,2:5].mean(axis=1)
})

# %%
fig, axs = plt.subplots(9, 2, figsize=(20, 30), sharex=True)

for i, state in enumerate(mobility_data_us["state"].unique()):
    ax = axs[i//2, i%2]
    ax.plot(mobility_data_us[mobility_data_us["state"]==state].set_index("date")[["HOME", "WORK"]])
    ax.set_title(state)
# Out:
# /Users/N547113/opt/anaconda3/lib/python3.8/site-packages/pandas/plotting/_converter.py:129: FutureWarning: Using an implicitly registered datetime converter for a matplotlib plotting method. The converter was registered by pandas on import. Future versions of pandas will require you to explicitly register matplotlib converters.
#
# To register the converters:
# 	>>> from pandas.plotting import register_matplotlib_converters
# 	>>> register_matplotlib_converters()
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ### Cases

# %%
# COVID Cases from Microsoft, includes Recovered and Infected
ms_covid = pd.read_csv(
    "../Data/Microsoft/COVID_CASES.csv", 
    encoding="ISO-8859-1",
    parse_dates=["Updated"],
    dayfirst=False
)
ms_us_covid = ms_covid[
    (ms_covid["Country_Region"]=="United States") & 
    (~ms_covid["AdminRegion1"].isnull()) &
    (ms_covid["AdminRegion2"].isnull())
]
ms_us_covid = ms_us_covid.loc[:,["AdminRegion1", "Updated", "Confirmed", "ConfirmedChange", "Deaths", "Recovered"]]
ms_us_covid.rename(columns={"AdminRegion1": "state"}, inplace=True)
ms_us_covid.reset_index(drop=True, inplace=True)

# %%
STATE_POPULATION = {
    "Alaska": 731545, "Alabama": 4900000, "Arkansas": 3017800, "Arizona": 7278700, "California": 39512200,
    "Colorado": 5758700, "Connecticut": 3565300, "District of Columbia": 705749, "Delaware": 973764,
    "Florida": 21477700, "Georgia": 10617400, "Hawaii": 1415900, "Iowa": 3155100, "Idaho": 1787100,
    "Illinois": 12671800, "Indiana": 6732200, "Kansas": 2913300, "Kentucky": 4467700, "Louisiana": 4648800,
    "Massachusetts": 6892500, "Maryland": 6045700, "Maine": 1344200, "Michigan": 9986900, "Minnesota": 5639600,
    "Missouri": 6137400, "Mississippi": 2976100, "Montana": 1068800, "North Carolina": 10488100, 
    "North Dakota": 762062, "Nebraska": 1934400, "New Hampshire": 1359700, "New Jersey": 8882200, 
    "New Mexico": 2096800, "Nevada": 3080200, "New York": 19453600, "Ohio": 11689100, "Oklahoma": 3957000,
    "Oregon": 4217700, "Pennsylvania": 12802000, "Rhode Island": 1059400, "South Carolina": 5148700,
    "South Dakota": 884659, "Tennessee": 6829200, "Texas": 28995900, "Utah": 3206000, "Virginia": 8535500,
    "Vermont": 623989, "Washington": 7614900, "Wisconsin": 5822400, "West Virginia": 1792100, "Wyoming": 578759
}

processed_dfs = []

for state in ms_us_covid["state"].unique():
    d = ms_us_covid[ms_us_covid["state"] == state]
    d = d.fillna(method='ffill').fillna(0)
    d["I"] = d["Confirmed"] - d["Deaths"] - d["Recovered"]

    d["S"] = int(STATE_POPULATION[state]*0.5) - d["I"]

    d["index"] = d["Updated"].dt.dayofyear

    d["ConfirmedChange"] = d["ConfirmedChange"].rolling(7).median()
    d["I"] = d["I"].rolling(7).median()
    d["S"] = d["S"].rolling(7).median()

    d.dropna(inplace=True)
    processed_dfs.append(d)
    
ms_us_covid = pd.concat(processed_dfs)

# %%
import math
fig, axs = plt.subplots(
    math.ceil(ms_us_covid["state"].nunique() / 2), 2, 
    figsize=(20, 60), sharex=True
)

for i, state in enumerate(ms_us_covid["state"].unique()):
    ax = axs[i//2, i%2]
    d = ms_us_covid[ms_us_covid["state"]==state]
    ax.plot(d.set_index("Updated")[["ConfirmedChange"]])
    ax.set_title(state)

# %% [markdown]
# ### Merge

# %%
final_data = ms_us_covid.merge(
    mobility_data_us, how='left', left_on=["state", "Updated"], right_on=["state", "date"]
)
final_data.dropna(inplace=True)
final_data.set_index("state", inplace=True)

# %% [markdown]
# ## Model

# %%
class COVIDGPModel(object):
    
    def __init__(
        self, 
        name,
        likelihood=gpflow.likelihoods.Gaussian(),
        kernel=gpflow.kernels.Matern32(),
        inducing_variable_func=None,
        variational_optimizer=None,
        model_variables_optimizer=None,
        n_iter=1000,
    ):
        self.name = name
        self.likelihood = likelihood
        self.kernel = kernel
        self.inducing_variable_func = inducing_variable_func or self._inducing_variable_func
        self.variational_optimizer = variational_optimizer or NaturalGradient(gamma=1.0)
        self.model_variables_optimizer = model_variables_optimizer or tf.optimizers.Adam(0.01)
        self.n_iter = n_iter
        
        self._model = None
        self._x_scaler = None
        self._y_scaler = None
        self._elbo = []
        
    def _inducing_variable_func(self, data):
        size = int(data.shape[0] * 0.1)
        
        Z = data[
            np.random.randint(data.shape[0], size=size), 0
        ]

        if data.shape[1] <= 1:
            return Z.reshape((-1, 1))
        
        for col in range(1, data.shape[1]):
            Z = np.vstack([
                Z, data[
                    np.random.randint(data.shape[0], size=size), col
                ]
            ])
            
        return Z.T
           
    def _init_model(self, X):
        self._model = gpflow.models.SVGP(
            likelihood=self.likelihood,
            kernel=self.kernel,
            inducing_variable=self.inducing_variable_func(X), 
            num_data=X.shape[0]
        )

        set_trainable(self._model.q_mu, False)
        set_trainable(self._model.q_sqrt, False)
        
        return self._model
        
    def _loss_function(self, X, y):
        model = self._model
        def _loss():
            return model.training_loss((X, y))
        return _loss
        
    def train(self, X, y):
        self._init_model(X)

        for _ in range(ci_niter(self.n_iter)):
            self.model_variables_optimizer.minimize(
                self._loss_function(X, y),
                self._model.trainable_variables
            )
            self.variational_optimizer.minimize(
                self._loss_function(X, y),
                [(self._model.q_mu, self._model.q_sqrt)]
            )
            self._elbo.append(self._model.elbo((X, y)))

    def predict(self, X):
        return self._model.predict_f(X)
    
    @property
    def score(self):
        return self._elbo[-1].numpy()
    
    def plot_elbo(self, ax=None):
        if not self._model:
            raise RuntimeError('The model must be trained first')
            
        if not ax:
            ax = plt
        ax.plot(self._elbo)
        
    def plot_prediction(self, t, X, y, t_test=None, y_test=None, num_samples=20, ax=None):
        if not ax:
            _fig, ax = plt.subplots(1, figsize=(15, 4))
        
        Ypred = self._model.predict_f_samples(X, full_cov=True, num_samples=num_samples)
        mean, var = self._model.predict_f(X)

        ax.plot(t, np.squeeze(Ypred).T, "C1", alpha=0.2)
        ax.plot(t, mean, "-", c="C0")

        lo = (mean - 2 * tf.sqrt(var)).numpy()
        hi = (mean + 2 * tf.sqrt(var)).numpy()
        ax.fill_between(t.flatten(), lo.flatten(), hi.flatten(), alpha=0.3)
        ax.plot(t, y, "o", c="C2", alpha=0.7, label="train")
        if (t_test is not None) and (y_test is not None):
            ax.plot(t_test, y_test, "o", c="C3", alpha=0.7, label="test")
            ax.legend()

# %%
_Experiment_cls = namedtuple(
    'Experiment',
    [
        'model', 'likelihood', 'kernel', 'mle', 
        'within_sample', 'var_within_sample', 
        'out_sample', 'var_out_sample', 
        'model_obj'
    ]
)

class Experiment(_Experiment_cls):
    
    def to_dict(self):
        d = self._asdict()
        d.pop('model_obj')
        return d
    
    def __key(self):
        return (self.model, self.likelihood, self.kernel)

    def __hash__(self):
        return hash(self.__key())

    def __eq__(self, other):
        if isinstance(other, Experiment):
            return self.__key() == other.__key()
        return False

def run_experiment(name, t, X, y, model_params=None, plot=False):
    np.random.seed(123)

    ix = sorted(X.index.unique())
    ix_train, ix_test = ix[:-2], ix[-2:]

    X_train, X_test = X.loc[ix_train].to_numpy(), X.loc[ix_test].to_numpy()
    y_train, y_test = y.loc[ix_train].to_numpy(), y.loc[ix_test].to_numpy()
    
    # X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=123)

    y_scaler = preprocessing.StandardScaler().fit(y_train)
    y_train = y_scaler.transform(y_train)
    y_test = y_scaler.transform(y_test)
    y = y_scaler.transform(y)

    x_scaler = preprocessing.StandardScaler().fit(X_train)
    X_train = x_scaler.transform(X_train)
    X_test = x_scaler.transform(X_test)
    X = x_scaler.transform(X)
    
    model = COVIDGPModel(name, **(model_params or {}))
    model.train(X_train, y_train)

    mean_train, var_train = model.predict(X_train)
    y_train_pred = y_scaler.inverse_transform(mean_train.numpy())
    y_train_true = y_scaler.inverse_transform(y_train)

    mean_test, var_test = model.predict(X_test)
    y_test_pred = y_scaler.inverse_transform(mean_test.numpy())
    y_test_true = y_scaler.inverse_transform(y_test)
    
    results = Experiment(
        model = model.name,
        likelihood = model.likelihood.__class__.__name__,
        kernel = model.kernel.__class__.__name__,
        mle = model.score,
        within_sample = round(np.mean(y_train_true - y_train_pred), 0),
        var_within_sample = np.mean(var_train),
        out_sample = round(np.mean(y_test_true - y_test_pred), 0),
        var_out_sample = np.mean(var_test),
        model_obj = model
    )

#     if plot:
#         f = plt.figure(figsize=(20,4))
#         ax = f.add_subplot(1, 3, (1, 2))
#         model.plot_prediction(t, X, y, t_test, y_test, ax=ax)
#         ax = f.add_subplot(1, 3, 3)
#         model.plot_prediction(t_test, X_test, y_test, t_test, y_test, ax=ax)
        
    return results, model

# %% [markdown]
# ## Experiments

# %%
results = set()

# %% [markdown]
# ### **$\lambda (t) = f(t)$** - Gaussian - Matern32

# %%
t = final_data[["Updated"]]
y = final_data[["ConfirmedChange"]]
X = final_data[["index"]]

model_params = {
}

res, model = run_experiment('$f(t)$', t, X, y, model_params=model_params, plot=True)
results.add(res)

# %%
model._model
# Out:
# <gpflow.models.svgp.SVGP object at 0x147808790>
# name                      class      transform         prior    trainable    shape          dtype    value
# ------------------------  ---------  ----------------  -------  -----------  -------------  -------  ----------------------------------------------------
# SVGP.kernel.variance      Parameter  Softplus                   True         ()             float64  0.8611783891355161
# SVGP.kernel.lengthscales  Parameter  Softplus                   True         ()             float64  2.3756752062744737
# SVGP.likelihood.variance  Parameter  Softplus + Shift           True         ()             float64  0.8266905992731187
# SVGP.inducing_variable.Z  Parameter  Identity                   True         (232, 1)       float64  [[0.65611482...
# SVGP.q_mu                 Parameter  Identity                   False        (232, 1)       float64  [[-6.76402231e-02...
# SVGP.q_sqrt               Parameter  FillTriangular             False        (1, 232, 232)  float64  [[[5.35546674e-02, 0.00000000e+00, 0.00000000e+00...

# %% [markdown]
# ### **$\lambda (t) = f(S(t), I(t))$** - Gaussian - Matern32

# %%
t = final_data[["Updated"]]
y = final_data[["ConfirmedChange"]]
X = final_data[["S", "I"]]

model_params = {
}

res, model = run_experiment('$f(S(t), I(t))$', t, X, y, model_params=model_params, plot=True)
results.add(res)

# %%
model._model
# Out:
# <gpflow.models.svgp.SVGP object at 0x145e76e80>
# name                      class      transform         prior    trainable    shape          dtype    value
# ------------------------  ---------  ----------------  -------  -----------  -------------  -------  ----------------------------------------------------
# SVGP.kernel.variance      Parameter  Softplus                   True         ()             float64  2.544371015444678
# SVGP.kernel.lengthscales  Parameter  Softplus                   True         ()             float64  1.1910197556960374
# SVGP.likelihood.variance  Parameter  Softplus + Shift           True         ()             float64  0.005440383563088922
# SVGP.inducing_variable.Z  Parameter  Identity                   True         (232, 2)       float64  [[-1.12437627e-01, 1.64382224e+00...
# SVGP.q_mu                 Parameter  Identity                   False        (232, 1)       float64  [[1.13937109e+00...
# SVGP.q_sqrt               Parameter  FillTriangular             False        (1, 232, 232)  float64  [[[2.72738584e-02, 0.00000000e+00, 0.00000000e+00...

# %% [markdown]
# ### **$\lambda (t) = f(S(t)*I(t))$** - Gaussian - Matern32

# %%
t = final_data[["Updated"]]
y = final_data[["ConfirmedChange"]]
X = pd.DataFrame({
    "S*I": final_data["S"] * final_data["I"]
}, index=final_data.index)[["S*I"]]

model_params = {
}

res, model = run_experiment('$f(S(t)*I(t))$', t, X, y, model_params=model_params, plot=True)
results.add(res)

# %%
model._model
# Out:
# <gpflow.models.svgp.SVGP object at 0x148639ca0>
# name                      class      transform         prior    trainable    shape          dtype    value
# ------------------------  ---------  ----------------  -------  -----------  -------------  -------  ----------------------------------------------------
# SVGP.kernel.variance      Parameter  Softplus                   True         ()             float64  2.4171211949507754
# SVGP.kernel.lengthscales  Parameter  Softplus                   True         ()             float64  2.607570267989189
# SVGP.likelihood.variance  Parameter  Softplus + Shift           True         ()             float64  0.05956107395283514
# SVGP.inducing_variable.Z  Parameter  Identity                   True         (232, 1)       float64  [[-0.2872052...
# SVGP.q_mu                 Parameter  Identity                   False        (232, 1)       float64  [[-2.20274149e-01...
# SVGP.q_sqrt               Parameter  FillTriangular             False        (1, 232, 232)  float64  [[[4.08506906e-03, 0.00000000e+00, 0.00000000e+00...

# %% [markdown]
# ### **$\lambda (t) = f(S(t)+I(t))$** - Gaussian - Matern32

# %%
t = final_data[["Updated"]]
y = final_data[["ConfirmedChange"]]
X = pd.DataFrame({
    "S+I": final_data["S"] + final_data["I"]
}, index=final_data.index)[[
    "S+I"
]]

model_params = {
}

res, model = run_experiment('$f(S(t)+I(t))$', t, X, y, model_params=model_params, plot=True)
results.add(res)

# %%
model._model
# Out:
# <gpflow.models.svgp.SVGP object at 0x1486a6a60>
# name                      class      transform         prior    trainable    shape          dtype    value
# ------------------------  ---------  ----------------  -------  -----------  -------------  -------  ----------------------------------------------------
# SVGP.kernel.variance      Parameter  Softplus                   True         ()             float64  2.360301427957472
# SVGP.kernel.lengthscales  Parameter  Softplus                   True         ()             float64  1.0478887093759814
# SVGP.likelihood.variance  Parameter  Softplus + Shift           True         ()             float64  0.5836362350533432
# SVGP.inducing_variable.Z  Parameter  Identity                   True         (232, 1)       float64  [[-0.73849013...
# SVGP.q_mu                 Parameter  Identity                   False        (232, 1)       float64  [[-2.73360696e-01...
# SVGP.q_sqrt               Parameter  FillTriangular             False        (1, 232, 232)  float64  [[[2.41804831e-02, 0.00000000e+00, 0.00000000e+00...

# %% [markdown]
# ### **$\lambda (t) = f(t, S(t)*I(t))$** - Gaussian - Matern32

# %%
t = final_data[["Updated"]]
y = final_data[["ConfirmedChange"]]
X = pd.DataFrame({
    "index": final_data["index"],
    "S*I": final_data["S"] * final_data["I"]
}, index=final_data.index)[[
    "index",
    "S*I"
]]

model_params = {
    'kernel': gpflow.kernels.Matern32(lengthscales=np.ones(X.shape[1]))
}

res, model = run_experiment('$f(t, S(t)*I(t))$', t, X, y, model_params=model_params, plot=True)
results.add(res)

# %%
model._model
# Out:
# <gpflow.models.svgp.SVGP object at 0x146d211f0>
# name                      class      transform         prior    trainable    shape          dtype    value
# ------------------------  ---------  ----------------  -------  -----------  -------------  -------  ----------------------------------------------------
# SVGP.kernel.variance      Parameter  Softplus                   True         ()             float64  2.9611040549056695
# SVGP.kernel.lengthscales  Parameter  Softplus                   True         (2,)           float64  [1.30180849 0.78910404]
# SVGP.likelihood.variance  Parameter  Softplus + Shift           True         ()             float64  0.020366088194627895
# SVGP.inducing_variable.Z  Parameter  Identity                   True         (232, 2)       float64  [[7.18067976e-01, 5.25932924e-01...
# SVGP.q_mu                 Parameter  Identity                   False        (232, 1)       float64  [[2.55341860e-01...
# SVGP.q_sqrt               Parameter  FillTriangular             False        (1, 232, 232)  float64  [[[3.28339141e-02, 0.00000000e+00, 0.00000000e+00...

# %% [markdown]
# ### **$\lambda (t) = f(t, S(t)+I(t))$** - Gaussian - Matern32

# %%
t = final_data[["Updated"]]
y = final_data[["ConfirmedChange"]]
X = pd.DataFrame({
    "index": final_data["index"],
    "S+I": final_data["S"] + final_data["I"]
}, index=final_data.index)[[
    "index",
    "S+I"
]]

model_params = {
    'kernel': gpflow.kernels.Matern32(lengthscales=np.ones(X.shape[1]))
}

res, model = run_experiment('$f(t, S(t)+I(t))$', t, X, y, model_params=model_params, plot=True)
results.add(res)

# %%
model._model
# Out:
# <gpflow.models.svgp.SVGP object at 0x1476020a0>
# name                      class      transform         prior    trainable    shape          dtype    value
# ------------------------  ---------  ----------------  -------  -----------  -------------  -------  ----------------------------------------------------
# SVGP.kernel.variance      Parameter  Softplus                   True         ()             float64  1.0916082196296342
# SVGP.kernel.lengthscales  Parameter  Softplus                   True         (2,)           float64  [1.44765685 0.24028506]
# SVGP.likelihood.variance  Parameter  Softplus + Shift           True         ()             float64  0.00571615613906671
# SVGP.inducing_variable.Z  Parameter  Identity                   True         (232, 2)       float64  [[6.24250443e-01, -9.44728430e-02...
# SVGP.q_mu                 Parameter  Identity                   False        (232, 1)       float64  [[2.17564820e-01...
# SVGP.q_sqrt               Parameter  FillTriangular             False        (1, 232, 232)  float64  [[[2.31725449e-02, 0.00000000e+00, 0.00000000e+00...

# %% [markdown]
# ### **$\lambda (t) = f(t, S(t), I(t))$** - Gaussian - Matern32

# %%
t = final_data[["Updated"]]
y = final_data[["ConfirmedChange"]]
X = pd.DataFrame({
    "index": final_data["index"],
    "S": final_data["S"],
    "I": final_data["I"]
}, index=final_data.index)[[
    "index",
    "S",
    "I"
]]

model_params = {
    'kernel': gpflow.kernels.Matern32(lengthscales=np.ones(X.shape[1]))
}

res, model = run_experiment('$f(t, S(t), I(t))$', t, X, y, model_params=model_params, plot=True)
results.add(res)

# %%
model._model
# Out:
# <gpflow.models.svgp.SVGP object at 0x147685c40>
# name                      class      transform         prior    trainable    shape          dtype    value
# ------------------------  ---------  ----------------  -------  -----------  -------------  -------  ----------------------------------------------------
# SVGP.kernel.variance      Parameter  Softplus                   True         ()             float64  0.8161104480145566
# SVGP.kernel.lengthscales  Parameter  Softplus                   True         (3,)           float64  [2.05541109 0.43535292 2.22403614]
# SVGP.likelihood.variance  Parameter  Softplus + Shift           True         ()             float64  0.005719590307558934
# SVGP.inducing_variable.Z  Parameter  Identity                   True         (232, 3)       float64  [[9.30086759e-01, 2.28163696e-01, 6.05994346e-01...
# SVGP.q_mu                 Parameter  Identity                   False        (232, 1)       float64  [[3.34762650e-01...
# SVGP.q_sqrt               Parameter  FillTriangular             False        (1, 232, 232)  float64  [[[2.41728375e-02, 0.00000000e+00, 0.00000000e+00...

# %% [markdown]
# ### **$\lambda (t) = f(t, S(t)^p, I(t)^p)$** - Gaussian - Matern32

# %%
t = final_data[["Updated"]]
y = final_data[["ConfirmedChange"]]
X = pd.DataFrame({
    "index": final_data["index"],
    "S": final_data["S"],
    "S**2": final_data["S"]**2,
    "S**3": final_data["S"]**3,
    "I": final_data["I"],
    "I**2": final_data["I"]**2,
    "I**3": final_data["I"]**3
}, index=final_data.index)[[
    "index",
    "S", "S**2", "S**3",
    "I", "I**2", "I**3"
]]

model_params = {
    'kernel': gpflow.kernels.Matern32(lengthscales=np.ones(X.shape[1]))
}

res, model = run_experiment('$f(t, S(t)^p, I(t)^p)$', t, X, y, model_params=model_params, plot=True)
results.add(res)

# %%
model._model
# Out:
# <gpflow.models.svgp.SVGP object at 0x1460546a0>
# name                      class      transform         prior    trainable    shape          dtype    value
# ------------------------  ---------  ----------------  -------  -----------  -------------  -------  ----------------------------------------------------
# SVGP.kernel.variance      Parameter  Softplus                   True         ()             float64  0.8919618135336098
# SVGP.kernel.lengthscales  Parameter  Softplus                   True         (7,)           float64  [2.22932181, 1.24348605, 2.29467315...
# SVGP.likelihood.variance  Parameter  Softplus + Shift           True         ()             float64  0.017310406750915466
# SVGP.inducing_variable.Z  Parameter  Identity                   True         (232, 7)       float64  [[0.91345744, 0.2804352, 1.02839355...
# SVGP.q_mu                 Parameter  Identity                   False        (232, 1)       float64  [[1.00305974e+00...
# SVGP.q_sqrt               Parameter  FillTriangular             False        (1, 232, 232)  float64  [[[6.36774546e-01, 0.00000000e+00, 0.00000000e+00...

# %%
m = [e for e in results if e.model == '$f(t, S(t)^p, I(t)^p)$'][0].model_obj
m.kernel.lengthscales.numpy()
# Out:
# array([2.22932181, 1.24348605, 2.29467315, 2.559082  , 2.58975978,
#        2.14449265, 4.22786653])

# %% [markdown]
# ### **$\lambda (t) = f(t, I(t), Home(t))$** - Gaussian - Matern32

# %%
t = final_data[["Updated"]]
y = final_data[["ConfirmedChange"]]
X = pd.DataFrame({
    "index": final_data["index"],
    "I": final_data["I"],
    "HOME": final_data["HOME"]
}, index=final_data.index)[[
    "index",
    "I",
    "HOME"
]]

model_params = {
    'kernel': gpflow.kernels.Matern32(lengthscales=np.ones(X.shape[1]))
}

res, model = run_experiment('$f(t, I(t), Home(t))$', t, X, y, model_params=model_params, plot=True)
results.add(res)

# %%
model._model
# Out:
# <gpflow.models.svgp.SVGP object at 0x146438e50>
# name                      class      transform         prior    trainable    shape          dtype    value
# ------------------------  ---------  ----------------  -------  -----------  -------------  -------  ----------------------------------------------------
# SVGP.kernel.variance      Parameter  Softplus                   True         ()             float64  1.0011072647272163
# SVGP.kernel.lengthscales  Parameter  Softplus                   True         (3,)           float64  [0.50188406 0.91678742 3.99902606]
# SVGP.likelihood.variance  Parameter  Softplus + Shift           True         ()             float64  0.037941168708565925
# SVGP.inducing_variable.Z  Parameter  Identity                   True         (232, 3)       float64  [[1.25952223e+00, 2.06069778e+00, 6.78220127e-02...
# SVGP.q_mu                 Parameter  Identity                   False        (232, 1)       float64  [[5.37106509e-01...
# SVGP.q_sqrt               Parameter  FillTriangular             False        (1, 232, 232)  float64  [[[7.54766170e-02, 0.00000000e+00, 0.00000000e+00...

# %% [markdown]
# ### **$\lambda (t) = f(t, S(t)*I(t), Home(t))$** - Gaussian - Matern32

# %%
t = final_data[["Updated"]]
y = final_data[["ConfirmedChange"]]
X = pd.DataFrame({
    "index": final_data["index"],
    "S*I": final_data["S"] * final_data["I"],
    "HOME": final_data["HOME"],
}, index=final_data.index)[[
    "index",
    "S*I",
    "HOME"
]]

model_params = {
    'kernel': gpflow.kernels.Matern32(lengthscales=np.ones(X.shape[1]))
}

res, model = run_experiment('$f(t, S(t)*I(t), Home(t))$', t, X, y, model_params=model_params, plot=True)
results.add(res)

# %%
model._model
# Out:
# <gpflow.models.svgp.SVGP object at 0x146425790>
# name                      class      transform         prior    trainable    shape          dtype    value
# ------------------------  ---------  ----------------  -------  -----------  -------------  -------  ----------------------------------------------------
# SVGP.kernel.variance      Parameter  Softplus                   True         ()             float64  1.3855617196620336
# SVGP.kernel.lengthscales  Parameter  Softplus                   True         (3,)           float64  [1.23242202 0.96880673 3.7943233 ]
# SVGP.likelihood.variance  Parameter  Softplus + Shift           True         ()             float64  0.029030984556755908
# SVGP.inducing_variable.Z  Parameter  Identity                   True         (232, 3)       float64  [[1.06992509e+00, 1.12921896e+00, -7.05086964e-01...
# SVGP.q_mu                 Parameter  Identity                   False        (232, 1)       float64  [[2.49903642e+00...
# SVGP.q_sqrt               Parameter  FillTriangular             False        (1, 232, 232)  float64  [[[9.76861278e-02, 0.00000000e+00, 0.00000000e+00...

# %% [markdown]
# ### **$\lambda (t) = f(t, S(t)*I(t), Home(t)*Work(t)*Recreational(t))$** - Gaussian - Matern32

# %%
t = final_data[["Updated"]]
y = final_data[["ConfirmedChange"]]
X = pd.DataFrame({
    "index": final_data["index"],
    "S*I": final_data["S"] * final_data["I"],
    "HOME*WORK*RECREATIONAL": final_data["HOME"]*final_data["WORK"]*final_data["RECREATIONAL"],
}, index=final_data.index)[[
    "index",
    "S*I",
    "HOME*WORK*RECREATIONAL"
]]

model_params = {
    'kernel': gpflow.kernels.Matern32(lengthscales=np.ones(X.shape[1]))
}

res, model = run_experiment('$f(t, S(t)*I(t), Home(t)*Work(t)*Recreational(t))$', t, X, y, model_params=model_params, plot=True)
results.add(res)

# %%
model._model
# Out:
# <gpflow.models.svgp.SVGP object at 0x14600b4f0>
# name                      class      transform         prior    trainable    shape          dtype    value
# ------------------------  ---------  ----------------  -------  -----------  -------------  -------  ----------------------------------------------------
# SVGP.kernel.variance      Parameter  Softplus                   True         ()             float64  1.408573462301106
# SVGP.kernel.lengthscales  Parameter  Softplus                   True         (3,)           float64  [1.27097689 1.06847801 2.99491733]
# SVGP.likelihood.variance  Parameter  Softplus + Shift           True         ()             float64  0.026857831025455765
# SVGP.inducing_variable.Z  Parameter  Identity                   True         (232, 3)       float64  [[6.57011230e-01, 6.32607525e-01, -2.29314859e-01...
# SVGP.q_mu                 Parameter  Identity                   False        (232, 1)       float64  [[2.35145552e-01...
# SVGP.q_sqrt               Parameter  FillTriangular             False        (1, 232, 232)  float64  [[[4.38099805e-02, 0.00000000e+00, 0.00000000e+00...

# %% [markdown]
# ### **$\lambda (t) = f(t, S(t), I(t), Home(t), Work(t), Recreational(t))$** - Gaussian - Matern32

# %%
t = final_data[["Updated"]]
y = final_data[["ConfirmedChange"]]
X = pd.DataFrame({
    "index": final_data["index"],
    "S": final_data["S"],
    "I": final_data["I"],
    "HOME": final_data["HOME"],
    "WORK": final_data["WORK"],
    "RECREATIONAL": final_data["RECREATIONAL"],
}, index=final_data.index)[[
    "index",
    "S",
    "I",
    "HOME", 
    "WORK", 
    "RECREATIONAL"
]]

model_params = {
    'kernel': gpflow.kernels.Matern32(lengthscales=np.ones(X.shape[1]))
}

res, model = run_experiment('$f(t, S(t)*I(t), Home(t), Work(t), Recreational(t))$', t, X, y, model_params=model_params, plot=True)
results.add(res)

# %%
model._model
# Out:
# <gpflow.models.svgp.SVGP object at 0x146016af0>
# name                      class      transform         prior    trainable    shape          dtype    value
# ------------------------  ---------  ----------------  -------  -----------  -------------  -------  ----------------------------------------------------
# SVGP.kernel.variance      Parameter  Softplus                   True         ()             float64  0.38685404469123075
# SVGP.kernel.lengthscales  Parameter  Softplus                   True         (6,)           float64  [1.90698183, 1.1175424, 2.01796795...
# SVGP.likelihood.variance  Parameter  Softplus + Shift           True         ()             float64  0.025275979955675903
# SVGP.inducing_variable.Z  Parameter  Identity                   True         (232, 6)       float64  [[-0.39326439, 0.39597299, -0.00601241...
# SVGP.q_mu                 Parameter  Identity                   False        (232, 1)       float64  [[8.09552409e-01...
# SVGP.q_sqrt               Parameter  FillTriangular             False        (1, 232, 232)  float64  [[[8.17139415e-02, 0.00000000e+00, 0.00000000e+00...

# %% [markdown]
# ### **$\lambda (t) = f(t, S(t)^p, I(t)^p, Home(t)^p, Work(t)^p, Recreational(t)^p)$** - Gaussian - Matern32

# %%
t = final_data[["Updated"]]
y = final_data[["ConfirmedChange"]]
X = pd.DataFrame({
    "index": final_data["index"],
    "S": final_data["S"],
    "S**2": final_data["S"]**2,
    "S**3": final_data["S"]**3,
    "I": final_data["I"],
    "I**2": final_data["I"]**2,
    "I**3": final_data["I"]**3,
    "HOME": final_data["HOME"],
    "HOME**2": final_data["HOME"]**2,
    "HOME**3": final_data["HOME"]**3,
    "WORK": final_data["WORK"],
    "WORK**2": final_data["WORK"]**2,
    "WORK**3": final_data["WORK"]**3,
    "RECREATIONAL": final_data["RECREATIONAL"],
    "RECREATIONAL**2": final_data["RECREATIONAL"]**2,
    "RECREATIONAL**3": final_data["RECREATIONAL"]**3,
}, index=final_data.index)[[
    "index",
    "S","S**2","S**3",
    "I","I**2","I**3",
    "HOME","HOME**2","HOME**3",
    "WORK","WORK**2","WORK**3",
    "RECREATIONAL","RECREATIONAL**2","RECREATIONAL**3",
]]

model_params = {
    'kernel': gpflow.kernels.Matern32(lengthscales=np.ones(X.shape[1]))
}

res, model = run_experiment('$f(t, S(t)^p, I(t)^p, Home(t)^p, Work(t)^p, Recreational(t)^p)$', t, X, y, model_params=model_params, plot=True)
results.add(res)

# %%
model._model
# Out:
# <gpflow.models.svgp.SVGP object at 0x1463d7ee0>
# name                      class      transform         prior    trainable    shape          dtype    value
# ------------------------  ---------  ----------------  -------  -----------  -------------  -------  ----------------------------------------------------
# SVGP.kernel.variance      Parameter  Softplus                   True         ()             float64  0.5303377714575803
# SVGP.kernel.lengthscales  Parameter  Softplus                   True         (16,)          float64  [2.86822825, 2.27636551, 2.81102783...
# SVGP.likelihood.variance  Parameter  Softplus + Shift           True         ()             float64  0.05772552634517336
# SVGP.inducing_variable.Z  Parameter  Identity                   True         (232, 16)      float64  [[0.88364572, 0.24215084, 1.06520321...
# SVGP.q_mu                 Parameter  Identity                   False        (232, 1)       float64  [[1.94059601e+00...
# SVGP.q_sqrt               Parameter  FillTriangular             False        (1, 232, 232)  float64  [[[7.48333233e-01, 0.00000000e+00, 0.00000000e+00...

# %% [markdown]
# ### **$\lambda (t) = f(t)$** - Gaussian - SE\*L\*RQ

# %%
t = final_data[["Updated"]]
y = final_data[["ConfirmedChange"]]
X = final_data[["index"]]

model_params = {
    'kernel': (
        gpflow.kernels.SquaredExponential() *
        gpflow.kernels.Linear() * 
        gpflow.kernels.RationalQuadratic()
    )
}

res, model = run_experiment('$f(t)$', t, X, y, model_params=model_params, plot=True)
results.add(res)

# %%
model._model
# Out:
# <gpflow.models.svgp.SVGP object at 0x14600b820>
# name                                 class      transform         prior    trainable    shape          dtype    value
# -----------------------------------  ---------  ----------------  -------  -----------  -------------  -------  ----------------------------------------------------
# SVGP.kernel.kernels[0].variance      Parameter  Softplus                   True         ()             float64  0.9531589436939619
# SVGP.kernel.kernels[0].lengthscales  Parameter  Softplus                   True         ()             float64  4.799224003853854
# SVGP.kernel.kernels[1].variance      Parameter  Softplus                   True         ()             float64  0.9531589436939624
# SVGP.kernel.kernels[2].variance      Parameter  Softplus                   True         ()             float64  0.9531589436939619
# SVGP.kernel.kernels[2].lengthscales  Parameter  Softplus                   True         ()             float64  1.4730875893486992
# SVGP.kernel.kernels[2].alpha         Parameter  Softplus                   True         ()             float64  0.18147923491945142
# SVGP.likelihood.variance             Parameter  Softplus + Shift           True         ()             float64  0.6645196830703509
# SVGP.inducing_variable.Z             Parameter  Identity                   True         (232, 1)       float64  [[0.73713845...
# SVGP.q_mu                            Parameter  Identity                   False        (232, 1)       float64  [[-5.64069959e-02...
# SVGP.q_sqrt                          Parameter  FillTriangular             False        (1, 232, 232)  float64  [[[6.25624545e-02, 0.00000000e+00, 0.00000000e+00...

# %% [markdown]
# ### **$\lambda (t) = f(S(t), I(t))$** - Gaussian - SE\*L\*RQ

# %%
t = final_data[["Updated"]]
y = final_data[["ConfirmedChange"]]
X = final_data[["S", "I"]]

model_params = {
    'kernel': (
        gpflow.kernels.SquaredExponential(lengthscales=np.ones(X.shape[1])) *
        gpflow.kernels.Linear() * 
        gpflow.kernels.RationalQuadratic(lengthscales=np.ones(X.shape[1]))
    )
}

res, model = run_experiment('$f(S(t), I(t))$', t, X, y, model_params=model_params, plot=True)
results.add(res)

# %%
model._model
# Out:
# <gpflow.models.svgp.SVGP object at 0x1477f8070>
# name                                 class      transform         prior    trainable    shape          dtype    value
# -----------------------------------  ---------  ----------------  -------  -----------  -------------  -------  ----------------------------------------------------
# SVGP.kernel.kernels[0].variance      Parameter  Softplus                   True         ()             float64  1.5818520462951275
# SVGP.kernel.kernels[0].lengthscales  Parameter  Softplus                   True         (2,)           float64  [1.22716444 1.21254081]
# SVGP.kernel.kernels[1].variance      Parameter  Softplus                   True         ()             float64  1.5818520462931491
# SVGP.kernel.kernels[2].variance      Parameter  Softplus                   True         ()             float64  1.581852046294636
# SVGP.kernel.kernels[2].lengthscales  Parameter  Softplus                   True         (2,)           float64  [0.10992113 2.77399245]
# SVGP.kernel.kernels[2].alpha         Parameter  Softplus                   True         ()             float64  2.2142497558630683
# SVGP.likelihood.variance             Parameter  Softplus + Shift           True         ()             float64  0.004724284058540032
# SVGP.inducing_variable.Z             Parameter  Identity                   True         (232, 2)       float64  [[-8.31129807e-01, 2.02260473e+00...
# SVGP.q_mu                            Parameter  Identity                   False        (232, 1)       float64  [[-3.63303830e-01...
# SVGP.q_sqrt                          Parameter  FillTriangular             False        (1, 232, 232)  float64  [[[9.94144492e-01, 0.00000000e+00, 0.00000000e+00...

# %% [markdown]
# ### **$\lambda (t) = f(S(t)*I(t))$** - Gaussian - SE\*L\*RQ

# %%
t = final_data[["Updated"]]
y = final_data[["ConfirmedChange"]]
X = pd.DataFrame({
    "S*I": final_data["S"] * final_data["I"]
}, index=final_data.index)[["S*I"]]

model_params = {
    'kernel': (
        gpflow.kernels.SquaredExponential() *
        gpflow.kernels.Linear() * 
        gpflow.kernels.RationalQuadratic()
    )
}

res, model = run_experiment('$f(S(t)*I(t))$', t, X, y, model_params=model_params, plot=True)
results.add(res)

# %%
model._model
# Out:
# <gpflow.models.svgp.SVGP object at 0x1477f36d0>
# name                                 class      transform         prior    trainable    shape          dtype    value
# -----------------------------------  ---------  ----------------  -------  -----------  -------------  -------  ----------------------------------------------------
# SVGP.kernel.kernels[0].variance      Parameter  Softplus                   True         ()             float64  0.5075795326106972
# SVGP.kernel.kernels[0].lengthscales  Parameter  Softplus                   True         ()             float64  2.300608366140311
# SVGP.kernel.kernels[1].variance      Parameter  Softplus                   True         ()             float64  0.5075795326098215
# SVGP.kernel.kernels[2].variance      Parameter  Softplus                   True         ()             float64  0.5075795326110256
# SVGP.kernel.kernels[2].lengthscales  Parameter  Softplus                   True         ()             float64  2.697236183996195
# SVGP.kernel.kernels[2].alpha         Parameter  Softplus                   True         ()             float64  2.546259961455666
# SVGP.likelihood.variance             Parameter  Softplus + Shift           True         ()             float64  0.056999684967808745
# SVGP.inducing_variable.Z             Parameter  Identity                   True         (232, 1)       float64  [[-0.23343903...
# SVGP.q_mu                            Parameter  Identity                   False        (232, 1)       float64  [[-3.28698524e+00...
# SVGP.q_sqrt                          Parameter  FillTriangular             False        (1, 232, 232)  float64  [[[5.29747501e-02, 0.00000000e+00, 0.00000000e+00...

# %% [markdown]
# ### **$\lambda (t) = f(S(t)+I(t))$** - Gaussian - SE\*L\*RQ

# %%
t = final_data[["Updated"]]
y = final_data[["ConfirmedChange"]]
X = pd.DataFrame({
    "S+I": final_data["S"] + final_data["I"]
}, index=final_data.index)[[
    "S+I"
]]

model_params = {
    'kernel': (
        gpflow.kernels.SquaredExponential() *
        gpflow.kernels.Linear() * 
        gpflow.kernels.RationalQuadratic()
    )
}

res, model = run_experiment('$f(S(t)+I(t))$', t, X, y, model_params=model_params, plot=True)
results.add(res)

# %%
model._model
# Out:
# <gpflow.models.svgp.SVGP object at 0x146461460>
# name                                 class      transform         prior    trainable    shape          dtype    value
# -----------------------------------  ---------  ----------------  -------  -----------  -------------  -------  ----------------------------------------------------
# SVGP.kernel.kernels[0].variance      Parameter  Softplus                   True         ()             float64  0.9562706827475783
# SVGP.kernel.kernels[0].lengthscales  Parameter  Softplus                   True         ()             float64  5.860240638221555
# SVGP.kernel.kernels[1].variance      Parameter  Softplus                   True         ()             float64  0.9562706827475778
# SVGP.kernel.kernels[2].variance      Parameter  Softplus                   True         ()             float64  0.9562706827475776
# SVGP.kernel.kernels[2].lengthscales  Parameter  Softplus                   True         ()             float64  2.4815184397789456
# SVGP.kernel.kernels[2].alpha         Parameter  Softplus                   True         ()             float64  0.043737004595366294
# SVGP.likelihood.variance             Parameter  Softplus + Shift           True         ()             float64  0.6059263951252131
# SVGP.inducing_variable.Z             Parameter  Identity                   True         (232, 1)       float64  [[-0.76096466...
# SVGP.q_mu                            Parameter  Identity                   False        (232, 1)       float64  [[-6.21462011e-01...
# SVGP.q_sqrt                          Parameter  FillTriangular             False        (1, 232, 232)  float64  [[[4.79484513e-02, 0.00000000e+00, 0.00000000e+00...

# %% [markdown]
# ### **$\lambda (t) = f(t, S(t)*I(t))$** - Gaussian - SE\*L\*RQ

# %%
t = final_data[["Updated"]]
y = final_data[["ConfirmedChange"]]
X = pd.DataFrame({
    "index": final_data["index"],
    "S*I": final_data["S"] * final_data["I"]
}, index=final_data.index)[[
    "index",
    "S*I"
]]

model_params = {
    'kernel': (
        gpflow.kernels.SquaredExponential(lengthscales=np.ones(X.shape[1])) *
        gpflow.kernels.Linear() * 
        gpflow.kernels.RationalQuadratic(lengthscales=np.ones(X.shape[1]))
    )
}

res, model = run_experiment('$f(t, S(t)*I(t))$', t, X, y, model_params=model_params, plot=True)
results.add(res)

# %%
model._model
# Out:
# <gpflow.models.svgp.SVGP object at 0x1460247f0>
# name                                 class      transform         prior    trainable    shape          dtype    value
# -----------------------------------  ---------  ----------------  -------  -----------  -------------  -------  ----------------------------------------------------
# SVGP.kernel.kernels[0].variance      Parameter  Softplus                   True         ()             float64  0.8245135145863577
# SVGP.kernel.kernels[0].lengthscales  Parameter  Softplus                   True         (2,)           float64  [0.28953574 0.91665518]
# SVGP.kernel.kernels[1].variance      Parameter  Softplus                   True         ()             float64  0.8245135145863677
# SVGP.kernel.kernels[2].variance      Parameter  Softplus                   True         ()             float64  0.8245135145864139
# SVGP.kernel.kernels[2].lengthscales  Parameter  Softplus                   True         (2,)           float64  [2.65015155 0.18048227]
# SVGP.kernel.kernels[2].alpha         Parameter  Softplus                   True         ()             float64  0.0016535019229841478
# SVGP.likelihood.variance             Parameter  Softplus + Shift           True         ()             float64  0.027999189258635086
# SVGP.inducing_variable.Z             Parameter  Identity                   True         (232, 2)       float64  [[9.13906946e-01, 7.69167756e-01...
# SVGP.q_mu                            Parameter  Identity                   False        (232, 1)       float64  [[1.31048203e+00...
# SVGP.q_sqrt                          Parameter  FillTriangular             False        (1, 232, 232)  float64  [[[8.83952635e-02, 0.00000000e+00, 0.00000000e+00...

# %% [markdown]
# ### **$\lambda (t) = f(t, S(t)+I(t))$** - Gaussian - SE\*L\*RQ

# %%
t = final_data[["Updated"]]
y = final_data[["ConfirmedChange"]]
X = pd.DataFrame({
    "index": final_data["index"],
    "S+I": final_data["S"] + final_data["I"]
}, index=final_data.index)[[
    "index",
    "S+I"
]]

model_params = {
    'kernel': (
        gpflow.kernels.SquaredExponential(lengthscales=np.ones(X.shape[1])) *
        gpflow.kernels.Linear() * 
        gpflow.kernels.RationalQuadratic(lengthscales=np.ones(X.shape[1]))
    )
}

res, model = run_experiment('$f(t, S(t)+I(t))$', t, X, y, model_params=model_params, plot=True)
results.add(res)

# %%
model._model
# Out:
# <gpflow.models.svgp.SVGP object at 0x146365af0>
# name                                 class      transform         prior    trainable    shape          dtype    value
# -----------------------------------  ---------  ----------------  -------  -----------  -------------  -------  ----------------------------------------------------
# SVGP.kernel.kernels[0].variance      Parameter  Softplus                   True         ()             float64  0.980149341560123
# SVGP.kernel.kernels[0].lengthscales  Parameter  Softplus                   True         (2,)           float64  [1.5174541  0.27046237]
# SVGP.kernel.kernels[1].variance      Parameter  Softplus                   True         ()             float64  0.9801493415600997
# SVGP.kernel.kernels[2].variance      Parameter  Softplus                   True         ()             float64  0.9801493415601191
# SVGP.kernel.kernels[2].lengthscales  Parameter  Softplus                   True         (2,)           float64  [1.09751807 0.14883106]
# SVGP.kernel.kernels[2].alpha         Parameter  Softplus                   True         ()             float64  0.2374227885874047
# SVGP.likelihood.variance             Parameter  Softplus + Shift           True         ()             float64  0.007643088709871573
# SVGP.inducing_variable.Z             Parameter  Identity                   True         (232, 2)       float64  [[8.63867411e-01, -9.49449987e-02...
# SVGP.q_mu                            Parameter  Identity                   False        (232, 1)       float64  [[1.04643341e+00...
# SVGP.q_sqrt                          Parameter  FillTriangular             False        (1, 232, 232)  float64  [[[2.66794758e-02, 0.00000000e+00, 0.00000000e+00...

# %% [markdown]
# ### **$\lambda (t) = f(t, S(t), I(t))$** - Gaussian - SE\*L\*RQ

# %%
t = final_data[["Updated"]]
y = final_data[["ConfirmedChange"]]
X = pd.DataFrame({
    "index": final_data["index"],
    "S": final_data["S"],
    "I": final_data["I"]
}, index=final_data.index)[[
    "index",
    "S",
    "I"
]]

model_params = {
    'kernel': (
        gpflow.kernels.SquaredExponential(lengthscales=np.ones(X.shape[1])) *
        gpflow.kernels.Linear() * 
        gpflow.kernels.RationalQuadratic(lengthscales=np.ones(X.shape[1]))
    )
}

res, model = run_experiment('$f(t, S(t), I(t))$', t, X, y, model_params=model_params, plot=True)
results.add(res)

# %%
model._model
# Out:
# <gpflow.models.svgp.SVGP object at 0x146389d30>
# name                                 class      transform         prior    trainable    shape          dtype    value
# -----------------------------------  ---------  ----------------  -------  -----------  -------------  -------  ----------------------------------------------------
# SVGP.kernel.kernels[0].variance      Parameter  Softplus                   True         ()             float64  0.625890590062564
# SVGP.kernel.kernels[0].lengthscales  Parameter  Softplus                   True         (3,)           float64  [1.43876616 1.414964   1.76948496]
# SVGP.kernel.kernels[1].variance      Parameter  Softplus                   True         ()             float64  0.625890590062558
# SVGP.kernel.kernels[2].variance      Parameter  Softplus                   True         ()             float64  0.625890590062564
# SVGP.kernel.kernels[2].lengthscales  Parameter  Softplus                   True         (3,)           float64  [1.48745781 0.87935611 2.01721056]
# SVGP.kernel.kernels[2].alpha         Parameter  Softplus                   True         ()             float64  0.4821656942088098
# SVGP.likelihood.variance             Parameter  Softplus + Shift           True         ()             float64  0.01409772744809231
# SVGP.inducing_variable.Z             Parameter  Identity                   True         (232, 3)       float64  [[1.16999630e+00, 2.18665154e-01, 9.37136871e-01...
# SVGP.q_mu                            Parameter  Identity                   False        (232, 1)       float64  [[1.22142190e+00...
# SVGP.q_sqrt                          Parameter  FillTriangular             False        (1, 232, 232)  float64  [[[3.97133643e-02, 0.00000000e+00, 0.00000000e+00...

# %% [markdown]
# ### **$\lambda (t) = f(t, S(t)^p, I(t)^p)$** - Gaussian - SE\*L\*RQ

# %%
t = final_data[["Updated"]]
y = final_data[["ConfirmedChange"]]
X = pd.DataFrame({
    "index": final_data["index"],
    "S": final_data["S"],
    "S**2": final_data["S"]**2,
    "S**3": final_data["S"]**3,
    "I": final_data["I"],
    "I**2": final_data["I"]**2,
    "I**3": final_data["I"]**3
}, index=final_data.index)[[
    "index",
    "S", "S**2", "S**3",
    "I", "I**2", "I**3"
]]

model_params = {
    'kernel': (
        gpflow.kernels.SquaredExponential(lengthscales=np.ones(X.shape[1])) *
        gpflow.kernels.Linear() * 
        gpflow.kernels.RationalQuadratic(lengthscales=np.ones(X.shape[1]))
    )
}

res, model = run_experiment('$f(t, S(t)^p, I(t)^p)$', t, X, y, model_params=model_params, plot=True)
results.add(res)

# %%
model._model
# Out:
# <gpflow.models.svgp.SVGP object at 0x145fb5b80>
# name                                 class      transform         prior    trainable    shape          dtype    value
# -----------------------------------  ---------  ----------------  -------  -----------  -------------  -------  ----------------------------------------------------
# SVGP.kernel.kernels[0].variance      Parameter  Softplus                   True         ()             float64  0.44006579227755516
# SVGP.kernel.kernels[0].lengthscales  Parameter  Softplus                   True         (7,)           float64  [1.50130013, 2.00456796, 2.3957286...
# SVGP.kernel.kernels[1].variance      Parameter  Softplus                   True         ()             float64  0.4400657922775549
# SVGP.kernel.kernels[2].variance      Parameter  Softplus                   True         ()             float64  0.44006579227755516
# SVGP.kernel.kernels[2].lengthscales  Parameter  Softplus                   True         (7,)           float64  [1.75004641, 0.78404272, 2.23524422...
# SVGP.kernel.kernels[2].alpha         Parameter  Softplus                   True         ()             float64  0.034251412226188285
# SVGP.likelihood.variance             Parameter  Softplus + Shift           True         ()             float64  0.03941304719446808
# SVGP.inducing_variable.Z             Parameter  Identity                   True         (232, 7)       float64  [[1.15358993, 0.96609789, 0.62787067...
# SVGP.q_mu                            Parameter  Identity                   False        (232, 1)       float64  [[3.55892680e+00...
# SVGP.q_sqrt                          Parameter  FillTriangular             False        (1, 232, 232)  float64  [[[2.91319213e-01, 0.00000000e+00, 0.00000000e+00...

# %% [markdown]
# ### **$\lambda (t) = f(t, I(t), Home(t))$** - Gaussian - SE\*L\*RQ

# %%
t = final_data[["Updated"]]
y = final_data[["ConfirmedChange"]]
X = pd.DataFrame({
    "index": final_data["index"],
    "I": final_data["I"],
    "HOME": final_data["HOME"]
}, index=final_data.index)[[
    "index",
    "I",
    "HOME"
]]

model_params = {
    'kernel': (
        gpflow.kernels.SquaredExponential(lengthscales=np.ones(X.shape[1])) *
        gpflow.kernels.Linear() * 
        gpflow.kernels.RationalQuadratic(lengthscales=np.ones(X.shape[1]))
    )
}

res, model = run_experiment('$f(t, I(t), Home(t))$', t, X, y, model_params=model_params, plot=True)
results.add(res)

# %%
model._model
# Out:
# <gpflow.models.svgp.SVGP object at 0x145f7c4f0>
# name                                 class      transform         prior    trainable    shape          dtype    value
# -----------------------------------  ---------  ----------------  -------  -----------  -------------  -------  ----------------------------------------------------
# SVGP.kernel.kernels[0].variance      Parameter  Softplus                   True         ()             float64  0.757781214233407
# SVGP.kernel.kernels[0].lengthscales  Parameter  Softplus                   True         (3,)           float64  [1.20844889 1.66148515 1.90034901]
# SVGP.kernel.kernels[1].variance      Parameter  Softplus                   True         ()             float64  0.7577812142333883
# SVGP.kernel.kernels[2].variance      Parameter  Softplus                   True         ()             float64  0.7577812142334124
# SVGP.kernel.kernels[2].lengthscales  Parameter  Softplus                   True         (3,)           float64  [0.73434051 1.23014446 2.32148926]
# SVGP.kernel.kernels[2].alpha         Parameter  Softplus                   True         ()             float64  0.08189736353873701
# SVGP.likelihood.variance             Parameter  Softplus + Shift           True         ()             float64  0.05414414835922121
# SVGP.inducing_variable.Z             Parameter  Identity                   True         (232, 3)       float64  [[1.16382364e+00, 2.18198653e+00, -3.96609660e-02...
# SVGP.q_mu                            Parameter  Identity                   False        (232, 1)       float64  [[1.55812569e+00...
# SVGP.q_sqrt                          Parameter  FillTriangular             False        (1, 232, 232)  float64  [[[7.19556475e-02, 0.00000000e+00, 0.00000000e+00...

# %% [markdown]
# ### **$\lambda (t) = f(t, S(t)*I(t), Home(t))$** - Gaussian - SE\*L\*RQ

# %%
t = final_data[["Updated"]]
y = final_data[["ConfirmedChange"]]
X = pd.DataFrame({
    "index": final_data["index"],
    "S*I": final_data["S"] * final_data["I"],
    "HOME": final_data["HOME"],
}, index=final_data.index)[[
    "index",
    "S*I",
    "HOME"
]]

model_params = {
    'kernel': (
        gpflow.kernels.SquaredExponential(lengthscales=np.ones(X.shape[1])) *
        gpflow.kernels.Linear() * 
        gpflow.kernels.RationalQuadratic(lengthscales=np.ones(X.shape[1]))
    )
}

res, model = run_experiment('$f(t, S(t)*I(t), Home(t))$', t, X, y, model_params=model_params, plot=True)
results.add(res)

# %%
model._model
# Out:
# <gpflow.models.svgp.SVGP object at 0x146438fd0>
# name                                 class      transform         prior    trainable    shape          dtype    value
# -----------------------------------  ---------  ----------------  -------  -----------  -------------  -------  ----------------------------------------------------
# SVGP.kernel.kernels[0].variance      Parameter  Softplus                   True         ()             float64  0.5952509552310287
# SVGP.kernel.kernels[0].lengthscales  Parameter  Softplus                   True         (3,)           float64  [1.25506412 2.07484084 2.54810819]
# SVGP.kernel.kernels[1].variance      Parameter  Softplus                   True         ()             float64  0.5952509552310244
# SVGP.kernel.kernels[2].variance      Parameter  Softplus                   True         ()             float64  0.5952509552310287
# SVGP.kernel.kernels[2].lengthscales  Parameter  Softplus                   True         (3,)           float64  [1.38814612 0.93072599 2.8285908 ]
# SVGP.kernel.kernels[2].alpha         Parameter  Softplus                   True         ()             float64  0.057621483826472274
# SVGP.likelihood.variance             Parameter  Softplus + Shift           True         ()             float64  0.057790337000325556
# SVGP.inducing_variable.Z             Parameter  Identity                   True         (232, 3)       float64  [[1.07087514e+00, 1.10428670e+00, -6.58752233e-01...
# SVGP.q_mu                            Parameter  Identity                   False        (232, 1)       float64  [[3.17119321e+00...
# SVGP.q_sqrt                          Parameter  FillTriangular             False        (1, 232, 232)  float64  [[[1.62187164e-01, 0.00000000e+00, 0.00000000e+00...

# %% [markdown]
# ### **$\lambda (t) = f(t, S(t)*I(t), Home(t)*Work(t)*Recreational(t))$** - Gaussian - SE\*L\*RQ

# %%
t = final_data[["Updated"]]
y = final_data[["ConfirmedChange"]]
X = pd.DataFrame({
    "index": final_data["index"],
    "S*I": final_data["S"] * final_data["I"],
    "HOME*WORK*RECREATIONAL": final_data["HOME"]*final_data["WORK"]*final_data["RECREATIONAL"],
}, index=final_data.index)[[
    "index",
    "S*I",
    "HOME*WORK*RECREATIONAL"
]]

model_params = {
    'kernel': (
        gpflow.kernels.SquaredExponential(lengthscales=np.ones(X.shape[1])) *
        gpflow.kernels.Linear() * 
        gpflow.kernels.RationalQuadratic(lengthscales=np.ones(X.shape[1]))
    )
}

res, model = run_experiment('$f(t, S(t)*I(t), Home(t)*Work(t)*Recreational(t)$', t, X, y, model_params=model_params, plot=True)
results.add(res)

# %%
model._model
# Out:
# <gpflow.models.svgp.SVGP object at 0x145fb5d60>
# name                                 class      transform         prior    trainable    shape          dtype    value
# -----------------------------------  ---------  ----------------  -------  -----------  -------------  -------  ----------------------------------------------------
# SVGP.kernel.kernels[0].variance      Parameter  Softplus                   True         ()             float64  0.6329203285945911
# SVGP.kernel.kernels[0].lengthscales  Parameter  Softplus                   True         (3,)           float64  [1.39023012 1.92296799 2.47441634]
# SVGP.kernel.kernels[1].variance      Parameter  Softplus                   True         ()             float64  0.6329203285945917
# SVGP.kernel.kernels[2].variance      Parameter  Softplus                   True         ()             float64  0.632920328594592
# SVGP.kernel.kernels[2].lengthscales  Parameter  Softplus                   True         (3,)           float64  [1.18600348 0.9041821  2.71975227]
# SVGP.kernel.kernels[2].alpha         Parameter  Softplus                   True         ()             float64  0.07550372580346516
# SVGP.likelihood.variance             Parameter  Softplus + Shift           True         ()             float64  0.04940093856961988
# SVGP.inducing_variable.Z             Parameter  Identity                   True         (232, 3)       float64  [[6.86177740e-01, 6.35019952e-01, -2.30280277e-01...
# SVGP.q_mu                            Parameter  Identity                   False        (232, 1)       float64  [[9.17404623e-01...
# SVGP.q_sqrt                          Parameter  FillTriangular             False        (1, 232, 232)  float64  [[[1.04231987e-01, 0.00000000e+00, 0.00000000e+00...

# %% [markdown]
# ### **$\lambda (t) = f(t, S(t), I(t), Home(t), Work(t), Recreational(t))$** - Gaussian - SE\*L\*RQ

# %%
t = final_data[["Updated"]]
y = final_data[["ConfirmedChange"]]
X = pd.DataFrame({
    "index": final_data["index"],
    "S": final_data["S"],
    "I": final_data["I"],
    "HOME": final_data["HOME"],
    "WORK": final_data["WORK"],
    "RECREATIONAL": final_data["RECREATIONAL"],
}, index=final_data.index)[[
    "index",
    "S",
    "I",
    "HOME", 
    "WORK", 
    "RECREATIONAL"
]]

model_params = {
    'kernel': (
        gpflow.kernels.SquaredExponential(lengthscales=np.ones(X.shape[1])) *
        gpflow.kernels.Linear() * 
        gpflow.kernels.RationalQuadratic(lengthscales=np.ones(X.shape[1]))
    )
}

res, model = run_experiment('$f(t, S(t), I(t), Home(t), Work(t), Recreational(t)$', t, X, y, model_params=model_params, plot=True)
results.add(res)

# %%
model._model
# Out:
# <gpflow.models.svgp.SVGP object at 0x146432070>
# name                                 class      transform         prior    trainable    shape          dtype    value
# -----------------------------------  ---------  ----------------  -------  -----------  -------------  -------  ----------------------------------------------------
# SVGP.kernel.kernels[0].variance      Parameter  Softplus                   True         ()             float64  0.5311545535894922
# SVGP.kernel.kernels[0].lengthscales  Parameter  Softplus                   True         (6,)           float64  [1.66133916, 1.44415739, 2.12305252...
# SVGP.kernel.kernels[1].variance      Parameter  Softplus                   True         ()             float64  0.5311545535894929
# SVGP.kernel.kernels[2].variance      Parameter  Softplus                   True         ()             float64  0.5311545535894919
# SVGP.kernel.kernels[2].lengthscales  Parameter  Softplus                   True         (6,)           float64  [1.96175967, 1.50149519, 2.80765516...
# SVGP.kernel.kernels[2].alpha         Parameter  Softplus                   True         ()             float64  0.9191197392689366
# SVGP.likelihood.variance             Parameter  Softplus + Shift           True         ()             float64  0.06885165672873865
# SVGP.inducing_variable.Z             Parameter  Identity                   True         (232, 6)       float64  [[0.17376836, 1.26260197, 0.2628505...
# SVGP.q_mu                            Parameter  Identity                   False        (232, 1)       float64  [[8.24637568e-02...
# SVGP.q_sqrt                          Parameter  FillTriangular             False        (1, 232, 232)  float64  [[[1.91398827e-01, 0.00000000e+00, 0.00000000e+00...

# %% [markdown]
# ### **$\lambda (t) = f(t, S(t)^p, I(t)^p, Home(t)^p, Work(t)^p, Recreational(t)^p)$** - Gaussian - SE\*L\*RQ

# %%
t = final_data[["Updated"]]
y = final_data[["ConfirmedChange"]]
X = pd.DataFrame({
    "index": final_data["index"],
    "S": final_data["S"],
    "S**2": final_data["S"]**2,
    "S**3": final_data["S"]**3,
    "I": final_data["I"],
    "I**2": final_data["I"]**2,
    "I**3": final_data["I"]**3,
    "HOME": final_data["HOME"],
    "HOME**2": final_data["HOME"]**2,
    "HOME**3": final_data["HOME"]**3,
    "WORK": final_data["WORK"],
    "WORK**2": final_data["WORK"]**2,
    "WORK**3": final_data["WORK"]**3,
    "RECREATIONAL": final_data["RECREATIONAL"],
    "RECREATIONAL**2": final_data["RECREATIONAL"]**2,
    "RECREATIONAL**3": final_data["RECREATIONAL"]**3,
}, index=final_data.index)[[
    "index",
    "S","S**2","S**3",
    "I","I**2","I**3",
    "HOME","HOME**2","HOME**3",
    "WORK","WORK**2","WORK**3",
    "RECREATIONAL","RECREATIONAL**2","RECREATIONAL**3",
]]

model_params = {
    'kernel': (
        gpflow.kernels.SquaredExponential(lengthscales=np.ones(X.shape[1])) *
        gpflow.kernels.Linear() * 
        gpflow.kernels.RationalQuadratic(lengthscales=np.ones(X.shape[1]))
    )
}

res, model = run_experiment('$f(t, S(t)^p, I(t)^p, Home(t)^p, Work(t)^p, Recreational(t)^p$', t, X, y, model_params=model_params, plot=True)
results.add(res)

# %%
model._model
# Out:
# <gpflow.models.svgp.SVGP object at 0x1462726d0>
# name                                 class      transform         prior    trainable    shape          dtype    value
# -----------------------------------  ---------  ----------------  -------  -----------  -------------  -------  ----------------------------------------------------
# SVGP.kernel.kernels[0].variance      Parameter  Softplus                   True         ()             float64  0.4864250285895578
# SVGP.kernel.kernels[0].lengthscales  Parameter  Softplus                   True         (16,)          float64  [2.66655049, 2.60048408, 3.27130182...
# SVGP.kernel.kernels[1].variance      Parameter  Softplus                   True         ()             float64  0.4864250285895575
# SVGP.kernel.kernels[2].variance      Parameter  Softplus                   True         ()             float64  0.4864250285895579
# SVGP.kernel.kernels[2].lengthscales  Parameter  Softplus                   True         (16,)          float64  [3.37322896, 2.97918122, 3.69772342...
# SVGP.kernel.kernels[2].alpha         Parameter  Softplus                   True         ()             float64  0.4062148569375618
# SVGP.likelihood.variance             Parameter  Softplus + Shift           True         ()             float64  0.14412449022306606
# SVGP.inducing_variable.Z             Parameter  Identity                   True         (232, 16)      float64  [[1.33747305e+00, 9.88441738e-01, 7.19112520e-01...
# SVGP.q_mu                            Parameter  Identity                   False        (232, 1)       float64  [[3.27455506e+00...
# SVGP.q_sqrt                          Parameter  FillTriangular             False        (1, 232, 232)  float64  [[[3.51686760e-01, 0.00000000e+00, 0.00000000e+00...

# %% [markdown]
# ### **$\lambda (t) = f(t)$** - Gaussian - SE\+L\+RQ

# %%
t = final_data[["Updated"]]
y = final_data[["ConfirmedChange"]]
X = final_data[["index"]]

model_params = {
    'kernel': (
        gpflow.kernels.SquaredExponential() +
        gpflow.kernels.Linear() +
        gpflow.kernels.RationalQuadratic()
    )
}

res, model = run_experiment('$f(t)$', t, X, y, model_params=model_params, plot=True)
results.add(res)

# %%
model._model
# Out:
# <gpflow.models.svgp.SVGP object at 0x146432700>
# name                                 class      transform         prior    trainable    shape          dtype    value
# -----------------------------------  ---------  ----------------  -------  -----------  -------------  -------  ----------------------------------------------------
# SVGP.kernel.kernels[0].variance      Parameter  Softplus                   True         ()             float64  0.9557996796689792
# SVGP.kernel.kernels[0].lengthscales  Parameter  Softplus                   True         ()             float64  3.640446456508993
# SVGP.kernel.kernels[1].variance      Parameter  Softplus                   True         ()             float64  0.9549562290885425
# SVGP.kernel.kernels[2].variance      Parameter  Softplus                   True         ()             float64  0.9558172444575572
# SVGP.kernel.kernels[2].lengthscales  Parameter  Softplus                   True         ()             float64  1.833177412921037
# SVGP.kernel.kernels[2].alpha         Parameter  Softplus                   True         ()             float64  0.10787091349805637
# SVGP.likelihood.variance             Parameter  Softplus + Shift           True         ()             float64  0.7998252771290549
# SVGP.inducing_variable.Z             Parameter  Identity                   True         (232, 1)       float64  [[0.69247314...
# SVGP.q_mu                            Parameter  Identity                   False        (232, 1)       float64  [[-2.84798794e-02...
# SVGP.q_sqrt                          Parameter  FillTriangular             False        (1, 232, 232)  float64  [[[2.98964070e-02, 0.00000000e+00, 0.00000000e+00...

# %% [markdown]
# ### **$\lambda (t) = f(S(t), I(t))$** - Gaussian - SE\+L\+RQ

# %%
t = final_data[["Updated"]]
y = final_data[["ConfirmedChange"]]
X = final_data[["S", "I"]]

model_params = {
    'kernel': (
        gpflow.kernels.SquaredExponential(lengthscales=np.ones(X.shape[1])) +
        gpflow.kernels.Linear() +
        gpflow.kernels.RationalQuadratic(lengthscales=np.ones(X.shape[1]))
    )
}

res, model = run_experiment('$f(S(t), I(t))$', t, X, y, model_params=model_params, plot=True)
results.add(res)

# %%
model._model
# Out:
# <gpflow.models.svgp.SVGP object at 0x145e36ca0>
# name                                 class      transform         prior    trainable    shape          dtype    value
# -----------------------------------  ---------  ----------------  -------  -----------  -------------  -------  ----------------------------------------------------
# SVGP.kernel.kernels[0].variance      Parameter  Softplus                   True         ()             float64  1.2541247263394903
# SVGP.kernel.kernels[0].lengthscales  Parameter  Softplus                   True         (2,)           float64  [0.09795495 1.39915143]
# SVGP.kernel.kernels[1].variance      Parameter  Softplus                   True         ()             float64  0.9346279289243663
# SVGP.kernel.kernels[2].variance      Parameter  Softplus                   True         ()             float64  0.6182537934942635
# SVGP.kernel.kernels[2].lengthscales  Parameter  Softplus                   True         (2,)           float64  [0.34542439 1.01730352]
# SVGP.kernel.kernels[2].alpha         Parameter  Softplus                   True         ()             float64  0.00505825661092197
# SVGP.likelihood.variance             Parameter  Softplus + Shift           True         ()             float64  0.0020621974687544324
# SVGP.inducing_variable.Z             Parameter  Identity                   True         (232, 2)       float64  [[-9.35170902e-01, 2.29756445e+00...
# SVGP.q_mu                            Parameter  Identity                   False        (232, 1)       float64  [[6.41603080e-01...
# SVGP.q_sqrt                          Parameter  FillTriangular             False        (1, 232, 232)  float64  [[[4.47690279e-01, 0.00000000e+00, 0.00000000e+00...

# %% [markdown]
# ### **$\lambda (t) = f(S(t)*I(t))$** - Gaussian - SE\+L\+RQ

# %%
t = final_data[["Updated"]]
y = final_data[["ConfirmedChange"]]
X = pd.DataFrame({
    "S*I": final_data["S"] * final_data["I"]
}, index=final_data.index)[["S*I"]]

model_params = {
    'kernel': (
        gpflow.kernels.SquaredExponential() +
        gpflow.kernels.Linear() +
        gpflow.kernels.RationalQuadratic()
    )
}

res, model = run_experiment('$f(S(t)*I(t))$', t, X, y, model_params=model_params, plot=True)
results.add(res)

# %%
model._model
# Out:
# <gpflow.models.svgp.SVGP object at 0x1462b7d00>
# name                                 class      transform         prior    trainable    shape          dtype    value
# -----------------------------------  ---------  ----------------  -------  -----------  -------------  -------  ----------------------------------------------------
# SVGP.kernel.kernels[0].variance      Parameter  Softplus                   True         ()             float64  0.8969877061910674
# SVGP.kernel.kernels[0].lengthscales  Parameter  Softplus                   True         ()             float64  3.029946733602956
# SVGP.kernel.kernels[1].variance      Parameter  Softplus                   True         ()             float64  0.9601133575987948
# SVGP.kernel.kernels[2].variance      Parameter  Softplus                   True         ()             float64  0.9140390342483254
# SVGP.kernel.kernels[2].lengthscales  Parameter  Softplus                   True         ()             float64  1.2470954086916108
# SVGP.kernel.kernels[2].alpha         Parameter  Softplus                   True         ()             float64  0.0072310496607236666
# SVGP.likelihood.variance             Parameter  Softplus + Shift           True         ()             float64  0.02360693155700782
# SVGP.inducing_variable.Z             Parameter  Identity                   True         (232, 1)       float64  [[-0.37951569...
# SVGP.q_mu                            Parameter  Identity                   False        (232, 1)       float64  [[-5.96950666e-01...
# SVGP.q_sqrt                          Parameter  FillTriangular             False        (1, 232, 232)  float64  [[[3.24123731e-02, 0.00000000e+00, 0.00000000e+00...

# %% [markdown]
# ### **$\lambda (t) = f(S(t)+I(t))$** - Gaussian - SE\+L\+RQ

# %%
t = final_data[["Updated"]]
y = final_data[["ConfirmedChange"]]
X = pd.DataFrame({
    "S+I": final_data["S"] + final_data["I"]
}, index=final_data.index)[[
    "S+I"
]]

model_params = {
    'kernel': (
        gpflow.kernels.SquaredExponential() +
        gpflow.kernels.Linear() +
        gpflow.kernels.RationalQuadratic()
    )
}

res, model = run_experiment('$f(S(t)+I(t))$', t, X, y, model_params=model_params, plot=True)
results.add(res)

# %%
model._model
# Out:
# <gpflow.models.svgp.SVGP object at 0x1462f4850>
# name                                 class      transform         prior    trainable    shape          dtype    value
# -----------------------------------  ---------  ----------------  -------  -----------  -------------  -------  ----------------------------------------------------
# SVGP.kernel.kernels[0].variance      Parameter  Softplus                   True         ()             float64  0.9613066819518807
# SVGP.kernel.kernels[0].lengthscales  Parameter  Softplus                   True         ()             float64  3.472225714539088
# SVGP.kernel.kernels[1].variance      Parameter  Softplus                   True         ()             float64  0.961333492430786
# SVGP.kernel.kernels[2].variance      Parameter  Softplus                   True         ()             float64  0.959531738314042
# SVGP.kernel.kernels[2].lengthscales  Parameter  Softplus                   True         ()             float64  0.3288047637181629
# SVGP.kernel.kernels[2].alpha         Parameter  Softplus                   True         ()             float64  0.1941823955111448
# SVGP.likelihood.variance             Parameter  Softplus + Shift           True         ()             float64  0.35625512071198995
# SVGP.inducing_variable.Z             Parameter  Identity                   True         (232, 1)       float64  [[-0.6336921...
# SVGP.q_mu                            Parameter  Identity                   False        (232, 1)       float64  [[-2.59756712e-01...
# SVGP.q_sqrt                          Parameter  FillTriangular             False        (1, 232, 232)  float64  [[[2.51661777e-02, 0.00000000e+00, 0.00000000e+00...

# %% [markdown]
# ### **$\lambda (t) = f(t, S(t)*I(t))$** - Gaussian - SE\+L\+RQ

# %%
t = final_data[["Updated"]]
y = final_data[["ConfirmedChange"]]
X = pd.DataFrame({
    "index": final_data["index"],
    "S*I": final_data["S"] * final_data["I"]
}, index=final_data.index)[[
    "index",
    "S*I"
]]

model_params = {
    'kernel': (
        gpflow.kernels.SquaredExponential(lengthscales=np.ones(X.shape[1])) +
        gpflow.kernels.Linear() +
        gpflow.kernels.RationalQuadratic(lengthscales=np.ones(X.shape[1]))
    )
}

res, model = run_experiment('$f(t, S(t)*I(t))$', t, X, y, model_params=model_params, plot=True)
results.add(res)

# %%
model._model
# Out:
# <gpflow.models.svgp.SVGP object at 0x146411400>
# name                                 class      transform         prior    trainable    shape          dtype    value
# -----------------------------------  ---------  ----------------  -------  -----------  -------------  -------  ----------------------------------------------------
# SVGP.kernel.kernels[0].variance      Parameter  Softplus                   True         ()             float64  0.9681607338006323
# SVGP.kernel.kernels[0].lengthscales  Parameter  Softplus                   True         (2,)           float64  [0.43709745 2.20563597]
# SVGP.kernel.kernels[1].variance      Parameter  Softplus                   True         ()             float64  0.9441548512068347
# SVGP.kernel.kernels[2].variance      Parameter  Softplus                   True         ()             float64  0.6614309051214062
# SVGP.kernel.kernels[2].lengthscales  Parameter  Softplus                   True         (2,)           float64  [0.62584728 0.15204377]
# SVGP.kernel.kernels[2].alpha         Parameter  Softplus                   True         ()             float64  0.029688574964157822
# SVGP.likelihood.variance             Parameter  Softplus + Shift           True         ()             float64  0.011852591562695435
# SVGP.inducing_variable.Z             Parameter  Identity                   True         (232, 2)       float64  [[1.10874324e+00, 7.15315376e-01...
# SVGP.q_mu                            Parameter  Identity                   False        (232, 1)       float64  [[2.37194246e-02...
# SVGP.q_sqrt                          Parameter  FillTriangular             False        (1, 232, 232)  float64  [[[2.36190391e-02, 0.00000000e+00, 0.00000000e+00...

# %% [markdown]
# ### **$\lambda (t) = f(t, S(t)+I(t))$** - Gaussian - SE\+L\+RQ

# %%
t = final_data[["Updated"]]
y = final_data[["ConfirmedChange"]]
X = pd.DataFrame({
    "index": final_data["index"],
    "S+I": final_data["S"] + final_data["I"]
}, index=final_data.index)[[
    "index",
    "S+I"
]]

model_params = {
    'kernel': (
        gpflow.kernels.SquaredExponential(lengthscales=np.ones(X.shape[1])) +
        gpflow.kernels.Linear() +
        gpflow.kernels.RationalQuadratic(lengthscales=np.ones(X.shape[1]))
    )
}

res, model = run_experiment('$f(t, S(t)+I(t))$', t, X, y, model_params=model_params, plot=True)
results.add(res)

# %%
model._model
# Out:
# <gpflow.models.svgp.SVGP object at 0x1463e9a30>
# name                                 class      transform         prior    trainable    shape          dtype    value
# -----------------------------------  ---------  ----------------  -------  -----------  -------------  -------  ----------------------------------------------------
# SVGP.kernel.kernels[0].variance      Parameter  Softplus                   True         ()             float64  0.9649097336341311
# SVGP.kernel.kernels[0].lengthscales  Parameter  Softplus                   True         (2,)           float64  [0.52734706 0.68546287]
# SVGP.kernel.kernels[1].variance      Parameter  Softplus                   True         ()             float64  0.9620979342179415
# SVGP.kernel.kernels[2].variance      Parameter  Softplus                   True         ()             float64  1.0187568112676562
# SVGP.kernel.kernels[2].lengthscales  Parameter  Softplus                   True         (2,)           float64  [0.85530706 0.16188908]
# SVGP.kernel.kernels[2].alpha         Parameter  Softplus                   True         ()             float64  0.21959979354849432
# SVGP.likelihood.variance             Parameter  Softplus + Shift           True         ()             float64  0.009326108323059074
# SVGP.inducing_variable.Z             Parameter  Identity                   True         (232, 2)       float64  [[0.60632213, -0.09428322...
# SVGP.q_mu                            Parameter  Identity                   False        (232, 1)       float64  [[1.03134668e-01...
# SVGP.q_sqrt                          Parameter  FillTriangular             False        (1, 232, 232)  float64  [[[1.80762426e-02, 0.00000000e+00, 0.00000000e+00...

# %% [markdown]
# ### **$\lambda (t) = f(t, S(t), I(t))$** - Gaussian - SE\+L\+RQ

# %%
t = final_data[["Updated"]]
y = final_data[["ConfirmedChange"]]
X = pd.DataFrame({
    "index": final_data["index"],
    "S": final_data["S"],
    "I": final_data["I"]
}, index=final_data.index)[[
    "index",
    "S",
    "I"
]]

model_params = {
    'kernel': (
        gpflow.kernels.SquaredExponential(lengthscales=np.ones(X.shape[1])) +
        gpflow.kernels.Linear() +
        gpflow.kernels.RationalQuadratic(lengthscales=np.ones(X.shape[1]))
    )
}

res, model = run_experiment('$f(t, S(t), I(t))$', t, X, y, model_params=model_params, plot=True)
results.add(res)

# %%
model._model
# Out:
# <gpflow.models.svgp.SVGP object at 0x1463c50d0>
# name                                 class      transform         prior    trainable    shape          dtype    value
# -----------------------------------  ---------  ----------------  -------  -----------  -------------  -------  ----------------------------------------------------
# SVGP.kernel.kernels[0].variance      Parameter  Softplus                   True         ()             float64  0.8819677905938406
# SVGP.kernel.kernels[0].lengthscales  Parameter  Softplus                   True         (3,)           float64  [1.67476641 1.38705511 2.14509909]
# SVGP.kernel.kernels[1].variance      Parameter  Softplus                   True         ()             float64  0.9618349136608272
# SVGP.kernel.kernels[2].variance      Parameter  Softplus                   True         ()             float64  0.8815476474586847
# SVGP.kernel.kernels[2].lengthscales  Parameter  Softplus                   True         (3,)           float64  [1.81443897 0.18801486 2.01140024]
# SVGP.kernel.kernels[2].alpha         Parameter  Softplus                   True         ()             float64  0.13348192413197962
# SVGP.likelihood.variance             Parameter  Softplus + Shift           True         ()             float64  0.008619173551237001
# SVGP.inducing_variable.Z             Parameter  Identity                   True         (232, 3)       float64  [[9.70086562e-01, 2.28077018e-01, 6.45673643e-01...
# SVGP.q_mu                            Parameter  Identity                   False        (232, 1)       float64  [[0.23947744...
# SVGP.q_sqrt                          Parameter  FillTriangular             False        (1, 232, 232)  float64  [[[1.37771186e-02, 0.00000000e+00, 0.00000000e+00...

# %% [markdown]
# ### **$\lambda (t) = f(t, S(t)^p, I(t)^p)$** - Gaussian - SE\+L\+RQ

# %%
t = final_data[["Updated"]]
y = final_data[["ConfirmedChange"]]
X = pd.DataFrame({
    "index": final_data["index"],
    "S": final_data["S"],
    "S**2": final_data["S"]**2,
    "S**3": final_data["S"]**3,
    "I": final_data["I"],
    "I**2": final_data["I"]**2,
    "I**3": final_data["I"]**3
}, index=final_data.index)[[
    "index",
    "S", "S**2", "S**3",
    "I", "I**2", "I**3"
]]

model_params = {
    'kernel': (
        gpflow.kernels.SquaredExponential(lengthscales=np.ones(X.shape[1])) +
        gpflow.kernels.Linear() +
        gpflow.kernels.RationalQuadratic(lengthscales=np.ones(X.shape[1]))
    )
}

res, model = run_experiment('$f(t, S(t)^p, I(t)^p)$', t, X, y, model_params=model_params, plot=True)
results.add(res)

# %%
model._model
# Out:
# <gpflow.models.svgp.SVGP object at 0x146257580>
# name                                 class      transform         prior    trainable    shape          dtype    value
# -----------------------------------  ---------  ----------------  -------  -----------  -------------  -------  ----------------------------------------------------
# SVGP.kernel.kernels[0].variance      Parameter  Softplus                   True         ()             float64  0.31515616726301476
# SVGP.kernel.kernels[0].lengthscales  Parameter  Softplus                   True         (7,)           float64  [2.20012977, 1.39668949, 2.57309907...
# SVGP.kernel.kernels[1].variance      Parameter  Softplus                   True         ()             float64  0.9621448786894321
# SVGP.kernel.kernels[2].variance      Parameter  Softplus                   True         ()             float64  0.4774095668121482
# SVGP.kernel.kernels[2].lengthscales  Parameter  Softplus                   True         (7,)           float64  [2.85752985, 0.1663879, 2.20271408...
# SVGP.kernel.kernels[2].alpha         Parameter  Softplus                   True         ()             float64  0.04155977210972715
# SVGP.likelihood.variance             Parameter  Softplus + Shift           True         ()             float64  0.011217800337146415
# SVGP.inducing_variable.Z             Parameter  Identity                   True         (232, 7)       float64  [[1.26885803, 0.53254754, 0.70806088...
# SVGP.q_mu                            Parameter  Identity                   False        (232, 1)       float64  [[5.02781245e-01...
# SVGP.q_sqrt                          Parameter  FillTriangular             False        (1, 232, 232)  float64  [[[1.84454886e-01, 0.00000000e+00, 0.00000000e+00...

# %% [markdown]
# ### **$\lambda (t) = f(t, I(t), Home(t))$** - Gaussian - SE\+L\+RQ

# %%
t = final_data[["Updated"]]
y = final_data[["ConfirmedChange"]]
X = pd.DataFrame({
    "index": final_data["index"],
    "I": final_data["I"],
    "HOME": final_data["HOME"]
}, index=final_data.index)[[
    "index",
    "I",
    "HOME"
]]

model_params = {
    'kernel': (
        gpflow.kernels.SquaredExponential(lengthscales=np.ones(X.shape[1])) +
        gpflow.kernels.Linear() +
        gpflow.kernels.RationalQuadratic(lengthscales=np.ones(X.shape[1]))
    )
}

res, model = run_experiment('$f(t, I(t), Home(t))$', t, X, y, model_params=model_params, plot=True)
results.add(res)

# %%
model._model
# Out:
# <gpflow.models.svgp.SVGP object at 0x1461c28b0>
# name                                 class      transform         prior    trainable    shape          dtype    value
# -----------------------------------  ---------  ----------------  -------  -----------  -------------  -------  ----------------------------------------------------
# SVGP.kernel.kernels[0].variance      Parameter  Softplus                   True         ()             float64  0.9414626425289765
# SVGP.kernel.kernels[0].lengthscales  Parameter  Softplus                   True         (3,)           float64  [0.22994577 1.47625518 3.76615498]
# SVGP.kernel.kernels[1].variance      Parameter  Softplus                   True         ()             float64  0.9619109820130096
# SVGP.kernel.kernels[2].variance      Parameter  Softplus                   True         ()             float64  0.8101095567449526
# SVGP.kernel.kernels[2].lengthscales  Parameter  Softplus                   True         (3,)           float64  [0.42138991 0.36165181 4.95088523]
# SVGP.kernel.kernels[2].alpha         Parameter  Softplus                   True         ()             float64  0.21299758399455104
# SVGP.likelihood.variance             Parameter  Softplus + Shift           True         ()             float64  0.018388959986160133
# SVGP.inducing_variable.Z             Parameter  Identity                   True         (232, 3)       float64  [[1.44560435e+00, 2.21650640e+00, -6.92997946e-01...
# SVGP.q_mu                            Parameter  Identity                   False        (232, 1)       float64  [[1.10612528e-01...
# SVGP.q_sqrt                          Parameter  FillTriangular             False        (1, 232, 232)  float64  [[[1.73130626e-02, 0.00000000e+00, 0.00000000e+00...

# %% [markdown]
# ### **$\lambda (t) = f(t, S(t)*I(t), Home(t))$** - Gaussian - SE\+L\+RQ

# %%
t = final_data[["Updated"]]
y = final_data[["ConfirmedChange"]]
X = pd.DataFrame({
    "index": final_data["index"],
    "S*I": final_data["S"] * final_data["I"],
    "HOME": final_data["HOME"],
}, index=final_data.index)[[
    "index",
    "S*I",
    "HOME"
]]

model_params = {
    'kernel': (
        gpflow.kernels.SquaredExponential(lengthscales=np.ones(X.shape[1])) +
        gpflow.kernels.Linear() +
        gpflow.kernels.RationalQuadratic(lengthscales=np.ones(X.shape[1]))
    )
}

res, model = run_experiment('$f(t, S(t)*I(t), Home(t))$', t, X, y, model_params=model_params, plot=True)
results.add(res)

# %%
model._model
# Out:
# <gpflow.models.svgp.SVGP object at 0x146161e80>
# name                                 class      transform         prior    trainable    shape          dtype    value
# -----------------------------------  ---------  ----------------  -------  -----------  -------------  -------  ----------------------------------------------------
# SVGP.kernel.kernels[0].variance      Parameter  Softplus                   True         ()             float64  0.8687843968787203
# SVGP.kernel.kernels[0].lengthscales  Parameter  Softplus                   True         (3,)           float64  [0.54077399 2.16939769 3.54042208]
# SVGP.kernel.kernels[1].variance      Parameter  Softplus                   True         ()             float64  0.9612727200266531
# SVGP.kernel.kernels[2].variance      Parameter  Softplus                   True         ()             float64  0.6597838437427168
# SVGP.kernel.kernels[2].lengthscales  Parameter  Softplus                   True         (3,)           float64  [0.76347537 0.18129634 4.6091437 ]
# SVGP.kernel.kernels[2].alpha         Parameter  Softplus                   True         ()             float64  0.03904859332346087
# SVGP.likelihood.variance             Parameter  Softplus + Shift           True         ()             float64  0.019682146986650134
# SVGP.inducing_variable.Z             Parameter  Identity                   True         (232, 3)       float64  [[8.31855081e-01, 6.25935650e-01, 3.53804174e-02...
# SVGP.q_mu                            Parameter  Identity                   False        (232, 1)       float64  [[3.37403883e-01...
# SVGP.q_sqrt                          Parameter  FillTriangular             False        (1, 232, 232)  float64  [[[4.31337166e-02, 0.00000000e+00, 0.00000000e+00...

# %% [markdown]
# ### **$\lambda (t) = f(t, S(t)*I(t), Home(t)*Work(t)*Recreational(t))$** - Gaussian - SE\+L\+RQ

# %%
t = final_data[["Updated"]]
y = final_data[["ConfirmedChange"]]
X = pd.DataFrame({
    "index": final_data["index"],
    "S*I": final_data["S"] * final_data["I"],
    "HOME*WORK*RECREATIONAL": final_data["HOME"]*final_data["WORK"]*final_data["RECREATIONAL"],
}, index=final_data.index)[[
    "index",
    "S*I",
    "HOME*WORK*RECREATIONAL"
]]


model_params = {
    'kernel': (
        gpflow.kernels.SquaredExponential(lengthscales=np.ones(X.shape[1])) +
        gpflow.kernels.Linear() +
        gpflow.kernels.RationalQuadratic(lengthscales=np.ones(X.shape[1]))
    )
}

res, model = run_experiment('$f(t, S(t)*I(t), Home(t)*Work(t)*Recreational(t)$', t, X, y, model_params=model_params, plot=True)
results.add(res)

# %%
model._model
# Out:
# <gpflow.models.svgp.SVGP object at 0x146062a00>
# name                                 class      transform         prior    trainable    shape          dtype    value
# -----------------------------------  ---------  ----------------  -------  -----------  -------------  -------  ----------------------------------------------------
# SVGP.kernel.kernels[0].variance      Parameter  Softplus                   True         ()             float64  0.9010114953110491
# SVGP.kernel.kernels[0].lengthscales  Parameter  Softplus                   True         (3,)           float64  [0.53652956 2.19645417 3.00846426]
# SVGP.kernel.kernels[1].variance      Parameter  Softplus                   True         ()             float64  0.9612190443925934
# SVGP.kernel.kernels[2].variance      Parameter  Softplus                   True         ()             float64  0.7198955947203713
# SVGP.kernel.kernels[2].lengthscales  Parameter  Softplus                   True         (3,)           float64  [0.77187972 0.19550561 4.32711646]
# SVGP.kernel.kernels[2].alpha         Parameter  Softplus                   True         ()             float64  0.03496987745976106
# SVGP.likelihood.variance             Parameter  Softplus + Shift           True         ()             float64  0.01926330422532476
# SVGP.inducing_variable.Z             Parameter  Identity                   True         (232, 3)       float64  [[7.12269351e-01, 6.38540309e-01, -1.65595310e-01...
# SVGP.q_mu                            Parameter  Identity                   False        (232, 1)       float64  [[8.88754394e-02...
# SVGP.q_sqrt                          Parameter  FillTriangular             False        (1, 232, 232)  float64  [[[3.22435193e-02, 0.00000000e+00, 0.00000000e+00...

# %% [markdown]
# ### **$\lambda (t) = f(t, S(t), I(t), Home(t), Work(t), Recreational(t))$** - Gaussian - SE\+L\+RQ

# %%
t = final_data[["Updated"]]
y = final_data[["ConfirmedChange"]]
X = pd.DataFrame({
    "index": final_data["index"],
    "S": final_data["S"],
    "I": final_data["I"],
    "HOME": final_data["HOME"],
    "WORK": final_data["WORK"],
    "RECREATIONAL": final_data["RECREATIONAL"],
}, index=final_data.index)[[
    "index",
    "S",
    "I",
    "HOME", 
    "WORK", 
    "RECREATIONAL"
]]

model_params = {
    'kernel': (
        gpflow.kernels.SquaredExponential(lengthscales=np.ones(X.shape[1])) +
        gpflow.kernels.Linear() +
        gpflow.kernels.RationalQuadratic(lengthscales=np.ones(X.shape[1]))
    )
}

res, model = run_experiment('$f(t, S(t), I(t), Home(t), Work(t), Recreational(t)$', t, X, y, model_params=model_params, plot=True)
results.add(res)

# %%
model._model
# Out:
# <gpflow.models.svgp.SVGP object at 0x1460978b0>
# name                                 class      transform         prior    trainable    shape          dtype    value
# -----------------------------------  ---------  ----------------  -------  -----------  -------------  -------  ----------------------------------------------------
# SVGP.kernel.kernels[0].variance      Parameter  Softplus                   True         ()             float64  0.6350337201303256
# SVGP.kernel.kernels[0].lengthscales  Parameter  Softplus                   True         (6,)           float64  [1.53903046, 0.70828107, 1.6537277...
# SVGP.kernel.kernels[1].variance      Parameter  Softplus                   True         ()             float64  0.9611826018366278
# SVGP.kernel.kernels[2].variance      Parameter  Softplus                   True         ()             float64  0.6117013457171387
# SVGP.kernel.kernels[2].lengthscales  Parameter  Softplus                   True         (6,)           float64  [1.68071779, 0.52708848, 1.66019729...
# SVGP.kernel.kernels[2].alpha         Parameter  Softplus                   True         ()             float64  2.3247808687501013
# SVGP.likelihood.variance             Parameter  Softplus + Shift           True         ()             float64  0.02033327377425232
# SVGP.inducing_variable.Z             Parameter  Identity                   True         (232, 6)       float64  [[-0.33849467, 0.38190005, -0.01609366...
# SVGP.q_mu                            Parameter  Identity                   False        (232, 1)       float64  [[1.73331124e-01...
# SVGP.q_sqrt                          Parameter  FillTriangular             False        (1, 232, 232)  float64  [[[2.48889109e-02, 0.00000000e+00, 0.00000000e+00...

# %% [markdown]
# ### **$\lambda (t) = f(t, S(t)^p, I(t)^p, Home(t)^p, Work(t)^p, Recreational(t)^p)$** - Gaussian - SE\+L\+RQ

# %%
t = final_data[["Updated"]]
y = final_data[["ConfirmedChange"]]
X = pd.DataFrame({
    "index": final_data["index"],
    "S": final_data["S"],
    "S**2": final_data["S"]**2,
    "S**3": final_data["S"]**3,
    "I": final_data["I"],
    "I**2": final_data["I"]**2,
    "I**3": final_data["I"]**3,
    "HOME": final_data["HOME"],
    "HOME**2": final_data["HOME"]**2,
    "HOME**3": final_data["HOME"]**3,
    "WORK": final_data["WORK"],
    "WORK**2": final_data["WORK"]**2,
    "WORK**3": final_data["WORK"]**3,
    "RECREATIONAL": final_data["RECREATIONAL"],
    "RECREATIONAL**2": final_data["RECREATIONAL"]**2,
    "RECREATIONAL**3": final_data["RECREATIONAL"]**3,
}, index=final_data.index)[[
    "index",
    "S","S**2","S**3",
    "I","I**2","I**3",
    "HOME","HOME**2","HOME**3",
    "WORK","WORK**2","WORK**3",
    "RECREATIONAL","RECREATIONAL**2","RECREATIONAL**3",
]]

model_params = {
    'kernel': (
        gpflow.kernels.SquaredExponential(lengthscales=np.ones(X.shape[1])) +
        gpflow.kernels.Linear() +
        gpflow.kernels.RationalQuadratic(lengthscales=np.ones(X.shape[1]))
    )
}

res, model = run_experiment('$f(t, S(t)^p, I(t)^p, Home(t)^p, Work(t)^p, Recreational(t)^p$', t, X, y, model_params=model_params, plot=True)
results.add(res)

# %%
model._model
# Out:
# <gpflow.models.svgp.SVGP object at 0x145e2fbe0>
# name                                 class      transform         prior    trainable    shape          dtype    value
# -----------------------------------  ---------  ----------------  -------  -----------  -------------  -------  ----------------------------------------------------
# SVGP.kernel.kernels[0].variance      Parameter  Softplus                   True         ()             float64  0.4218824619227354
# SVGP.kernel.kernels[0].lengthscales  Parameter  Softplus                   True         (16,)          float64  [2.29269598, 2.03156274, 2.8682456...
# SVGP.kernel.kernels[1].variance      Parameter  Softplus                   True         ()             float64  0.9616333156625542
# SVGP.kernel.kernels[2].variance      Parameter  Softplus                   True         ()             float64  0.3666102619650643
# SVGP.kernel.kernels[2].lengthscales  Parameter  Softplus                   True         (16,)          float64  [2.70412175, 2.38786766, 2.64056838...
# SVGP.kernel.kernels[2].alpha         Parameter  Softplus                   True         ()             float64  0.7867632635566366
# SVGP.likelihood.variance             Parameter  Softplus + Shift           True         ()             float64  0.030505252023834542
# SVGP.inducing_variable.Z             Parameter  Identity                   True         (232, 16)      float64  [[1.31000015, 0.38580595, -0.06583969...
# SVGP.q_mu                            Parameter  Identity                   False        (232, 1)       float64  [[1.20768688e-01...
# SVGP.q_sqrt                          Parameter  FillTriangular             False        (1, 232, 232)  float64  [[[3.53313105e-02, 0.00000000e+00, 0.00000000e+00...

# %% [markdown]
# ## Report

# %%
report = pd.DataFrame([e.to_dict() for e in results])

# %%
report.loc[report["out_sample"].abs().sort_values(ascending=True).index]
# Out:
#       kernel likelihood          mle  \
# 32  Product   Gaussian   359.831895
# 9   Product   Gaussian  -122.224380
# 20  Matern32  Gaussian   795.831594
# 18  Matern32  Gaussian  -126.023003
# 13  Product   Gaussian   1388.332110
# 12  Matern32  Gaussian  -54.170154
# 30  Product   Gaussian   626.784478
# 6   Sum       Gaussian   1002.783865
# 2   Product   Gaussian   142.032121
# 34  Product   Gaussian  -2936.024035
# 14  Product   Gaussian  -573.558402
# 35  Sum       Gaussian   875.030921
# 8   Product   Gaussian   165.272187
# 17  Sum       Gaussian   1307.482787
# 3   Sum       Gaussian  -3274.658628
# 23  Sum       Gaussian   568.265742
# 10  Sum       Gaussian  -8311.567444
# 27  Matern32  Gaussian   2511.814748
# 5   Matern32  Gaussian   554.161132
# 19  Matern32  Gaussian   2699.568260
# 38  Matern32  Gaussian  -2948.376215
# 31  Sum       Gaussian   2333.116999
# 24  Product   Gaussian   2407.805315
# 25  Product   Gaussian  -49.768382
# 4   Product   Gaussian  -3955.437067
# 7   Matern32  Gaussian  -3170.128458
# 22  Sum       Gaussian   2537.748631
# 37  Matern32  Gaussian   773.464330
# 16  Sum       Gaussian   311.131101
# 28  Matern32  Gaussian   460.689655
# 36  Matern32  Gaussian   834.053252
# 0   Sum       Gaussian   1988.203460
# 1   Sum       Gaussian   1197.308174
# 15  Matern32  Gaussian   1987.001766
# 21  Sum       Gaussian   3294.860179
# 11  Product   Gaussian   2533.689744
# 29  Matern32  Gaussian  -3095.168638
# 33  Sum       Gaussian  -3096.213329
# 26  Product   Gaussian  -3125.201350
#
#                                                               model  \
# 32  $f(t, S(t)*I(t))$
# 9   $f(t, I(t), Home(t))$
# 20  $f(t, S(t)*I(t), Home(t), Work(t), Recreational(t))$
# 18  $f(t, S(t)^p, I(t)^p, Home(t)^p, Work(t)^p, Recreational(t)^p)$
# 13  $f(t, S(t), I(t))$
# 12  $f(t, I(t), Home(t))$
# 30  $f(t, S(t)^p, I(t)^p)$
# 6   $f(t, S(t)*I(t), Home(t)*Work(t)*Recreational(t)$
# 2   $f(t, S(t)*I(t), Home(t)*Work(t)*Recreational(t)$
# 34  $f(S(t)+I(t))$
# 14  $f(t, S(t)^p, I(t)^p, Home(t)^p, Work(t)^p, Recreational(t)^p$
# 35  $f(t, S(t)*I(t), Home(t))$
# 8   $f(t, S(t), I(t), Home(t), Work(t), Recreational(t)$
# 17  $f(t, S(t), I(t), Home(t), Work(t), Recreational(t)$
# 3   $f(S(t)+I(t))$
# 23  $f(t, S(t)^p, I(t)^p, Home(t)^p, Work(t)^p, Recreational(t)^p$
# 10  $f(S(t)*I(t))$
# 27  $f(t, S(t)+I(t))$
# 5   $f(t, S(t)*I(t), Home(t)*Work(t)*Recreational(t))$
# 19  $f(t, S(t), I(t))$
# 38  $f(S(t)+I(t))$
# 31  $f(t, S(t)+I(t))$
# 24  $f(t, S(t)+I(t))$
# 25  $f(t, S(t)*I(t), Home(t))$
# 4   $f(S(t)*I(t))$
# 7   $f(S(t)*I(t))$
# 22  $f(t, S(t), I(t))$
# 37  $f(t, S(t)*I(t))$
# 16  $f(t, I(t), Home(t))$
# 28  $f(t, S(t)*I(t), Home(t))$
# 36  $f(t, S(t)^p, I(t)^p)$
# 0   $f(t, S(t)^p, I(t)^p)$
# 1   $f(t, S(t)*I(t))$
# 15  $f(S(t), I(t))$
# 21  $f(S(t), I(t))$
# 11  $f(S(t), I(t))$
# 29  $f(t)$
# 33  $f(t)$
# 26  $f(t)$
#
#     out_sample  var_out_sample  var_within_sample  within_sample
# 32  1.0         0.001270        0.008534           5.0
# 9  -2.0         0.005218        0.010947          -1.0
# 20  6.0         0.009859        0.009838           1.0
# 18  9.0         0.017323        0.021349           3.0
# 13 -9.0         0.000355        0.001901          -1.0
# 12 -15.0        0.009435        0.011773           0.0
# 30 -16.0        0.001144        0.009881           0.0
# 6  -22.0        0.002188        0.006656           0.0
# 2   24.0        0.001157        0.009255           1.0
# 34 -25.0        0.000604        0.001098           12.0
# 14  26.0        0.018342        0.028850          -1.0
# 35 -30.0        0.002604        0.007911           0.0
# 8   30.0        0.008690        0.015097           0.0
# 17  32.0        0.003865        0.004646          -0.0
# 3  -33.0        0.001694        0.001655           0.0
# 23  35.0        0.005528        0.014734          -0.0
# 10  35.0        0.000024        0.001375           0.0
# 27 -38.0        0.002388        0.001101           0.0
# 5   38.0        0.002094        0.005958           0.0
# 19 -38.0        0.002151        0.001192           0.0
# 38 -39.0        0.002079        0.002323           0.0
# 31 -40.0        0.001723        0.000869           0.0
# 24 -41.0        0.002097        0.000727          -0.0
# 25  41.0        0.001537        0.011102           4.0
# 4   43.0        0.000032        0.004719           84.0
# 7   51.0        0.000044        0.002752           1.0
# 22 -53.0        0.003262        0.000839          -0.0
# 37  53.0        0.000699        0.004578           0.0
# 16  54.0        0.009915        0.008005          -0.0
# 28  58.0        0.002319        0.006932           0.0
# 36 -61.0        0.001517        0.007230           2.0
# 0  -72.0        0.003237        0.003793          -0.0
# 1  -81.0        0.001964        0.004697           0.0
# 15 -282.0       0.000582        0.002593           0.0
# 21 -291.0       0.002378        0.000642          -0.0
# 11 -338.0       0.001501        0.000460           0.0
# 29 -501.0       0.002726        0.002824           0.0
# 33 -502.0       0.002391        0.002491           0.0
# 26 -529.0       0.001948        0.002084          -27.0
