# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Dataset" data-toc-modified-id="Dataset-1">Dataset</a></span><ul class="toc-item"><li><span><a href="#Mobility" data-toc-modified-id="Mobility-1.1">Mobility</a></span></li><li><span><a href="#Cases" data-toc-modified-id="Cases-1.2">Cases</a></span></li><li><span><a href="#Merge" data-toc-modified-id="Merge-1.3">Merge</a></span></li></ul></li><li><span><a href="#Model" data-toc-modified-id="Model-2">Model</a></span></li><li><span><a href="#Experiments" data-toc-modified-id="Experiments-3">Experiments</a></span><ul class="toc-item"><li><span><a href="#$\lambda-(t)-=-f(t)$---Gaussian---Matern32" data-toc-modified-id="$\lambda-(t)-=-f(t)$---Gaussian---Matern32-3.1"><strong>$\lambda (t) = f(t)$</strong> - Gaussian - Matern32</a></span></li><li><span><a href="#$\lambda-(t)-=-f(S(t),-I(t))$---Gaussian---Matern32" data-toc-modified-id="$\lambda-(t)-=-f(S(t),-I(t))$---Gaussian---Matern32-3.2"><strong>$\lambda (t) = f(S(t), I(t))$</strong> - Gaussian - Matern32</a></span></li><li><span><a href="#$\lambda-(t)-=-f(S(t)*I(t))$---Gaussian---Matern32" data-toc-modified-id="$\lambda-(t)-=-f(S(t)*I(t))$---Gaussian---Matern32-3.3"><strong>$\lambda (t) = f(S(t)*I(t))$</strong> - Gaussian - Matern32</a></span></li><li><span><a href="#$\lambda-(t)-=-f(S(t)+I(t))$---Gaussian---Matern32" data-toc-modified-id="$\lambda-(t)-=-f(S(t)+I(t))$---Gaussian---Matern32-3.4"><strong>$\lambda (t) = f(S(t)+I(t))$</strong> - Gaussian - Matern32</a></span></li><li><span><a href="#$\lambda-(t)-=-f(t,-S(t)*I(t))$---Gaussian---Matern32" data-toc-modified-id="$\lambda-(t)-=-f(t,-S(t)*I(t))$---Gaussian---Matern32-3.5"><strong>$\lambda (t) = f(t, S(t)*I(t))$</strong> - Gaussian - Matern32</a></span></li><li><span><a href="#$\lambda-(t)-=-f(t,-S(t)+I(t))$---Gaussian---Matern32" data-toc-modified-id="$\lambda-(t)-=-f(t,-S(t)+I(t))$---Gaussian---Matern32-3.6"><strong>$\lambda (t) = f(t, S(t)+I(t))$</strong> - Gaussian - Matern32</a></span></li><li><span><a href="#$\lambda-(t)-=-f(t,-S(t),-I(t))$---Gaussian---Matern32" data-toc-modified-id="$\lambda-(t)-=-f(t,-S(t),-I(t))$---Gaussian---Matern32-3.7"><strong>$\lambda (t) = f(t, S(t), I(t))$</strong> - Gaussian - Matern32</a></span></li><li><span><a href="#$\lambda-(t)-=-f(t,-S(t)^p,-I(t)^p)$---Gaussian---Matern32" data-toc-modified-id="$\lambda-(t)-=-f(t,-S(t)^p,-I(t)^p)$---Gaussian---Matern32-3.8"><strong>$\lambda (t) = f(t, S(t)^p, I(t)^p)$</strong> - Gaussian - Matern32</a></span></li><li><span><a href="#$\lambda-(t)-=-f(t,-I(t),-Home(t))$---Gaussian---Matern32" data-toc-modified-id="$\lambda-(t)-=-f(t,-I(t),-Home(t))$---Gaussian---Matern32-3.9"><strong>$\lambda (t) = f(t, I(t), Home(t))$</strong> - Gaussian - Matern32</a></span></li><li><span><a href="#$\lambda-(t)-=-f(t,-I(t),-Home(t),-Weekday(t))$---Gaussian---Matern32" data-toc-modified-id="$\lambda-(t)-=-f(t,-I(t),-Home(t),-Weekday(t))$---Gaussian---Matern32-3.10"><strong>$\lambda (t) = f(t, I(t), Home(t), Weekday(t))$</strong> - Gaussian - Matern32</a></span></li><li><span><a href="#$\lambda-(t)-=-f(t,-S(t)*I(t),-Home(t))$---Gaussian---Matern32" data-toc-modified-id="$\lambda-(t)-=-f(t,-S(t)*I(t),-Home(t))$---Gaussian---Matern32-3.11"><strong>$\lambda (t) = f(t, S(t)*I(t), Home(t))$</strong> - Gaussian - Matern32</a></span></li><li><span><a href="#$\lambda-(t)-=-f(t,-S(t)*I(t),-Home(t),-Weekday(t))$---Gaussian---Matern32" data-toc-modified-id="$\lambda-(t)-=-f(t,-S(t)*I(t),-Home(t),-Weekday(t))$---Gaussian---Matern32-3.12"><strong>$\lambda (t) = f(t, S(t)*I(t), Home(t), Weekday(t))$</strong> - Gaussian - Matern32</a></span></li><li><span><a href="#$\lambda-(t)-=-f(t,-S(t)*I(t),-Home(t)*Work(t)*Recreational(t))$---Gaussian---Matern32" data-toc-modified-id="$\lambda-(t)-=-f(t,-S(t)*I(t),-Home(t)*Work(t)*Recreational(t))$---Gaussian---Matern32-3.13"><strong>$\lambda (t) = f(t, S(t)*I(t), Home(t)*Work(t)*Recreational(t))$</strong> - Gaussian - Matern32</a></span></li><li><span><a href="#$\lambda-(t)-=-f(t,-S(t)*I(t),-Home(t)*Work(t)*Recreational(t),-Weekday(t))$---Gaussian---Matern32" data-toc-modified-id="$\lambda-(t)-=-f(t,-S(t)*I(t),-Home(t)*Work(t)*Recreational(t),-Weekday(t))$---Gaussian---Matern32-3.14"><strong>$\lambda (t) = f(t, S(t)*I(t), Home(t)*Work(t)*Recreational(t), Weekday(t))$</strong> - Gaussian - Matern32</a></span></li><li><span><a href="#$\lambda-(t)-=-f(t,-S(t),-I(t),-Home(t),-Work(t),-Recreational(t))$---Gaussian---Matern32" data-toc-modified-id="$\lambda-(t)-=-f(t,-S(t),-I(t),-Home(t),-Work(t),-Recreational(t))$---Gaussian---Matern32-3.15"><strong>$\lambda (t) = f(t, S(t), I(t), Home(t), Work(t), Recreational(t))$</strong> - Gaussian - Matern32</a></span></li><li><span><a href="#$\lambda-(t)-=-f(t,-S(t),-I(t),-Home(t),-Work(t),-Recreational(t),-Weekday(t))$---Gaussian---Matern32" data-toc-modified-id="$\lambda-(t)-=-f(t,-S(t),-I(t),-Home(t),-Work(t),-Recreational(t),-Weekday(t))$---Gaussian---Matern32-3.16"><strong>$\lambda (t) = f(t, S(t), I(t), Home(t), Work(t), Recreational(t), Weekday(t))$</strong> - Gaussian - Matern32</a></span></li><li><span><a href="#$\lambda-(t)-=-f(t,-S(t)^p,-I(t)^p,-Home(t)^p,-Work(t)^p,-Recreational(t)^p)$---Gaussian---Matern32" data-toc-modified-id="$\lambda-(t)-=-f(t,-S(t)^p,-I(t)^p,-Home(t)^p,-Work(t)^p,-Recreational(t)^p)$---Gaussian---Matern32-3.17"><strong>$\lambda (t) = f(t, S(t)^p, I(t)^p, Home(t)^p, Work(t)^p, Recreational(t)^p)$</strong> - Gaussian - Matern32</a></span></li><li><span><a href="#$\lambda-(t)-=-f(t)$---Gaussian---SE*L*RQ" data-toc-modified-id="$\lambda-(t)-=-f(t)$---Gaussian---SE*L*RQ-3.18"><strong>$\lambda (t) = f(t)$</strong> - Gaussian - SE*L*RQ</a></span></li><li><span><a href="#$\lambda-(t)-=-f(S(t),-I(t))$---Gaussian---SE*L*RQ" data-toc-modified-id="$\lambda-(t)-=-f(S(t),-I(t))$---Gaussian---SE*L*RQ-3.19"><strong>$\lambda (t) = f(S(t), I(t))$</strong> - Gaussian - SE*L*RQ</a></span></li><li><span><a href="#$\lambda-(t)-=-f(S(t)*I(t))$---Gaussian---SE*L*RQ" data-toc-modified-id="$\lambda-(t)-=-f(S(t)*I(t))$---Gaussian---SE*L*RQ-3.20"><strong>$\lambda (t) = f(S(t)*I(t))$</strong> - Gaussian - SE*L*RQ</a></span></li><li><span><a href="#$\lambda-(t)-=-f(S(t)+I(t))$---Gaussian---SE*L*RQ" data-toc-modified-id="$\lambda-(t)-=-f(S(t)+I(t))$---Gaussian---SE*L*RQ-3.21"><strong>$\lambda (t) = f(S(t)+I(t))$</strong> - Gaussian - SE*L*RQ</a></span></li><li><span><a href="#$\lambda-(t)-=-f(t,-S(t)*I(t))$---Gaussian---SE*L*RQ" data-toc-modified-id="$\lambda-(t)-=-f(t,-S(t)*I(t))$---Gaussian---SE*L*RQ-3.22"><strong>$\lambda (t) = f(t, S(t)*I(t))$</strong> - Gaussian - SE*L*RQ</a></span></li><li><span><a href="#$\lambda-(t)-=-f(t,-S(t)+I(t))$---Gaussian---SE*L*RQ" data-toc-modified-id="$\lambda-(t)-=-f(t,-S(t)+I(t))$---Gaussian---SE*L*RQ-3.23"><strong>$\lambda (t) = f(t, S(t)+I(t))$</strong> - Gaussian - SE*L*RQ</a></span></li><li><span><a href="#$\lambda-(t)-=-f(t,-S(t),-I(t))$---Gaussian---SE*L*RQ" data-toc-modified-id="$\lambda-(t)-=-f(t,-S(t),-I(t))$---Gaussian---SE*L*RQ-3.24"><strong>$\lambda (t) = f(t, S(t), I(t))$</strong> - Gaussian - SE*L*RQ</a></span></li><li><span><a href="#$\lambda-(t)-=-f(t,-S(t)^p,-I(t)^p)$---Gaussian---SE*L*RQ" data-toc-modified-id="$\lambda-(t)-=-f(t,-S(t)^p,-I(t)^p)$---Gaussian---SE*L*RQ-3.25"><strong>$\lambda (t) = f(t, S(t)^p, I(t)^p)$</strong> - Gaussian - SE*L*RQ</a></span></li><li><span><a href="#$\lambda-(t)-=-f(t,-I(t),-Home(t))$---Gaussian---SE*L*RQ" data-toc-modified-id="$\lambda-(t)-=-f(t,-I(t),-Home(t))$---Gaussian---SE*L*RQ-3.26"><strong>$\lambda (t) = f(t, I(t), Home(t))$</strong> - Gaussian - SE*L*RQ</a></span></li><li><span><a href="#$\lambda-(t)-=-f(t,-I(t),-Home(t),-Weekday(t))$---Gaussian---SE*L*RQ" data-toc-modified-id="$\lambda-(t)-=-f(t,-I(t),-Home(t),-Weekday(t))$---Gaussian---SE*L*RQ-3.27"><strong>$\lambda (t) = f(t, I(t), Home(t), Weekday(t))$</strong> - Gaussian - SE*L*RQ</a></span></li><li><span><a href="#$\lambda-(t)-=-f(t,-S(t)*I(t),-Home(t))$---Gaussian---SE*L*RQ" data-toc-modified-id="$\lambda-(t)-=-f(t,-S(t)*I(t),-Home(t))$---Gaussian---SE*L*RQ-3.28"><strong>$\lambda (t) = f(t, S(t)*I(t), Home(t))$</strong> - Gaussian - SE*L*RQ</a></span></li><li><span><a href="#$\lambda-(t)-=-f(t,-S(t)*I(t),-Home(t),-Weekday(t))$---Gaussian---SE*L*RQ" data-toc-modified-id="$\lambda-(t)-=-f(t,-S(t)*I(t),-Home(t),-Weekday(t))$---Gaussian---SE*L*RQ-3.29"><strong>$\lambda (t) = f(t, S(t)*I(t), Home(t), Weekday(t))$</strong> - Gaussian - SE*L*RQ</a></span></li><li><span><a href="#$\lambda-(t)-=-f(t,-S(t)*I(t),-Home(t)*Work(t)*Recreational(t))$---Gaussian---SE*L*RQ" data-toc-modified-id="$\lambda-(t)-=-f(t,-S(t)*I(t),-Home(t)*Work(t)*Recreational(t))$---Gaussian---SE*L*RQ-3.30"><strong>$\lambda (t) = f(t, S(t)*I(t), Home(t)*Work(t)*Recreational(t))$</strong> - Gaussian - SE*L*RQ</a></span></li><li><span><a href="#$\lambda-(t)-=-f(t,-S(t)*I(t),-Home(t)*Work(t)*Recreational(t),-Weekday(t))$---Gaussian---SE*L*RQ" data-toc-modified-id="$\lambda-(t)-=-f(t,-S(t)*I(t),-Home(t)*Work(t)*Recreational(t),-Weekday(t))$---Gaussian---SE*L*RQ-3.31"><strong>$\lambda (t) = f(t, S(t)*I(t), Home(t)*Work(t)*Recreational(t), Weekday(t))$</strong> - Gaussian - SE*L*RQ</a></span></li><li><span><a href="#$\lambda-(t)-=-f(t,-S(t),-I(t),-Home(t),-Work(t),-Recreational(t))$---Gaussian---SE*L*RQ" data-toc-modified-id="$\lambda-(t)-=-f(t,-S(t),-I(t),-Home(t),-Work(t),-Recreational(t))$---Gaussian---SE*L*RQ-3.32"><strong>$\lambda (t) = f(t, S(t), I(t), Home(t), Work(t), Recreational(t))$</strong> - Gaussian - SE*L*RQ</a></span></li><li><span><a href="#$\lambda-(t)-=-f(t,-S(t),-I(t),-Home(t),-Work(t),-Recreational(t),-Weekday(t))$---Gaussian---SE*L*RQ" data-toc-modified-id="$\lambda-(t)-=-f(t,-S(t),-I(t),-Home(t),-Work(t),-Recreational(t),-Weekday(t))$---Gaussian---SE*L*RQ-3.33"><strong>$\lambda (t) = f(t, S(t), I(t), Home(t), Work(t), Recreational(t), Weekday(t))$</strong> - Gaussian - SE*L*RQ</a></span></li><li><span><a href="#$\lambda-(t)-=-f(t,-S(t)^p,-I(t)^p,-Home(t)^p,-Work(t)^p,-Recreational(t)^p)$---Gaussian---SE*L*RQ" data-toc-modified-id="$\lambda-(t)-=-f(t,-S(t)^p,-I(t)^p,-Home(t)^p,-Work(t)^p,-Recreational(t)^p)$---Gaussian---SE*L*RQ-3.34"><strong>$\lambda (t) = f(t, S(t)^p, I(t)^p, Home(t)^p, Work(t)^p, Recreational(t)^p)$</strong> - Gaussian - SE*L*RQ</a></span></li><li><span><a href="#$\lambda-(t)-=-f(t)$---Gaussian---SE+L+RQ" data-toc-modified-id="$\lambda-(t)-=-f(t)$---Gaussian---SE+L+RQ-3.35"><strong>$\lambda (t) = f(t)$</strong> - Gaussian - SE+L+RQ</a></span></li><li><span><a href="#$\lambda-(t)-=-f(S(t),-I(t))$---Gaussian---SE+L+RQ" data-toc-modified-id="$\lambda-(t)-=-f(S(t),-I(t))$---Gaussian---SE+L+RQ-3.36"><strong>$\lambda (t) = f(S(t), I(t))$</strong> - Gaussian - SE+L+RQ</a></span></li><li><span><a href="#$\lambda-(t)-=-f(S(t)*I(t))$---Gaussian---SE+L+RQ" data-toc-modified-id="$\lambda-(t)-=-f(S(t)*I(t))$---Gaussian---SE+L+RQ-3.37"><strong>$\lambda (t) = f(S(t)*I(t))$</strong> - Gaussian - SE+L+RQ</a></span></li><li><span><a href="#$\lambda-(t)-=-f(S(t)+I(t))$---Gaussian---SE+L+RQ" data-toc-modified-id="$\lambda-(t)-=-f(S(t)+I(t))$---Gaussian---SE+L+RQ-3.38"><strong>$\lambda (t) = f(S(t)+I(t))$</strong> - Gaussian - SE+L+RQ</a></span></li><li><span><a href="#$\lambda-(t)-=-f(t,-S(t)*I(t))$---Gaussian---SE+L+RQ" data-toc-modified-id="$\lambda-(t)-=-f(t,-S(t)*I(t))$---Gaussian---SE+L+RQ-3.39"><strong>$\lambda (t) = f(t, S(t)*I(t))$</strong> - Gaussian - SE+L+RQ</a></span></li><li><span><a href="#$\lambda-(t)-=-f(t,-S(t)+I(t))$---Gaussian---SE+L+RQ" data-toc-modified-id="$\lambda-(t)-=-f(t,-S(t)+I(t))$---Gaussian---SE+L+RQ-3.40"><strong>$\lambda (t) = f(t, S(t)+I(t))$</strong> - Gaussian - SE+L+RQ</a></span></li><li><span><a href="#$\lambda-(t)-=-f(t,-S(t),-I(t))$---Gaussian---SE+L+RQ" data-toc-modified-id="$\lambda-(t)-=-f(t,-S(t),-I(t))$---Gaussian---SE+L+RQ-3.41"><strong>$\lambda (t) = f(t, S(t), I(t))$</strong> - Gaussian - SE+L+RQ</a></span></li><li><span><a href="#$\lambda-(t)-=-f(t,-S(t)^p,-I(t)^p)$---Gaussian---SE+L+RQ" data-toc-modified-id="$\lambda-(t)-=-f(t,-S(t)^p,-I(t)^p)$---Gaussian---SE+L+RQ-3.42"><strong>$\lambda (t) = f(t, S(t)^p, I(t)^p)$</strong> - Gaussian - SE+L+RQ</a></span></li><li><span><a href="#$\lambda-(t)-=-f(t,-I(t),-Home(t))$---Gaussian---SE+L+RQ" data-toc-modified-id="$\lambda-(t)-=-f(t,-I(t),-Home(t))$---Gaussian---SE+L+RQ-3.43"><strong>$\lambda (t) = f(t, I(t), Home(t))$</strong> - Gaussian - SE+L+RQ</a></span></li><li><span><a href="#$\lambda-(t)-=-f(t,-I(t),-Home(t),-Weekday(t))$---Gaussian---SE+L+RQ" data-toc-modified-id="$\lambda-(t)-=-f(t,-I(t),-Home(t),-Weekday(t))$---Gaussian---SE+L+RQ-3.44"><strong>$\lambda (t) = f(t, I(t), Home(t), Weekday(t))$</strong> - Gaussian - SE+L+RQ</a></span></li><li><span><a href="#$\lambda-(t)-=-f(t,-S(t)*I(t),-Home(t))$---Gaussian---SE+L+RQ" data-toc-modified-id="$\lambda-(t)-=-f(t,-S(t)*I(t),-Home(t))$---Gaussian---SE+L+RQ-3.45"><strong>$\lambda (t) = f(t, S(t)*I(t), Home(t))$</strong> - Gaussian - SE+L+RQ</a></span></li><li><span><a href="#$\lambda-(t)-=-f(t,-S(t)*I(t),-Home(t),-Weekday(t))$---Gaussian---SE+L+RQ" data-toc-modified-id="$\lambda-(t)-=-f(t,-S(t)*I(t),-Home(t),-Weekday(t))$---Gaussian---SE+L+RQ-3.46"><strong>$\lambda (t) = f(t, S(t)*I(t), Home(t), Weekday(t))$</strong> - Gaussian - SE+L+RQ</a></span></li><li><span><a href="#$\lambda-(t)-=-f(t,-S(t)*I(t),-Home(t)*Work(t)*Recreational(t))$---Gaussian---SE+L+RQ" data-toc-modified-id="$\lambda-(t)-=-f(t,-S(t)*I(t),-Home(t)*Work(t)*Recreational(t))$---Gaussian---SE+L+RQ-3.47"><strong>$\lambda (t) = f(t, S(t)*I(t), Home(t)*Work(t)*Recreational(t))$</strong> - Gaussian - SE+L+RQ</a></span></li><li><span><a href="#$\lambda-(t)-=-f(t,-S(t)*I(t),-Home(t)*Work(t)*Recreational(t),-Weekday(t))$---Gaussian---SE+L+RQ" data-toc-modified-id="$\lambda-(t)-=-f(t,-S(t)*I(t),-Home(t)*Work(t)*Recreational(t),-Weekday(t))$---Gaussian---SE+L+RQ-3.48"><strong>$\lambda (t) = f(t, S(t)*I(t), Home(t)*Work(t)*Recreational(t), Weekday(t))$</strong> - Gaussian - SE+L+RQ</a></span></li><li><span><a href="#$\lambda-(t)-=-f(t,-S(t),-I(t),-Home(t),-Work(t),-Recreational(t))$---Gaussian---SE+L+RQ" data-toc-modified-id="$\lambda-(t)-=-f(t,-S(t),-I(t),-Home(t),-Work(t),-Recreational(t))$---Gaussian---SE+L+RQ-3.49"><strong>$\lambda (t) = f(t, S(t), I(t), Home(t), Work(t), Recreational(t))$</strong> - Gaussian - SE+L+RQ</a></span></li><li><span><a href="#$\lambda-(t)-=-f(t,-S(t),-I(t),-Home(t),-Work(t),-Recreational(t),-Weekday(t))$---Gaussian---SE+L+RQ" data-toc-modified-id="$\lambda-(t)-=-f(t,-S(t),-I(t),-Home(t),-Work(t),-Recreational(t),-Weekday(t))$---Gaussian---SE+L+RQ-3.50"><strong>$\lambda (t) = f(t, S(t), I(t), Home(t), Work(t), Recreational(t), Weekday(t))$</strong> - Gaussian - SE+L+RQ</a></span></li><li><span><a href="#$\lambda-(t)-=-f(t,-S(t)^p,-I(t)^p,-Home(t)^p,-Work(t)^p,-Recreational(t)^p)$---Gaussian---SE+L+RQ" data-toc-modified-id="$\lambda-(t)-=-f(t,-S(t)^p,-I(t)^p,-Home(t)^p,-Work(t)^p,-Recreational(t)^p)$---Gaussian---SE+L+RQ-3.51"><strong>$\lambda (t) = f(t, S(t)^p, I(t)^p, Home(t)^p, Work(t)^p, Recreational(t)^p)$</strong> - Gaussian - SE+L+RQ</a></span></li></ul></li><li><span><a href="#Report" data-toc-modified-id="Report-4">Report</a></span></li></ul></div>

# %%
import pandas as pd
from itertools import cycle
import gpflow
import numpy as np
from gpflow.utilities import print_summary, positive
from gpflow.ci_utils import ci_niter
from gpflow.optimizers import NaturalGradient
from gpflow import set_trainable
import tensorflow as tf
import tensorflow_probability as tfp
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from collections import namedtuple
import statsmodels.api as sm
from contextlib import contextmanager
import time

sns.set(style="white")
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', -1)

gpflow.config.set_default_float(np.float64)
gpflow.config.set_default_summary_fmt("notebook")

# %% [markdown]
# ## Dataset

# %% [markdown]
# ### Mobility

# %%
mobility_data = pd.read_csv(
    "../Data/Google/Global_Mobility_Report.csv", 
    encoding="ISO-8859-1", 
    parse_dates=["date"],
    dayfirst=True
)
# Out:
# /Users/N547113/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3071: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
mobility_data_us = mobility_data[
    (mobility_data["country_region"]=="United States") & (mobility_data["sub_region_1"].isnull())
]
mobility_data_us = mobility_data_us.iloc[:,7:].reset_index(drop=True) # keep only relevant columns
mobility_data_us.iloc[:,1:] = mobility_data_us.iloc[:,1:].apply(lambda x: x/100 + 1)

# %%
mobility_data_us = pd.DataFrame({
    "date": mobility_data_us["date"],
    "HOME": mobility_data_us['residential_percent_change_from_baseline'],
    "WORK": mobility_data_us['workplaces_percent_change_from_baseline'],
    "RECREATIONAL": mobility_data_us['retail_and_recreation_percent_change_from_baseline'],
    "OTHER": mobility_data_us.iloc[:,2:5].mean(axis=1)
})

mobility_data_us["HOME"] = mobility_data_us["HOME"].rolling(7).median()
mobility_data_us["WORK"] = mobility_data_us["WORK"].rolling(7).median()
mobility_data_us["RECREATIONAL"] = mobility_data_us["RECREATIONAL"].rolling(7).median()
mobility_data_us["OTHER"] = mobility_data_us["OTHER"].rolling(7).median()

# %%
mobility_data_us[["HOME", "WORK", "RECREATIONAL", "OTHER"]].plot(figsize=(10,6))
# Out:
# <AxesSubplot:>

# %% [markdown]
# 19thFeb 27thJuly

# %% [markdown]
# ### Cases

# %%
# COVID Cases from Microsoft, includes Recovered and Infected
ms_covid = pd.read_csv(
    "../Data/Microsoft/COVID_CASES.csv", 
    encoding="ISO-8859-1",
    parse_dates=["Updated"],
    dayfirst=False
)
ms_us_covid = ms_covid[(ms_covid["Country_Region"]=="United States") & (ms_covid["AdminRegion1"].isnull())]
ms_us_covid = ms_us_covid.loc[:,["Updated", "Confirmed", "ConfirmedChange", "Deaths", "Recovered"]]
ms_us_covid.reset_index(drop=True, inplace=True)

# %%
# Create the 3 categories S, I, R for US data (UK does not include R)
ms_us_covid = ms_us_covid.fillna(method='ffill').fillna(0)
ms_us_covid["I"] = ms_us_covid["Confirmed"] - ms_us_covid["Deaths"] - ms_us_covid["Recovered"]

ms_us_covid["S"] = 70000000 - ms_us_covid["I"]

ms_us_covid["index"] = ms_us_covid["Updated"].dt.dayofyear

ms_us_covid["WEEKDAY"] = (ms_us_covid["Updated"].dt.dayofweek < 5).astype(int)

ms_us_covid["ConfirmedChange"] = ms_us_covid["ConfirmedChange"].rolling(7).median()
ms_us_covid["I"] = ms_us_covid["I"].rolling(7).median()
ms_us_covid["S"] = ms_us_covid["S"].rolling(7).median()

ms_us_covid.dropna(inplace=True)

plt.plot(ms_us_covid["ConfirmedChange"])

# %% [markdown]
# ### Merge

# %%
final_data = ms_us_covid.set_index("Updated").merge(
    mobility_data_us.set_index("date"), how='left', left_index=True, right_index=True
).reset_index()
final_data.dropna(inplace=True)

# %%
fig, axs = plt.subplots(ncols=3, figsize=(20, 4))

final_data.set_index("Updated")[["ConfirmedChange"]].plot(ax=axs[0])
final_data.set_index("Updated")[["I"]].plot(ax=axs[1])
final_data.set_index("Updated")[["S"]].plot(ax=axs[2])
# Out:
# <AxesSubplot:xlabel='Updated'>

# %% [markdown]
# ## Model

# %%
from experiment import run_experiment, Report

# %%
def train_test_split_func(t, X, y):
    t_train, t_test = t[:-21,:], t[-21:,:]
    X_train, X_test = X[:-21,:], X[-21:,:]
    y_train, y_test = y[:-21,:], y[-21:,:]
    
    return t_train, t_test, X_train, X_test, y_train, y_test

# %% [markdown]
# ## Experiments

# %%
results = set()

# %% [markdown]
# ### **$\lambda (t) = f(t)$** - Gaussian - Matern32

# %%
t = final_data[["Updated"]].to_numpy()
y = final_data[["ConfirmedChange"]].to_numpy()
X = final_data[["index"]].to_numpy()

model_params = {
}

res, model = run_experiment('$f(t)$', t, X, y, 
                            model_params=model_params, 
                            train_test_split_func=train_test_split_func, 
                            plot=False)
results.add(res)

# %%
res.to_pandas()
# Out:
#                                             Summary
# Model                      $f(t)$
# Likelihood                 Gaussian
# Kernel                     Matern32
# ELBO                       106.01
# Training-set dates         2020-02-21 to 2020-07-06
# Test-set dates             2020-07-07 to 2020-07-27
# train_size                 137
# test_size                  21
# Number of inducing points  13
# run_time                   92.5669
# Train average variance     0.0019
# Test average variance      0.1657
# Train average error        0
# Test average error         220
# 1st week average error    -993
# 2nd week average error     1630
# 3rd week average error     22

# %% [markdown]
# ### **$\lambda (t) = f(S(t), I(t))$** - Gaussian - Matern32

# %%
t = final_data[["Updated"]].to_numpy()
y = final_data[["ConfirmedChange"]].to_numpy()
X = final_data[["S", "I"]].to_numpy()

model_params = {
}

res, model = run_experiment('$f(S(t), I(t))$', t, X, y, 
                            model_params=model_params, 
                            train_test_split_func=train_test_split_func, 
                            plot=True)
results.add(res)

# %%
res.to_pandas()
# Out:
#                                             Summary
# Model                      $f(S(t), I(t))$
# Likelihood                 Gaussian
# Kernel                     Matern32
# ELBO                       65.01
# Training-set dates         2020-02-21 to 2020-07-06
# Test-set dates             2020-07-07 to 2020-07-27
# train_size                 137
# test_size                  21
# Number of inducing points  13
# run_time                   88.2621
# Train average variance     0.0034
# Test average variance      0.9583
# Train average error       -0
# Test average error         11072
# 1st week average error     2079
# 2nd week average error     12003
# 3rd week average error     19134

# %% [markdown]
# ### **$\lambda (t) = f(S(t)*I(t))$** - Gaussian - Matern32

# %%
t = final_data[["Updated"]].to_numpy()
y = final_data[["ConfirmedChange"]].to_numpy()
X = (
    final_data["S"] * final_data["I"]
).to_numpy().reshape(-1, 1)

model_params = {
}

res, model = run_experiment('$f(S(t)*I(t))$', t, X, y, 
                            model_params=model_params, 
                            train_test_split_func=train_test_split_func, 
                            plot=True)
results.add(res)

# %%
res.to_pandas()
# Out:
#                                             Summary
# Model                      $f(S(t)*I(t))$
# Likelihood                 Gaussian
# Kernel                     Matern32
# ELBO                       84.83
# Training-set dates         2020-02-21 to 2020-07-06
# Test-set dates             2020-07-07 to 2020-07-27
# train_size                 137
# test_size                  21
# Number of inducing points  13
# run_time                   97.057
# Train average variance     0.0023
# Test average variance      1.152
# Train average error       -0
# Test average error         9101
# 1st week average error     328
# 2nd week average error     9738
# 3rd week average error     17238

# %% [markdown]
# ### **$\lambda (t) = f(S(t)+I(t))$** - Gaussian - Matern32

# %%
t = final_data[["Updated"]].to_numpy()
y = final_data[["ConfirmedChange"]].to_numpy()
X = (
    final_data["S"] + final_data["I"]
).to_numpy().reshape(-1, 1)

model_params = {
}

res, model = run_experiment('$f(S(t)+I(t))$', t, X, y, 
                            model_params=model_params, 
                            train_test_split_func=train_test_split_func, 
                            plot=True)
results.add(res)

# %%
res.to_pandas()
# Out:
#                                             Summary
# Model                      $f(S(t)+I(t))$
# Likelihood                 Gaussian
# Kernel                     Matern32
# ELBO                      -196
# Training-set dates         2020-02-21 to 2020-07-06
# Test-set dates             2020-07-07 to 2020-07-27
# train_size                 137
# test_size                  21
# Number of inducing points  13
# run_time                   96.1574
# Train average variance     0.0071
# Test average variance      0.0071
# Train average error       -0
# Test average error         41443
# 1st week average error     34876
# 2nd week average error     43706
# 3rd week average error     45747

# %% [markdown]
# ### **$\lambda (t) = f(t, S(t)*I(t))$** - Gaussian - Matern32

# %%
t = final_data[["Updated"]].to_numpy()
y = final_data[["ConfirmedChange"]].to_numpy()
X = np.hstack([
    final_data[["index"]].to_numpy(),
    (final_data["S"] * final_data["I"]).to_numpy().reshape(-1, 1)
])

model_params = {
    'kernel': gpflow.kernels.Matern32(lengthscales=np.ones(X.shape[1]))
}

res, model = run_experiment('$f(t, S(t)*I(t))$', t, X, y, 
                            model_params=model_params, 
                            train_test_split_func=train_test_split_func, 
                            plot=True)
results.add(res)

# %%
res.to_pandas()
# Out:
#                                             Summary
# Model                      $f(t, S(t)*I(t))$
# Likelihood                 Gaussian
# Kernel                     Matern32
# ELBO                       105.29
# Training-set dates         2020-02-21 to 2020-07-06
# Test-set dates             2020-07-07 to 2020-07-27
# train_size                 137
# test_size                  21
# Number of inducing points  13
# run_time                   97.4098
# Train average variance     0.0021
# Test average variance      0.3248
# Train average error        0
# Test average error         4438
# 1st week average error    -204
# 2nd week average error     5355
# 3rd week average error     8164

# %% [markdown]
# ### **$\lambda (t) = f(t, S(t)+I(t))$** - Gaussian - Matern32

# %%
t = final_data[["Updated"]].to_numpy()
y = final_data[["ConfirmedChange"]].to_numpy()
X = np.hstack([
    final_data[["index"]].to_numpy(),
    (final_data["S"] + final_data["I"]).to_numpy().reshape(-1, 1)
])

model_params = {
    'kernel': gpflow.kernels.Matern32(lengthscales=np.ones(X.shape[1]))
}

res, model = run_experiment('$f(t, S(t)+I(t))$', t, X, y, 
                            model_params=model_params, 
                            train_test_split_func=train_test_split_func, 
                            plot=True)
results.add(res)

# %%
res.to_pandas()
# Out:
#                                             Summary
# Model                      $f(t, S(t)+I(t))$
# Likelihood                 Gaussian
# Kernel                     Matern32
# ELBO                       106.01
# Training-set dates         2020-02-21 to 2020-07-06
# Test-set dates             2020-07-07 to 2020-07-27
# train_size                 137
# test_size                  21
# Number of inducing points  13
# run_time                   92.2541
# Train average variance     0.0019
# Test average variance      0.1661
# Train average error        0
# Test average error         236
# 1st week average error    -983
# 2nd week average error     1647
# 3rd week average error     45

# %% [markdown]
# ### **$\lambda (t) = f(t, S(t), I(t))$** - Gaussian - Matern32

# %%
t = final_data[["Updated"]].to_numpy()
y = final_data[["ConfirmedChange"]].to_numpy()
X = np.hstack([
    final_data[["index"]].to_numpy(),
    final_data[["S"]].to_numpy(),
    final_data[["I"]].to_numpy(),
])

model_params = {
    'kernel': gpflow.kernels.Matern32(lengthscales=np.ones(X.shape[1]))
}

res, model = run_experiment('$f(t, S(t), I(t))$', t, X, y, 
                            model_params=model_params, 
                            train_test_split_func=train_test_split_func, 
                            plot=True)
results.add(res)

# %%
res.to_pandas()
# Out:
#                                             Summary
# Model                      $f(t, S(t), I(t))$
# Likelihood                 Gaussian
# Kernel                     Matern32
# ELBO                       98.53
# Training-set dates         2020-02-21 to 2020-07-06
# Test-set dates             2020-07-07 to 2020-07-27
# train_size                 137
# test_size                  21
# Number of inducing points  13
# run_time                   95.0656
# Train average variance     0.0022
# Test average variance      0.4607
# Train average error        0
# Test average error         7685
# 1st week average error     704
# 2nd week average error     8491
# 3rd week average error     13861

# %% [markdown]
# ### **$\lambda (t) = f(t, S(t)^p, I(t)^p)$** - Gaussian - Matern32

# %%
t = final_data[["Updated"]].to_numpy()
y = final_data[["ConfirmedChange"]].to_numpy()
X = np.hstack([
    final_data[["index"]].to_numpy(),
    final_data[["S"]].to_numpy(),
    final_data[["S"]].to_numpy()**2,
    final_data[["S"]].to_numpy()**3,
    final_data[["I"]].to_numpy(),
    final_data[["I"]].to_numpy()**2,
    final_data[["I"]].to_numpy()**3,
])

model_params = {
    'kernel': gpflow.kernels.Matern32(lengthscales=np.ones(X.shape[1]))
}

res, model = run_experiment('$f(t, S(t)^p, I(t)^p)$', t, X, y, 
                            model_params=model_params, 
                            train_test_split_func=train_test_split_func, 
                            plot=True)
results.add(res)

# %%
res.to_pandas()
# Out:
#                                             Summary
# Model                      $f(t, S(t)^p, I(t)^p)$
# Likelihood                 Gaussian
# Kernel                     Matern32
# ELBO                       97.26
# Training-set dates         2020-02-21 to 2020-07-06
# Test-set dates             2020-07-07 to 2020-07-27
# train_size                 137
# test_size                  21
# Number of inducing points  13
# run_time                   98.2298
# Train average variance     0.0026
# Test average variance      0.3902
# Train average error        1
# Test average error         19783
# 1st week average error     4591
# 2nd week average error     21041
# 3rd week average error     33717

# %%
m = [e for e in results if e.model == '$f(t, S(t)^p, I(t)^p)$'][0].model_obj
m.kernel.lengthscales.numpy()
# Out:
# array([1.40873733, 5.8410897 , 4.36862039, 6.37994591, 4.84539732,
#        6.28313919, 8.73038198])

# %% [markdown]
# ### **$\lambda (t) = f(t, I(t), Home(t))$** - Gaussian - Matern32

# %%
t = final_data[["Updated"]].to_numpy()
y = final_data[["ConfirmedChange"]].to_numpy()
X = np.hstack([
    final_data[["index"]].to_numpy(),
    final_data[["I"]].to_numpy(),
    final_data[["HOME"]].to_numpy(),
])

model_params = {
    'kernel': gpflow.kernels.Matern32(lengthscales=np.ones(X.shape[1]))
}

res, model = run_experiment('$f(t, I(t), Home(t))$', t, X, y, 
                            model_params=model_params, 
                            train_test_split_func=train_test_split_func, 
                            plot=True)
results.add(res)

# %%
res.to_pandas()
# Out:
#                                             Summary
# Model                      $f(t, I(t), Home(t))$
# Likelihood                 Gaussian
# Kernel                     Matern32
# ELBO                       101.88
# Training-set dates         2020-02-21 to 2020-07-06
# Test-set dates             2020-07-07 to 2020-07-27
# train_size                 137
# test_size                  21
# Number of inducing points  13
# run_time                   99.3463
# Train average variance     0.0022
# Test average variance      0.2305
# Train average error        1
# Test average error         6736
# 1st week average error     511
# 2nd week average error     7611
# 3rd week average error     12087

# %% [markdown]
# ### **$\lambda (t) = f(t, I(t), Home(t), Weekday(t))$** - Gaussian - Matern32

# %%
t = final_data[["Updated"]].to_numpy()
y = final_data[["ConfirmedChange"]].to_numpy()
X = np.hstack([
    final_data[["index"]].to_numpy(),
    final_data[["I"]].to_numpy(),
    final_data[["HOME"]].to_numpy(),
    final_data[["WEEKDAY"]].to_numpy(),
])

model_params = {
    'kernel': gpflow.kernels.Matern32(lengthscales=np.ones(X.shape[1]))
}

res, model = run_experiment('$f(t, I(t), Home(t), Weekday(t))$', t, X, y, 
                            model_params=model_params, 
                            train_test_split_func=train_test_split_func, 
                            plot=True)
results.add(res)

# %%
res.to_pandas()
# Out:
#                                                      Summary
# Model                      $f(t, I(t), Home(t), Weekday(t))$
# Likelihood                 Gaussian
# Kernel                     Matern32
# ELBO                       45.48
# Training-set dates         2020-02-21 to 2020-07-06
# Test-set dates             2020-07-07 to 2020-07-27
# train_size                 137
# test_size                  21
# Number of inducing points  13
# run_time                   97.0907
# Train average variance     0.0075
# Test average variance      0.1751
# Train average error        4
# Test average error         18848
# 1st week average error     5451
# 2nd week average error     20495
# 3rd week average error     30598

# %% [markdown]
# ### **$\lambda (t) = f(t, S(t)*I(t), Home(t))$** - Gaussian - Matern32

# %%
t = final_data[["Updated"]].to_numpy()
y = final_data[["ConfirmedChange"]].to_numpy()
X = np.hstack([
    final_data[["index"]].to_numpy(),
    (final_data["S"] * final_data["I"]).to_numpy().reshape(-1, 1),
    final_data[["HOME"]].to_numpy(),
])

model_params = {
    'kernel': gpflow.kernels.Matern32(lengthscales=np.ones(X.shape[1]))
}

res, model = run_experiment('$f(t, S(t)*I(t), Home(t))$', t, X, y, 
                            model_params=model_params, 
                            train_test_split_func=train_test_split_func, 
                            plot=True)
results.add(res)

# %%
res.to_pandas()
# Out:
#                                               Summary
# Model                      $f(t, S(t)*I(t), Home(t))$
# Likelihood                 Gaussian
# Kernel                     Matern32
# ELBO                       102.04
# Training-set dates         2020-02-21 to 2020-07-06
# Test-set dates             2020-07-07 to 2020-07-27
# train_size                 137
# test_size                  21
# Number of inducing points  13
# run_time                   72.8576
# Train average variance     0.0022
# Test average variance      0.2238
# Train average error        1
# Test average error         6503
# 1st week average error     462
# 2nd week average error     7403
# 3rd week average error     11644

# %% [markdown]
# ### **$\lambda (t) = f(t, S(t)*I(t), Home(t), Weekday(t))$** - Gaussian - Matern32

# %%
t = final_data[["Updated"]].to_numpy()
y = final_data[["ConfirmedChange"]].to_numpy()
X = np.hstack([
    final_data[["index"]].to_numpy(),
    (final_data["S"] * final_data["I"]).to_numpy().reshape(-1, 1),
    final_data[["HOME"]].to_numpy(),
    final_data[["WEEKDAY"]].to_numpy(),
])

model_params = {
    'kernel': gpflow.kernels.Matern32(lengthscales=np.ones(X.shape[1]))
}

res, model = run_experiment('$f(t, S(t)*I(t), Home(t), Weekday(t))$', t, X, y, 
                            model_params=model_params, 
                            train_test_split_func=train_test_split_func, 
                            plot=True)
results.add(res)

# %%
res.to_pandas()
# Out:
#                                                           Summary
# Model                      $f(t, S(t)*I(t), Home(t), Weekday(t))$
# Likelihood                 Gaussian
# Kernel                     Matern32
# ELBO                       46.33
# Training-set dates         2020-02-21 to 2020-07-06
# Test-set dates             2020-07-07 to 2020-07-27
# train_size                 137
# test_size                  21
# Number of inducing points  13
# run_time                   85.0478
# Train average variance     0.0073
# Test average variance      0.1626
# Train average error        4
# Test average error         18723
# 1st week average error     5473
# 2nd week average error     20378
# 3rd week average error     30316

# %% [markdown]
# ### **$\lambda (t) = f(t, S(t)*I(t), Home(t)*Work(t)*Recreational(t))$** - Gaussian - Matern32

# %%
t = final_data[["Updated"]].to_numpy()
y = final_data[["ConfirmedChange"]].to_numpy()
X = np.hstack([
    final_data[["index"]].to_numpy(),
    (final_data["S"] * final_data["I"]).to_numpy().reshape(-1, 1),
    (final_data["HOME"] * final_data["WORK"] * final_data["RECREATIONAL"]).to_numpy().reshape(-1, 1),
])

model_params = {
    'kernel': gpflow.kernels.Matern32(lengthscales=np.ones(X.shape[1]))
}

res, model = run_experiment('$f(t, S(t)*I(t), Home(t)*Work(t)*Recreational(t))$', t, X, y, 
                            model_params=model_params, 
                            train_test_split_func=train_test_split_func, 
                            plot=True)
results.add(res)

# %%
res.to_pandas()
# Out:
#                                                                       Summary
# Model                      $f(t, S(t)*I(t), Home(t)*Work(t)*Recreational(t))$
# Likelihood                 Gaussian
# Kernel                     Matern32
# ELBO                       96.11
# Training-set dates         2020-02-21 to 2020-07-06
# Test-set dates             2020-07-07 to 2020-07-27
# train_size                 137
# test_size                  21
# Number of inducing points  13
# run_time                   85.5999
# Train average variance     0.0026
# Test average variance      0.232
# Train average error        1
# Test average error         6105
# 1st week average error     796
# 2nd week average error     7163
# 3rd week average error     10355

# %% [markdown]
# ### **$\lambda (t) = f(t, S(t)*I(t), Home(t)*Work(t)*Recreational(t), Weekday(t))$** - Gaussian - Matern32

# %%
t = final_data[["Updated"]].to_numpy()
y = final_data[["ConfirmedChange"]].to_numpy()
X = np.hstack([
    final_data[["index"]].to_numpy(),
    (final_data["S"] * final_data["I"]).to_numpy().reshape(-1, 1),
    (final_data["HOME"] * final_data["WORK"] * final_data["RECREATIONAL"]).to_numpy().reshape(-1, 1),
    final_data[["WEEKDAY"]].to_numpy(),
])

model_params = {
    'kernel': gpflow.kernels.Matern32(lengthscales=np.ones(X.shape[1]))
}

res, model = run_experiment('$f(t, S(t)*I(t), Home(t)*Work(t)*Recreational(t), Weekday(t))$', t, X, y, 
                            model_params=model_params, 
                            train_test_split_func=train_test_split_func, 
                            plot=True)
results.add(res)

# %%
res.to_pandas()
# Out:
#                                                                                   Summary
# Model                      $f(t, S(t)*I(t), Home(t)*Work(t)*Recreational(t), Weekday(t))$
# Likelihood                 Gaussian
# Kernel                     Matern32
# ELBO                       42.26
# Training-set dates         2020-02-21 to 2020-07-06
# Test-set dates             2020-07-07 to 2020-07-27
# train_size                 137
# test_size                  21
# Number of inducing points  13
# run_time                   90.7444
# Train average variance     0.0076
# Test average variance      0.1901
# Train average error        4
# Test average error         20466
# 1st week average error     6163
# 2nd week average error     22426
# 3rd week average error     32808

# %% [markdown]
# ### **$\lambda (t) = f(t, S(t), I(t), Home(t), Work(t), Recreational(t))$** - Gaussian - Matern32

# %%
t = final_data[["Updated"]].to_numpy()
y = final_data[["ConfirmedChange"]].to_numpy()
X = np.hstack([
    final_data[["index"]].to_numpy(),
    final_data[["S"]].to_numpy(),
    final_data[["I"]].to_numpy(),
    final_data[["HOME"]].to_numpy(),
    final_data[["WORK"]].to_numpy(),
    final_data[["RECREATIONAL"]].to_numpy(),
])

model_params = {
    'kernel': gpflow.kernels.Matern32(lengthscales=np.ones(X.shape[1]))
}

res, model = run_experiment('$f(t, S(t)*I(t), Home(t), Work(t), Recreational(t))$', t, X, y, 
                            model_params=model_params, 
                            train_test_split_func=train_test_split_func, 
                            plot=True)
results.add(res)

# %%
res.to_pandas()
# Out:
#                                                                         Summary
# Model                      $f(t, S(t)*I(t), Home(t), Work(t), Recreational(t))$
# Likelihood                 Gaussian
# Kernel                     Matern32
# ELBO                       83.18
# Training-set dates         2020-02-21 to 2020-07-06
# Test-set dates             2020-07-07 to 2020-07-27
# train_size                 137
# test_size                  21
# Number of inducing points  13
# run_time                   100.329
# Train average variance     0.0031
# Test average variance      0.2232
# Train average error        1
# Test average error         8244
# 1st week average error     745
# 2nd week average error     9077
# 3rd week average error     14911

# %% [markdown]
# ### **$\lambda (t) = f(t, S(t), I(t), Home(t), Work(t), Recreational(t), Weekday(t))$** - Gaussian - Matern32

# %%
t = final_data[["Updated"]].to_numpy()
y = final_data[["ConfirmedChange"]].to_numpy()
X = np.hstack([
    final_data[["index"]].to_numpy(),
    final_data[["S"]].to_numpy(),
    final_data[["I"]].to_numpy(),
    final_data[["HOME"]].to_numpy(),
    final_data[["WORK"]].to_numpy(),
    final_data[["RECREATIONAL"]].to_numpy(),
    final_data[["WEEKDAY"]].to_numpy(),
])

model_params = {
    'kernel': gpflow.kernels.Matern32(lengthscales=np.ones(X.shape[1]))
}

res, model = run_experiment('$f(t, S(t)*I(t), Home(t), Work(t), Recreational(t), Weekday(t))$', t, X, y, 
                            model_params=model_params, 
                            train_test_split_func=train_test_split_func, 
                            plot=True)
results.add(res)

# %%
res.to_pandas()
# Out:
#                                                                                     Summary
# Model                      $f(t, S(t)*I(t), Home(t), Work(t), Recreational(t), Weekday(t))$
# Likelihood                 Gaussian
# Kernel                     Matern32
# ELBO                       39.67
# Training-set dates         2020-02-21 to 2020-07-06
# Test-set dates             2020-07-07 to 2020-07-27
# train_size                 137
# test_size                  21
# Number of inducing points  13
# run_time                   81.335
# Train average variance     0.0077
# Test average variance      0.1782
# Train average error        3
# Test average error         16891
# 1st week average error     4436
# 2nd week average error     18279
# 3rd week average error     27958

# %% [markdown]
# ### **$\lambda (t) = f(t, S(t)^p, I(t)^p, Home(t)^p, Work(t)^p, Recreational(t)^p)$** - Gaussian - Matern32

# %%
t = final_data[["Updated"]].to_numpy()
y = final_data[["ConfirmedChange"]].to_numpy()
X = np.hstack([
    final_data[["index"]].to_numpy(),
    final_data[["S"]].to_numpy(),
    final_data[["S"]].to_numpy()**2,
    final_data[["S"]].to_numpy()**3,
    final_data[["I"]].to_numpy(),
    final_data[["I"]].to_numpy()**2,
    final_data[["I"]].to_numpy()**3,
    final_data[["HOME"]].to_numpy(),
    final_data[["HOME"]].to_numpy()**2,
    final_data[["HOME"]].to_numpy()**3,
    final_data[["WORK"]].to_numpy(),
    final_data[["WORK"]].to_numpy()**2,
    final_data[["WORK"]].to_numpy()**3,
    final_data[["RECREATIONAL"]].to_numpy(),
    final_data[["RECREATIONAL"]].to_numpy()**2,
    final_data[["RECREATIONAL"]].to_numpy()**3,
])

model_params = {
    'kernel': gpflow.kernels.Matern32(lengthscales=np.ones(X.shape[1]))
}

res, model = run_experiment('$f(t, S(t)^p, I(t)^p, Home(t)^p, Work(t)^p, Recreational(t)^p)$', t, X, y, 
                            model_params=model_params, 
                            train_test_split_func=train_test_split_func, 
                            plot=True)
results.add(res)

# %%
res.to_pandas()
# Out:
#                                                                                    Summary
# Model                      $f(t, S(t)^p, I(t)^p, Home(t)^p, Work(t)^p, Recreational(t)^p)$
# Likelihood                 Gaussian
# Kernel                     Matern32
# ELBO                       71.55
# Training-set dates         2020-02-21 to 2020-07-06
# Test-set dates             2020-07-07 to 2020-07-27
# train_size                 137
# test_size                  21
# Number of inducing points  13
# run_time                   74.3589
# Train average variance     0.0038
# Test average variance      0.3562
# Train average error        1
# Test average error         24942
# 1st week average error     6356
# 2nd week average error     27854
# 3rd week average error     40617

# %% [markdown]
# ### **$\lambda (t) = f(t)$** - Gaussian - SE\*L\*RQ

# %%
t = final_data[["Updated"]].to_numpy()
y = final_data[["ConfirmedChange"]].to_numpy()
X = final_data[["index"]].to_numpy()

model_params = {
    'kernel': (
        gpflow.kernels.SquaredExponential() *
        gpflow.kernels.Linear() * 
        gpflow.kernels.RationalQuadratic()
    )
}

res, model = run_experiment('$f(t)$', t, X, y, 
                            model_params=model_params, 
                            train_test_split_func=train_test_split_func, 
                            plot=True)
results.add(res)

# %%
res.to_pandas()
# Out:
#                                             Summary
# Model                      $f(t)$
# Likelihood                 Gaussian
# Kernel                     Product
# ELBO                      -3.54
# Training-set dates         2020-02-21 to 2020-07-06
# Test-set dates             2020-07-07 to 2020-07-27
# train_size                 137
# test_size                  21
# Number of inducing points  13
# run_time                   93.8987
# Train average variance     0.0047
# Test average variance      1.9001
# Train average error        719
# Test average error         12600
# 1st week average error     1666
# 2nd week average error     12785
# 3rd week average error     23349

# %% [markdown]
# ### **$\lambda (t) = f(S(t), I(t))$** - Gaussian - SE\*L\*RQ

# %%
t = final_data[["Updated"]].to_numpy()
y = final_data[["ConfirmedChange"]].to_numpy()
X = final_data[["S", "I"]].to_numpy()

model_params = {
    'kernel': (
        gpflow.kernels.SquaredExponential(lengthscales=np.ones(X.shape[1])) *
        gpflow.kernels.Linear() * 
        gpflow.kernels.RationalQuadratic(lengthscales=np.ones(X.shape[1]))
    )
}

res, model = run_experiment('$f(S(t), I(t))$', t, X, y, 
                            model_params=model_params, 
                            train_test_split_func=train_test_split_func, 
                            plot=True)
results.add(res)

# %%
res.to_pandas()
# Out:
#                                             Summary
# Model                      $f(S(t), I(t))$
# Likelihood                 Gaussian
# Kernel                     Product
# ELBO                       1.19
# Training-set dates         2020-02-21 to 2020-07-06
# Test-set dates             2020-07-07 to 2020-07-27
# train_size                 137
# test_size                  21
# Number of inducing points  13
# run_time                   84.8814
# Train average variance     0.0044
# Test average variance      14.239
# Train average error        524
# Test average error         27307
# 1st week average error     2496
# 2nd week average error     34081
# 3rd week average error     45343

# %% [markdown]
# ### **$\lambda (t) = f(S(t)*I(t))$** - Gaussian - SE\*L\*RQ

# %%
t = final_data[["Updated"]].to_numpy()
y = final_data[["ConfirmedChange"]].to_numpy()
X = (
    final_data["S"] * final_data["I"]
).to_numpy().reshape(-1, 1)

model_params = {
    'kernel': (
        gpflow.kernels.SquaredExponential() *
        gpflow.kernels.Linear() * 
        gpflow.kernels.RationalQuadratic()
    )
}

res, model = run_experiment('$f(S(t)*I(t))$', t, X, y, 
                            model_params=model_params, 
                            train_test_split_func=train_test_split_func, 
                            plot=True)
results.add(res)

# %%
res.to_pandas()
# Out:
#                                             Summary
# Model                      $f(S(t)*I(t))$
# Likelihood                 Gaussian
# Kernel                     Product
# ELBO                       2.13
# Training-set dates         2020-02-21 to 2020-07-06
# Test-set dates             2020-07-07 to 2020-07-27
# train_size                 137
# test_size                  21
# Number of inducing points  13
# run_time                   105.3
# Train average variance     0.0048
# Test average variance      14.0917
# Train average error        503
# Test average error         31706
# 1st week average error     9609
# 2nd week average error     39797
# 3rd week average error     45714

# %% [markdown]
# ### **$\lambda (t) = f(S(t)+I(t))$** - Gaussian - SE\*L\*RQ

# %%
t = final_data[["Updated"]].to_numpy()
y = final_data[["ConfirmedChange"]].to_numpy()
X = (
    final_data["S"] + final_data["I"]
).to_numpy().reshape(-1, 1)

model_params = {
    'kernel': (
        gpflow.kernels.SquaredExponential() *
        gpflow.kernels.Linear() * 
        gpflow.kernels.RationalQuadratic()
    )
}

res, model = run_experiment('$f(S(t)+I(t))$', t, X, y, 
                            model_params=model_params, 
                            train_test_split_func=train_test_split_func, 
                            plot=True)
results.add(res)

# %%
res.to_pandas()
# Out:
#                                             Summary
# Model                      $f(S(t)+I(t))$
# Likelihood                 Gaussian
# Kernel                     Product
# ELBO                      -194.39
# Training-set dates         2020-02-21 to 2020-07-06
# Test-set dates             2020-07-07 to 2020-07-27
# train_size                 137
# test_size                  21
# Number of inducing points  13
# run_time                   125.77
# Train average variance     0
# Test average variance      0
# Train average error       -0
# Test average error         41443
# 1st week average error     34876
# 2nd week average error     43706
# 3rd week average error     45747

# %% [markdown]
# ### **$\lambda (t) = f(t, S(t)*I(t))$** - Gaussian - SE\*L\*RQ

# %%
t = final_data[["Updated"]].to_numpy()
y = final_data[["ConfirmedChange"]].to_numpy()
X = np.hstack([
    final_data[["index"]].to_numpy(),
    (final_data["S"] * final_data["I"]).to_numpy().reshape(-1, 1)
])

model_params = {
    'kernel': (
        gpflow.kernels.SquaredExponential(lengthscales=np.ones(X.shape[1])) *
        gpflow.kernels.Linear() * 
        gpflow.kernels.RationalQuadratic(lengthscales=np.ones(X.shape[1]))
    )
}

res, model = run_experiment('$f(t, S(t)*I(t))$', t, X, y, 
                            model_params=model_params, 
                            train_test_split_func=train_test_split_func, 
                            plot=True)
results.add(res)

# %%
res.to_pandas()
# Out:
#                                             Summary
# Model                      $f(t, S(t)*I(t))$
# Likelihood                 Gaussian
# Kernel                     Product
# ELBO                       118.97
# Training-set dates         2020-02-21 to 2020-07-06
# Test-set dates             2020-07-07 to 2020-07-27
# train_size                 137
# test_size                  21
# Number of inducing points  13
# run_time                   122.672
# Train average variance     0.0009
# Test average variance      10.3992
# Train average error        11
# Test average error         6849
# 1st week average error    -483
# 2nd week average error     6999
# 3rd week average error     14030

# %% [markdown]
# ### **$\lambda (t) = f(t, S(t)+I(t))$** - Gaussian - SE\*L\*RQ

# %%
t = final_data[["Updated"]].to_numpy()
y = final_data[["ConfirmedChange"]].to_numpy()
X = np.hstack([
    final_data[["index"]].to_numpy(),
    (final_data["S"] + final_data["I"]).to_numpy().reshape(-1, 1)
])

model_params = {
    'kernel': (
        gpflow.kernels.SquaredExponential(lengthscales=np.ones(X.shape[1])) *
        gpflow.kernels.Linear() * 
        gpflow.kernels.RationalQuadratic(lengthscales=np.ones(X.shape[1]))
    )
}

res, model = run_experiment('$f(t, S(t)+I(t))$', t, X, y, 
                            model_params=model_params, 
                            train_test_split_func=train_test_split_func, 
                            plot=True)
results.add(res)

# %%
res.to_pandas()
# Out:
#                                             Summary
# Model                      $f(t, S(t)+I(t))$
# Likelihood                 Gaussian
# Kernel                     Product
# ELBO                      -3.54
# Training-set dates         2020-02-21 to 2020-07-06
# Test-set dates             2020-07-07 to 2020-07-27
# train_size                 137
# test_size                  21
# Number of inducing points  13
# run_time                   118.064
# Train average variance     0.0047
# Test average variance      1.8996
# Train average error        719
# Test average error         12596
# 1st week average error     1665
# 2nd week average error     12780
# 3rd week average error     23341

# %% [markdown]
# ### **$\lambda (t) = f(t, S(t), I(t))$** - Gaussian - SE\*L\*RQ

# %%
t = final_data[["Updated"]].to_numpy()
y = final_data[["ConfirmedChange"]].to_numpy()
X = np.hstack([
    final_data[["index"]].to_numpy(),
    final_data[["S"]].to_numpy(),
    final_data[["I"]].to_numpy(),
])

model_params = {
    'kernel': (
        gpflow.kernels.SquaredExponential(lengthscales=np.ones(X.shape[1])) *
        gpflow.kernels.Linear() * 
        gpflow.kernels.RationalQuadratic(lengthscales=np.ones(X.shape[1]))
    )
}

res, model = run_experiment('$f(t, S(t), I(t))$', t, X, y, 
                            model_params=model_params, 
                            train_test_split_func=train_test_split_func, 
                            plot=True)
results.add(res)

# %%
res.to_pandas()
# Out:
#                                             Summary
# Model                      $f(t, S(t), I(t))$
# Likelihood                 Gaussian
# Kernel                     Product
# ELBO                       114.5
# Training-set dates         2020-02-21 to 2020-07-06
# Test-set dates             2020-07-07 to 2020-07-27
# train_size                 137
# test_size                  21
# Number of inducing points  13
# run_time                   112.227
# Train average variance     0.001
# Test average variance      13.5821
# Train average error        14
# Test average error         6260
# 1st week average error    -1056
# 2nd week average error     5973
# 3rd week average error     13862

# %% [markdown]
# ### **$\lambda (t) = f(t, S(t)^p, I(t)^p)$** - Gaussian - SE\*L\*RQ

# %%
t = final_data[["Updated"]].to_numpy()
y = final_data[["ConfirmedChange"]].to_numpy()
X = np.hstack([
    final_data[["index"]].to_numpy(),
    final_data[["S"]].to_numpy(),
    final_data[["S"]].to_numpy()**2,
    final_data[["S"]].to_numpy()**3,
    final_data[["I"]].to_numpy(),
    final_data[["I"]].to_numpy()**2,
    final_data[["I"]].to_numpy()**3,
])

model_params = {
    'kernel': (
        gpflow.kernels.SquaredExponential(lengthscales=np.ones(X.shape[1])) *
        gpflow.kernels.Linear() * 
        gpflow.kernels.RationalQuadratic(lengthscales=np.ones(X.shape[1]))
    )
}

res, model = run_experiment('$f(t, S(t)^p, I(t)^p)$', t, X, y, 
                            model_params=model_params, 
                            train_test_split_func=train_test_split_func, 
                            plot=True)
results.add(res)

# %%
res.to_pandas()
# Out:
#                                             Summary
# Model                      $f(t, S(t)^p, I(t)^p)$
# Likelihood                 Gaussian
# Kernel                     Product
# ELBO                       100.81
# Training-set dates         2020-02-21 to 2020-07-06
# Test-set dates             2020-07-07 to 2020-07-27
# train_size                 137
# test_size                  21
# Number of inducing points  13
# run_time                   100.711
# Train average variance     0.0015
# Test average variance      28.4802
# Train average error        6
# Test average error         22937
# 1st week average error    -850
# 2nd week average error     25431
# 3rd week average error     44230

# %% [markdown]
# ### **$\lambda (t) = f(t, I(t), Home(t))$** - Gaussian - SE\*L\*RQ

# %%
t = final_data[["Updated"]].to_numpy()
y = final_data[["ConfirmedChange"]].to_numpy()
X = np.hstack([
    final_data[["index"]].to_numpy(),
    final_data[["I"]].to_numpy(),
    final_data[["HOME"]].to_numpy(),
])

model_params = {
    'kernel': (
        gpflow.kernels.SquaredExponential(lengthscales=np.ones(X.shape[1])) *
        gpflow.kernels.Linear() * 
        gpflow.kernels.RationalQuadratic(lengthscales=np.ones(X.shape[1]))
    )
}

res, model = run_experiment('$f(t, I(t), Home(t))$', t, X, y, 
                            model_params=model_params, 
                            train_test_split_func=train_test_split_func, 
                            plot=True)
results.add(res)

# %%
res.to_pandas()
# Out:
#                                             Summary
# Model                      $f(t, I(t), Home(t))$
# Likelihood                 Gaussian
# Kernel                     Product
# ELBO                       118.22
# Training-set dates         2020-02-21 to 2020-07-06
# Test-set dates             2020-07-07 to 2020-07-27
# train_size                 137
# test_size                  21
# Number of inducing points  13
# run_time                   98.8259
# Train average variance     0.0013
# Test average variance      0.837
# Train average error        6
# Test average error         13944
# 1st week average error     2059
# 2nd week average error     14200
# 3rd week average error     25574

# %% [markdown]
# ### **$\lambda (t) = f(t, I(t), Home(t), Weekday(t))$** - Gaussian - SE\*L\*RQ

# %%
t = final_data[["Updated"]].to_numpy()
y = final_data[["ConfirmedChange"]].to_numpy()
X = np.hstack([
    final_data[["index"]].to_numpy(),
    final_data[["I"]].to_numpy(),
    final_data[["HOME"]].to_numpy(),
    final_data[["WEEKDAY"]].to_numpy(),
])

model_params = {
    'kernel': (
        gpflow.kernels.SquaredExponential(lengthscales=np.ones(X.shape[1])) *
        gpflow.kernels.Linear() * 
        gpflow.kernels.RationalQuadratic(lengthscales=np.ones(X.shape[1]))
    )
}

res, model = run_experiment('$f(t, I(t), Home(t), Weekday(t))$', t, X, y, 
                            model_params=model_params, 
                            train_test_split_func=train_test_split_func, 
                            plot=True)
results.add(res)

# %%
res.to_pandas()
# Out:
#                                                      Summary
# Model                      $f(t, I(t), Home(t), Weekday(t))$
# Likelihood                 Gaussian
# Kernel                     Product
# ELBO                       46.66
# Training-set dates         2020-02-21 to 2020-07-06
# Test-set dates             2020-07-07 to 2020-07-27
# train_size                 137
# test_size                  21
# Number of inducing points  13
# run_time                   109.526
# Train average variance     0.0059
# Test average variance      0.6432
# Train average error        9
# Test average error         27679
# 1st week average error     7929
# 2nd week average error     31656
# 3rd week average error     43451

# %% [markdown]
# ### **$\lambda (t) = f(t, S(t)*I(t), Home(t))$** - Gaussian - SE\*L\*RQ

# %%
t = final_data[["Updated"]].to_numpy()
y = final_data[["ConfirmedChange"]].to_numpy()
X = np.hstack([
    final_data[["index"]].to_numpy(),
    (final_data["S"] * final_data["I"]).to_numpy().reshape(-1, 1),
    final_data[["HOME"]].to_numpy(),
])

model_params = {
    'kernel': (
        gpflow.kernels.SquaredExponential(lengthscales=np.ones(X.shape[1])) *
        gpflow.kernels.Linear() * 
        gpflow.kernels.RationalQuadratic(lengthscales=np.ones(X.shape[1]))
    )
}

res, model = run_experiment('$f(t, S(t)*I(t), Home(t))$', t, X, y, 
                            model_params=model_params, 
                            train_test_split_func=train_test_split_func, 
                            plot=True)
results.add(res)

# %%
res.to_pandas()
# Out:
#                                               Summary
# Model                      $f(t, S(t)*I(t), Home(t))$
# Likelihood                 Gaussian
# Kernel                     Product
# ELBO                       118.34
# Training-set dates         2020-02-21 to 2020-07-06
# Test-set dates             2020-07-07 to 2020-07-27
# train_size                 137
# test_size                  21
# Number of inducing points  13
# run_time                   104.413
# Train average variance     0.0013
# Test average variance      0.8051
# Train average error        6
# Test average error         14066
# 1st week average error     2126
# 2nd week average error     14347
# 3rd week average error     25724

# %% [markdown]
# ### **$\lambda (t) = f(t, S(t)*I(t), Home(t), Weekday(t))$** - Gaussian - SE\*L\*RQ

# %%
t = final_data[["Updated"]].to_numpy()
y = final_data[["ConfirmedChange"]].to_numpy()
X = np.hstack([
    final_data[["index"]].to_numpy(),
    (final_data["S"] * final_data["I"]).to_numpy().reshape(-1, 1),
    final_data[["HOME"]].to_numpy(),
    final_data[["WEEKDAY"]].to_numpy(),
])

model_params = {
    'kernel': (
        gpflow.kernels.SquaredExponential(lengthscales=np.ones(X.shape[1])) *
        gpflow.kernels.Linear() * 
        gpflow.kernels.RationalQuadratic(lengthscales=np.ones(X.shape[1]))
    )
}

res, model = run_experiment('$f(t, S(t)*I(t), Home(t), Weekday(t))$', t, X, y, 
                            model_params=model_params, 
                            train_test_split_func=train_test_split_func, 
                            plot=True)
results.add(res)

# %%
res.to_pandas()
# Out:
#                                                           Summary
# Model                      $f(t, S(t)*I(t), Home(t), Weekday(t))$
# Likelihood                 Gaussian
# Kernel                     Product
# ELBO                       47.37
# Training-set dates         2020-02-21 to 2020-07-06
# Test-set dates             2020-07-07 to 2020-07-27
# train_size                 137
# test_size                  21
# Number of inducing points  13
# run_time                   99.3919
# Train average variance     0.0058
# Test average variance      0.6249
# Train average error        8
# Test average error         26877
# 1st week average error     7298
# 2nd week average error     30472
# 3rd week average error     42860

# %% [markdown]
# ### **$\lambda (t) = f(t, S(t)*I(t), Home(t)*Work(t)*Recreational(t))$** - Gaussian - SE\*L\*RQ

# %%
t = final_data[["Updated"]].to_numpy()
y = final_data[["ConfirmedChange"]].to_numpy()
X = np.hstack([
    final_data[["index"]].to_numpy(),
    (final_data["S"] * final_data["I"]).to_numpy().reshape(-1, 1),
    (final_data["HOME"] * final_data["WORK"] * final_data["RECREATIONAL"]).to_numpy().reshape(-1, 1),
])

model_params = {
    'kernel': (
        gpflow.kernels.SquaredExponential(lengthscales=np.ones(X.shape[1])) *
        gpflow.kernels.Linear() * 
        gpflow.kernels.RationalQuadratic(lengthscales=np.ones(X.shape[1]))
    )
}

res, model = run_experiment('$f(t, S(t)*I(t), Home(t)*Work(t)*Recreational(t)$', t, X, y, 
                            model_params=model_params, 
                            train_test_split_func=train_test_split_func, 
                            plot=True)
results.add(res)

# %%
res.to_pandas()

# %% [markdown]
# ### **$\lambda (t) = f(t, S(t)*I(t), Home(t)*Work(t)*Recreational(t), Weekday(t))$** - Gaussian - SE\*L\*RQ

# %%
t = final_data[["Updated"]].to_numpy()
y = final_data[["ConfirmedChange"]].to_numpy()
X = np.hstack([
    final_data[["index"]].to_numpy(),
    (final_data["S"] * final_data["I"]).to_numpy().reshape(-1, 1),
    (final_data["HOME"] * final_data["WORK"] * final_data["RECREATIONAL"]).to_numpy().reshape(-1, 1),
    final_data[["WEEKDAY"]].to_numpy(),
])

model_params = {
    'kernel': (
        gpflow.kernels.SquaredExponential(lengthscales=np.ones(X.shape[1])) *
        gpflow.kernels.Linear() * 
        gpflow.kernels.RationalQuadratic(lengthscales=np.ones(X.shape[1]))
    )
}

res, model = run_experiment('$f(t, S(t)*I(t), Home(t)*Work(t)*Recreational(t), Weekday(t))$', t, X, y, 
                            model_params=model_params, 
                            train_test_split_func=train_test_split_func, 
                            plot=True)
results.add(res)

# %%
res.to_pandas()

# %% [markdown]
# ### **$\lambda (t) = f(t, S(t), I(t), Home(t), Work(t), Recreational(t))$** - Gaussian - SE\*L\*RQ

# %%
t = final_data[["Updated"]].to_numpy()
y = final_data[["ConfirmedChange"]].to_numpy()
X = np.hstack([
    final_data[["index"]].to_numpy(),
    final_data[["S"]].to_numpy(),
    final_data[["I"]].to_numpy(),
    final_data[["HOME"]].to_numpy(),
    final_data[["WORK"]].to_numpy(),
    final_data[["RECREATIONAL"]].to_numpy(),
])

model_params = {
    'kernel': (
        gpflow.kernels.SquaredExponential(lengthscales=np.ones(X.shape[1])) *
        gpflow.kernels.Linear() * 
        gpflow.kernels.RationalQuadratic(lengthscales=np.ones(X.shape[1]))
    )
}

res, model = run_experiment('$f(t, S(t), I(t), Home(t), Work(t), Recreational(t)$', t, X, y, 
                            model_params=model_params, 
                            train_test_split_func=train_test_split_func, 
                            plot=True)
results.add(res)

# %%
res.to_pandas()

# %% [markdown]
# ### **$\lambda (t) = f(t, S(t), I(t), Home(t), Work(t), Recreational(t), Weekday(t))$** - Gaussian - SE\*L\*RQ

# %%
t = final_data[["Updated"]].to_numpy()
y = final_data[["ConfirmedChange"]].to_numpy()
X = np.hstack([
    final_data[["index"]].to_numpy(),
    final_data[["S"]].to_numpy(),
    final_data[["I"]].to_numpy(),
    final_data[["HOME"]].to_numpy(),
    final_data[["WORK"]].to_numpy(),
    final_data[["RECREATIONAL"]].to_numpy(),
    final_data[["WEEKDAY"]].to_numpy(),
])

model_params = {
    'kernel': (
        gpflow.kernels.SquaredExponential(lengthscales=np.ones(X.shape[1])) *
        gpflow.kernels.Linear() * 
        gpflow.kernels.RationalQuadratic(lengthscales=np.ones(X.shape[1]))
    )
}

res, model = run_experiment('$f(t, S(t), I(t), Home(t), Work(t), Recreational(t), Weekday(t))$', t, X, y, 
                            model_params=model_params, 
                            train_test_split_func=train_test_split_func, 
                            plot=True)
results.add(res)

# %%
res.to_pandas()

# %% [markdown]
# ### **$\lambda (t) = f(t, S(t)^p, I(t)^p, Home(t)^p, Work(t)^p, Recreational(t)^p)$** - Gaussian - SE\*L\*RQ

# %%
t = final_data[["Updated"]].to_numpy()
y = final_data[["ConfirmedChange"]].to_numpy()
X = np.hstack([
    final_data[["index"]].to_numpy(),
    final_data[["S"]].to_numpy(),
    final_data[["S"]].to_numpy()**2,
    final_data[["S"]].to_numpy()**3,
    final_data[["I"]].to_numpy(),
    final_data[["I"]].to_numpy()**2,
    final_data[["I"]].to_numpy()**3,
    final_data[["HOME"]].to_numpy(),
    final_data[["HOME"]].to_numpy()**2,
    final_data[["HOME"]].to_numpy()**3,
    final_data[["WORK"]].to_numpy(),
    final_data[["WORK"]].to_numpy()**2,
    final_data[["WORK"]].to_numpy()**3,
    final_data[["RECREATIONAL"]].to_numpy(),
    final_data[["RECREATIONAL"]].to_numpy()**2,
    final_data[["RECREATIONAL"]].to_numpy()**3,
])

model_params = {
    'kernel': (
        gpflow.kernels.SquaredExponential(lengthscales=np.ones(X.shape[1])) *
        gpflow.kernels.Linear() * 
        gpflow.kernels.RationalQuadratic(lengthscales=np.ones(X.shape[1]))
    )
}

res, model = run_experiment('$f(t, S(t)^p, I(t)^p, Home(t)^p, Work(t)^p, Recreational(t)^p$', t, X, y, 
                            model_params=model_params, 
                            train_test_split_func=train_test_split_func, 
                            plot=True)
results.add(res)

# %%
res.to_pandas()

# %% [markdown]
# ### **$\lambda (t) = f(t)$** - Gaussian - SE\+L\+RQ

# %%
t = final_data[["Updated"]].to_numpy()
y = final_data[["ConfirmedChange"]].to_numpy()
X = final_data[["index"]].to_numpy()

model_params = {
    'kernel': (
        gpflow.kernels.SquaredExponential() +
        gpflow.kernels.Linear() +
        gpflow.kernels.RationalQuadratic()
    )
}

res, model = run_experiment('$f(t)$', t, X, y, 
                            model_params=model_params, 
                            train_test_split_func=train_test_split_func, 
                            plot=True)
results.add(res)

# %%
res.to_pandas()

# %% [markdown]
# ### **$\lambda (t) = f(S(t), I(t))$** - Gaussian - SE\+L\+RQ

# %%
t = final_data[["Updated"]].to_numpy()
y = final_data[["ConfirmedChange"]].to_numpy()
X = final_data[["S", "I"]].to_numpy()

model_params = {
    'kernel': (
        gpflow.kernels.SquaredExponential(lengthscales=np.ones(X.shape[1])) +
        gpflow.kernels.Linear() +
        gpflow.kernels.RationalQuadratic(lengthscales=np.ones(X.shape[1]))
    )
}

res, model = run_experiment('$f(S(t), I(t))$', t, X, y, 
                            model_params=model_params, 
                            train_test_split_func=train_test_split_func, 
                            plot=True)
results.add(res)

# %%
res.to_pandas()

# %% [markdown]
# ### **$\lambda (t) = f(S(t)*I(t))$** - Gaussian - SE\+L\+RQ

# %%
t = final_data[["Updated"]].to_numpy()
y = final_data[["ConfirmedChange"]].to_numpy()
X = (
    final_data["S"] * final_data["I"]
).to_numpy().reshape(-1, 1)

model_params = {
    'kernel': (
        gpflow.kernels.SquaredExponential() +
        gpflow.kernels.Linear() +
        gpflow.kernels.RationalQuadratic()
    )
}

res, model = run_experiment('$f(S(t)*I(t))$', t, X, y, 
                            model_params=model_params, 
                            train_test_split_func=train_test_split_func, 
                            plot=True)
results.add(res)

# %%
res.to_pandas()

# %% [markdown]
# ### **$\lambda (t) = f(S(t)+I(t))$** - Gaussian - SE\+L\+RQ

# %%
t = final_data[["Updated"]].to_numpy()
y = final_data[["ConfirmedChange"]].to_numpy()
X = (
    final_data["S"] + final_data["I"]
).to_numpy().reshape(-1, 1)

model_params = {
    'kernel': (
        gpflow.kernels.SquaredExponential() +
        gpflow.kernels.Linear() +
        gpflow.kernels.RationalQuadratic()
    )
}

res, model = run_experiment('$f(S(t)+I(t))$', t, X, y, 
                            model_params=model_params, 
                            train_test_split_func=train_test_split_func, 
                            plot=True)
results.add(res)

# %%
res.to_pandas()

# %% [markdown]
# ### **$\lambda (t) = f(t, S(t)*I(t))$** - Gaussian - SE\+L\+RQ

# %%
t = final_data[["Updated"]].to_numpy()
y = final_data[["ConfirmedChange"]].to_numpy()
X = np.hstack([
    final_data[["index"]].to_numpy(),
    (final_data["S"] * final_data["I"]).to_numpy().reshape(-1, 1)
])

model_params = {
    'kernel': (
        gpflow.kernels.SquaredExponential(lengthscales=np.ones(X.shape[1])) +
        gpflow.kernels.Linear() +
        gpflow.kernels.RationalQuadratic(lengthscales=np.ones(X.shape[1]))
    )
}

res, model = run_experiment('$f(t, S(t)*I(t))$', t, X, y, 
                            model_params=model_params, 
                            train_test_split_func=train_test_split_func, 
                            plot=True)
results.add(res)

# %%
res.to_pandas()

# %% [markdown]
# ### **$\lambda (t) = f(t, S(t)+I(t))$** - Gaussian - SE\+L\+RQ

# %%
t = final_data[["Updated"]].to_numpy()
y = final_data[["ConfirmedChange"]].to_numpy()
X = np.hstack([
    final_data[["index"]].to_numpy(),
    (final_data["S"] + final_data["I"]).to_numpy().reshape(-1, 1)
])

model_params = {
    'kernel': (
        gpflow.kernels.SquaredExponential(lengthscales=np.ones(X.shape[1])) +
        gpflow.kernels.Linear() +
        gpflow.kernels.RationalQuadratic(lengthscales=np.ones(X.shape[1]))
    )
}

res, model = run_experiment('$f(t, S(t)+I(t))$', t, X, y, 
                            model_params=model_params, 
                            train_test_split_func=train_test_split_func, 
                            plot=True)
results.add(res)

# %%
res.to_pandas()

# %% [markdown]
# ### **$\lambda (t) = f(t, S(t), I(t))$** - Gaussian - SE\+L\+RQ

# %%
t = final_data[["Updated"]].to_numpy()
y = final_data[["ConfirmedChange"]].to_numpy()
X = np.hstack([
    final_data[["index"]].to_numpy(),
    final_data[["S"]].to_numpy(),
    final_data[["I"]].to_numpy(),
])

model_params = {
    'kernel': (
        gpflow.kernels.SquaredExponential(lengthscales=np.ones(X.shape[1])) +
        gpflow.kernels.Linear() +
        gpflow.kernels.RationalQuadratic(lengthscales=np.ones(X.shape[1]))
    )
}

res, model = run_experiment('$f(t, S(t), I(t))$', t, X, y, 
                            model_params=model_params, 
                            train_test_split_func=train_test_split_func, 
                            plot=True)
results.add(res)

# %%
res.to_pandas()

# %% [markdown]
# ### **$\lambda (t) = f(t, S(t)^p, I(t)^p)$** - Gaussian - SE\+L\+RQ

# %%
t = final_data[["Updated"]].to_numpy()
y = final_data[["ConfirmedChange"]].to_numpy()
X = np.hstack([
    final_data[["index"]].to_numpy(),
    final_data[["S"]].to_numpy(),
    final_data[["S"]].to_numpy()**2,
    final_data[["S"]].to_numpy()**3,
    final_data[["I"]].to_numpy(),
    final_data[["I"]].to_numpy()**2,
    final_data[["I"]].to_numpy()**3,
])

model_params = {
    'kernel': (
        gpflow.kernels.SquaredExponential(lengthscales=np.ones(X.shape[1])) +
        gpflow.kernels.Linear() +
        gpflow.kernels.RationalQuadratic(lengthscales=np.ones(X.shape[1]))
    )
}

res, model = run_experiment('$f(t, S(t)^p, I(t)^p)$', t, X, y, 
                            model_params=model_params, 
                            train_test_split_func=train_test_split_func, 
                            plot=True)
results.add(res)

# %%
res.to_pandas()

# %% [markdown]
# ### **$\lambda (t) = f(t, I(t), Home(t))$** - Gaussian - SE\+L\+RQ

# %%
t = final_data[["Updated"]].to_numpy()
y = final_data[["ConfirmedChange"]].to_numpy()
X = np.hstack([
    final_data[["index"]].to_numpy(),
    final_data[["I"]].to_numpy(),
    final_data[["HOME"]].to_numpy(),
])

model_params = {
    'kernel': (
        gpflow.kernels.SquaredExponential(lengthscales=np.ones(X.shape[1])) +
        gpflow.kernels.Linear() +
        gpflow.kernels.RationalQuadratic(lengthscales=np.ones(X.shape[1]))
    )
}

res, model = run_experiment('$f(t, I(t), Home(t))$', t, X, y, 
                            model_params=model_params, 
                            train_test_split_func=train_test_split_func, 
                            plot=True)
results.add(res)

# %%
res.to_pandas()

# %% [markdown]
# ### **$\lambda (t) = f(t, I(t), Home(t), Weekday(t))$** - Gaussian - SE\+L\+RQ

# %%
t = final_data[["Updated"]].to_numpy()
y = final_data[["ConfirmedChange"]].to_numpy()
X = np.hstack([
    final_data[["index"]].to_numpy(),
    final_data[["I"]].to_numpy(),
    final_data[["HOME"]].to_numpy(),
    final_data[["WEEKDAY"]].to_numpy(),
])

model_params = {
    'kernel': (
        gpflow.kernels.SquaredExponential(lengthscales=np.ones(X.shape[1])) +
        gpflow.kernels.Linear() +
        gpflow.kernels.RationalQuadratic(lengthscales=np.ones(X.shape[1]))
    )
}

res, model = run_experiment('$f(t, I(t), Home(t), Weekday(t))$', t, X, y, 
                            model_params=model_params, 
                            train_test_split_func=train_test_split_func, 
                            plot=True)
results.add(res)

# %%
res.to_pandas()

# %% [markdown]
# ### **$\lambda (t) = f(t, S(t)*I(t), Home(t))$** - Gaussian - SE\+L\+RQ

# %%
t = final_data[["Updated"]].to_numpy()
y = final_data[["ConfirmedChange"]].to_numpy()
X = np.hstack([
    final_data[["index"]].to_numpy(),
    (final_data["S"] * final_data["I"]).to_numpy().reshape(-1, 1),
    final_data[["HOME"]].to_numpy(),
])

model_params = {
    'kernel': (
        gpflow.kernels.SquaredExponential(lengthscales=np.ones(X.shape[1])) +
        gpflow.kernels.Linear() +
        gpflow.kernels.RationalQuadratic(lengthscales=np.ones(X.shape[1]))
    )
}

res, model = run_experiment('$f(t, S(t)*I(t), Home(t))$', t, X, y, 
                            model_params=model_params, 
                            train_test_split_func=train_test_split_func, 
                            plot=True)
results.add(res)

# %%
res.to_pandas()

# %% [markdown]
# ### **$\lambda (t) = f(t, S(t)*I(t), Home(t), Weekday(t))$** - Gaussian - SE\+L\+RQ

# %%
t = final_data[["Updated"]].to_numpy()
y = final_data[["ConfirmedChange"]].to_numpy()
X = np.hstack([
    final_data[["index"]].to_numpy(),
    (final_data["S"] * final_data["I"]).to_numpy().reshape(-1, 1),
    final_data[["HOME"]].to_numpy(),
    final_data[["WEEKDAY"]].to_numpy(),
])

model_params = {
    'kernel': (
        gpflow.kernels.SquaredExponential(lengthscales=np.ones(X.shape[1])) +
        gpflow.kernels.Linear() +
        gpflow.kernels.RationalQuadratic(lengthscales=np.ones(X.shape[1]))
    )
}

res, model = run_experiment('$f(t, S(t)*I(t), Home(t), Weekday(t))$', t, X, y, 
                            model_params=model_params, 
                            train_test_split_func=train_test_split_func, 
                            plot=True)
results.add(res)

# %%
res.to_pandas()

# %% [markdown]
# ### **$\lambda (t) = f(t, S(t)*I(t), Home(t)*Work(t)*Recreational(t))$** - Gaussian - SE\+L\+RQ

# %%
t = final_data[["Updated"]].to_numpy()
y = final_data[["ConfirmedChange"]].to_numpy()
X = np.hstack([
    final_data[["index"]].to_numpy(),
    (final_data["S"] * final_data["I"]).to_numpy().reshape(-1, 1),
    (final_data["HOME"] * final_data["WORK"] * final_data["RECREATIONAL"]).to_numpy().reshape(-1, 1),
])

model_params = {
    'kernel': (
        gpflow.kernels.SquaredExponential(lengthscales=np.ones(X.shape[1])) +
        gpflow.kernels.Linear() +
        gpflow.kernels.RationalQuadratic(lengthscales=np.ones(X.shape[1]))
    )
}

res, model = run_experiment('$f(t, S(t)*I(t), Home(t)*Work(t)*Recreational(t)$', t, X, y, 
                            model_params=model_params, 
                            train_test_split_func=train_test_split_func, 
                            plot=True)
results.add(res)

# %%
res.to_pandas()

# %% [markdown]
# ### **$\lambda (t) = f(t, S(t)*I(t), Home(t)*Work(t)*Recreational(t), Weekday(t))$** - Gaussian - SE\+L\+RQ

# %%
t = final_data[["Updated"]].to_numpy()
y = final_data[["ConfirmedChange"]].to_numpy()
X = np.hstack([
    final_data[["index"]].to_numpy(),
    (final_data["S"] * final_data["I"]).to_numpy().reshape(-1, 1),
    (final_data["HOME"] * final_data["WORK"] * final_data["RECREATIONAL"]).to_numpy().reshape(-1, 1),
    final_data[["WEEKDAY"]].to_numpy(),
])

model_params = {
    'kernel': (
        gpflow.kernels.SquaredExponential(lengthscales=np.ones(X.shape[1])) +
        gpflow.kernels.Linear() +
        gpflow.kernels.RationalQuadratic(lengthscales=np.ones(X.shape[1]))
    )
}

res, model = run_experiment('$f(t, S(t)*I(t), Home(t)*Work(t)*Recreational(t), Weekday(t))$', t, X, y, 
                            model_params=model_params, 
                            train_test_split_func=train_test_split_func, 
                            plot=True)
results.add(res)

# %%
res.to_pandas()

# %% [markdown]
# ### **$\lambda (t) = f(t, S(t), I(t), Home(t), Work(t), Recreational(t))$** - Gaussian - SE\+L\+RQ

# %%
t = final_data[["Updated"]].to_numpy()
y = final_data[["ConfirmedChange"]].to_numpy()
X = np.hstack([
    final_data[["index"]].to_numpy(),
    final_data[["S"]].to_numpy(),
    final_data[["I"]].to_numpy(),
    final_data[["HOME"]].to_numpy(),
    final_data[["WORK"]].to_numpy(),
    final_data[["RECREATIONAL"]].to_numpy(),
])

model_params = {
    'kernel': (
        gpflow.kernels.SquaredExponential(lengthscales=np.ones(X.shape[1])) +
        gpflow.kernels.Linear() +
        gpflow.kernels.RationalQuadratic(lengthscales=np.ones(X.shape[1]))
    )
}

res, model = run_experiment('$f(t, S(t), I(t), Home(t), Work(t), Recreational(t)$', t, X, y, 
                            model_params=model_params, 
                            train_test_split_func=train_test_split_func, 
                            plot=True)
results.add(res)

# %%
res.to_pandas()

# %% [markdown]
# ### **$\lambda (t) = f(t, S(t), I(t), Home(t), Work(t), Recreational(t), Weekday(t))$** - Gaussian - SE\+L\+RQ

# %%
t = final_data[["Updated"]].to_numpy()
y = final_data[["ConfirmedChange"]].to_numpy()
X = np.hstack([
    final_data[["index"]].to_numpy(),
    final_data[["S"]].to_numpy(),
    final_data[["I"]].to_numpy(),
    final_data[["HOME"]].to_numpy(),
    final_data[["WORK"]].to_numpy(),
    final_data[["RECREATIONAL"]].to_numpy(),
    final_data[["WEEKDAY"]].to_numpy(),
])

model_params = {
    'kernel': (
        gpflow.kernels.SquaredExponential(lengthscales=np.ones(X.shape[1])) +
        gpflow.kernels.Linear() +
        gpflow.kernels.RationalQuadratic(lengthscales=np.ones(X.shape[1]))
    )
}

res, model = run_experiment('$f(t, S(t), I(t), Home(t), Work(t), Recreational(t), Weekday(t))$', t, X, y, 
                            model_params=model_params, 
                            train_test_split_func=train_test_split_func, 
                            plot=True)
results.add(res)

# %%
res.to_pandas()

# %% [markdown]
# ### **$\lambda (t) = f(t, S(t)^p, I(t)^p, Home(t)^p, Work(t)^p, Recreational(t)^p)$** - Gaussian - SE\+L\+RQ

# %%
t = final_data[["Updated"]].to_numpy()
y = final_data[["ConfirmedChange"]].to_numpy()
X = np.hstack([
    final_data[["index"]].to_numpy(),
    final_data[["S"]].to_numpy(),
    final_data[["S"]].to_numpy()**2,
    final_data[["S"]].to_numpy()**3,
    final_data[["I"]].to_numpy(),
    final_data[["I"]].to_numpy()**2,
    final_data[["I"]].to_numpy()**3,
    final_data[["HOME"]].to_numpy(),
    final_data[["HOME"]].to_numpy()**2,
    final_data[["HOME"]].to_numpy()**3,
    final_data[["WORK"]].to_numpy(),
    final_data[["WORK"]].to_numpy()**2,
    final_data[["WORK"]].to_numpy()**3,
    final_data[["RECREATIONAL"]].to_numpy(),
    final_data[["RECREATIONAL"]].to_numpy()**2,
    final_data[["RECREATIONAL"]].to_numpy()**3,
])

model_params = {
    'kernel': (
        gpflow.kernels.SquaredExponential(lengthscales=np.ones(X.shape[1])) +
        gpflow.kernels.Linear() +
        gpflow.kernels.RationalQuadratic(lengthscales=np.ones(X.shape[1]))
    )
}

res, model = run_experiment('$f(t, S(t)^p, I(t)^p, Home(t)^p, Work(t)^p, Recreational(t)^p$', t, X, y, 
                            model_params=model_params, 
                            train_test_split_func=train_test_split_func, 
                            plot=True)
results.add(res)

# %%
res.to_pandas()

# %% [markdown]
# ## Report

# %%
rep = Report(results, name='test')
rep.loc[rep["out_sample"].abs().sort_values(ascending=True).index]
